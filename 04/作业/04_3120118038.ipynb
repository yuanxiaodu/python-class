# %%
import sys
sys.executable
# Out:
# 'D:\\ANACONDA\\python.exe'

# %%
sys.argv
# Out:
# ['D:\\ANACONDA\\lib\\site-packages\\ipykernel_launcher.py',
#  '-f',
#  'C:\\Users\\663\\AppData\\Roaming\\jupyter\\runtime\\kernel-d3fe1a48-0ee9-418c-a2a2-38c1e6e72248.json']

# %%
def print_two(*args):
    arg1, arg2 = args
    print(f"arg1: {arg1}, arg2:{arg2}")

# %%
print_two("Chung","Zhong")
# Out:
# arg1: Chung, arg2:Zhong

# %%
print_three("Chung","Zhong","Lee")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-faf66adc4670> in <module>
# ----> 1 print_three("Chung","Zhong","Lee")
#
# NameError: name 'print_three' is not defined

# %%
print_one("First!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5eb219ab39fa> in <module>
# ----> 1 print_one("First!")
#
# NameError: name 'print_one' is not defined

# %%
def print_one(arg1):
    print(f"arg1: {arg1}")

# %%
print_one("Ashura")
# Out:
# arg1: Ashura

# %%
def print_three(*args):
    arg1, arg2, arg3 = args
    print(f"arg1:{arg1},arg2:{arg2},arg3:{arg3}")

# %%
print_three("Zhong","Lee","Yang")
# Out:
# arg1:Zhong,arg2:Lee,arg3:Yang

# %%
def print_none():
    print("ALL BLANK")

# %%
print_none("I have a dream!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-3b4fb73f4d3e> in <module>
# ----> 1 print_none("I have a dream!")
#
# TypeError: print_none() takes 0 positional arguments but 1 was given

# %%
def print_none(*args):
    print("ALL BLANK")

# %%
print_none("I have a dream!")
# Out:
# ALL BLANK

# %%
def dogs_and_cats(dogs_count, cats_count):
    print(f"There are {dogs_count} dogs.")
    print(f"There are {cats_count} cats.")
    print("We have reach the animal kingdom!")
    print("Here cames a lion!")

print("We can just give the function numbers directly:")
dogs_and_cats(8,12)
# Out:
# We can just give the function numbers directly:
# There are 8 dogs.
# There are 12 cats.
# We have reach the animal kingdom!
# Here cames a lion!

# %%
print("OR, we can use variables from our script:")
amount_of_dogs = 8
amount_of_cats = 12
dogs_and_cats(amount_of_dogs,amount_of_cats)
# Out:
# OR, we can use variables from our script:
# There are 8 dogs.
# There are 12 cats.
# We have reach the animal kingdom!
# Here cames a lion!

# %%
print("I don't know if it can do math or not.")
dogs_and_cats(8+10, 12+10)
# Out:
# I don't know if it can do math or not.
# There are 18 dogs.
# There are 22 cats.
# We have reach the animal kingdom!
# Here cames a lion!

# %%
print("Can it combine the two? variables and maths:")
dogs_and_cats(amount_of_dogs+10，amount_of_cats+10)
# Out:
#   File "<ipython-input-66-61f29fa716de>", line 2
#     dogs_and_cats(amount_of_dogs+10，amount_of_cats+10)
#                                                  ^
# SyntaxError: invalid character in identifier

# %%
print("Can it combine the two? variables and maths:")
amount_of_dogs = 6
amount_of_cats = 8
dogs_and_cats(amount_of_dogs+10, amount_of_cats+10)
# Out:
# Can it combine the two? variables and maths:
# There are 16 dogs.
# There are 18 cats.
# We have reach the animal kingdom!
# Here cames a lion!

# %%
filename = '663.txt'
txt = open(filename)

print(f"I have created a file {filename}:")
print(txt.read())
txt.close()
# Out:
# I have created a file 663.txt:
# Chung!
# Bravo!!!!

# %%
filename = '663.txt'
txt = open(filename)

print(f"I have created a file {filename}:")
print(txt.read())
# Out:
# I have created a file 663.txt:
# Chung!
# Bravo!!!!

# %%
target = open('filename', 'w')

line1 = input("line 1: ")
line2 = input("line 2: ")
line3 = input("line 3: ")

target.write(line1)
target.write("\n")
target.write(line2)
target.write("\n")
target.write(line3)
target.write("\n")


target.close()
# Out:
# line 1:  C'est
# line 2:  La
# line 3:  Vie!!

# %%
target = open('663.txt','w')

line1 = input ("line1: ")
line2 = input ("line2: ")
line3 = input ("line3: ")

target.write(line1)
target.write("\000")
target.write(line2)
target.write("\000")
target.write(line3)
target.write("\000")

target.close()
# Out:
# line1:  C'est
# line2:  La
# line3:  Vie!!!

# %%
rewind(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-00d4237f74ea> in <module>
# ----> 1 rewind(file)
#
# NameError: name 'rewind' is not defined

# %%
input_file = 'not a sample.txt'

def print_all(f):
    print(f.read())
    
def rewind(f):
    f.seek(0)
    
def print_a_line(line_count,f):
    print(line_count,f.readline())
    
current_file = open(input_file)

print_all(current_file)
# Out:
# I have bought a new iphone.
# Beacause I like the size of Iphone 12 mini.
# And it's price is affordable for me.
# Anyway, the arrival of my new phone really satisfy me.

# %%
input_file = 'not a sample.txt'

def print_all(f):
    print(f.read())

def print_a_line(line_count, f):
    print(line_count, f.readline())

current_file = open(input_file)


print_all(current_file)


rewind(current_file)


current_line = 2
print_a_line(current_line, current_file)

current_line = current_line + 1
print_a_line(current_line, current_file)

current_line += 1
print_a_line(current_line, current_file)

current_file.close()
# Out:
# I have bought a new iphone.
# Beacause I like the size of Iphone 12 mini.
# And it's price is affordable for me.
# Anyway, the arrival of my new phone really satisfy me.
# 2 I have bought a new iphone.
#
# 3 Beacause I like the size of Iphone 12 mini.
#
# 4 And it's price is affordable for me.

# %%
def add(a, b):   
    print(f"ADDING {a} + {b}")
    return a + b

def subtract(a, b):
    print(f"SUBTRACTING {a} - {b}")
    return a - b

def multiply(a, b):
    print(f"MULTIPLYING {a} * {b}")
    return a * b

def divide(a, b):
    print(f"DIVIDING {a} / {b}")
    return a / b


print("Let's do some math with just functions!")

age = add(30, 5)
height = subtract(78, 4)
weight = multiply(90, 2)
iq = divide(100, 2)

print(f"Age: {age}, Height: {height}, Weight: {weight}, IQ: {iq}")


# A puzzle for the extra credit, type it in anyway.
print("Here is a puzzle.")

what = add(age, subtract(height, multiply(weight, divide(iq, 2))))

print("That becomes: ", what, "Can you do it by hand?")
# Out:
# Let's do some math with just functions!
# ADDING 30 + 5
# SUBTRACTING 78 - 4
# MULTIPLYING 90 * 2
# DIVIDING 100 / 2
# Age: 35, Height: 74, Weight: 180, IQ: 50.0
# Here is a puzzle.
# DIVIDING 50.0 / 2
# MULTIPLYING 180 * 25.0
# SUBTRACTING 74 - 4500.0
# ADDING 35 + -4426.0
# That becomes:  -4391.0 Can you do it by hand?

# %%
def add(a,b):
    print(f"Adding {a} + {b}")
    return a + b

age = add(20,5)
# Out:
# Adding 20 + 5

# %%
print(age)
# Out:
# 25

# %%
def add(a,b):
    print(f"Adding {a} + {b}")
    return a + b

def subtract(a,b):
    print(f"Subtracting {a} + {b}")
    return a - b

def multiply(a,b):
    print(f"Multiplying {a} * {b}")
    return a * b

def divide(a,b):
    print(f"Dividing {a} / {b}")
    return a / b

print("Can these functions really work? Let me see: \n")
age = add(20,5)
height = subtract(180,5)
weight = multiply(31,2)
IQ = divide(400,2.5)

print(f"He's {age} years old, {height}cm tall and {weight}kg.")
# Out:
# Can these functions really work? Let me see:
#
# Adding 20 + 5
# Subtracting 180 + 5
# Multiplying 31 * 2
# Dividing 400 / 2.5
# He's 25 years old, 175cm tall and 62kg.

# %%
what = (add(age,subtract(height,multiply(weight,divide(IQ,2)))))
print("That comes: ", what, "Of course I can do it by hand")
# Out:
# Dividing 160.0 / 2
# Multiplying 62 * 80.0
# Subtracting 175 + 4960.0
# Adding 25 + -4785.0
# That comes:  -4760.0 Of course I can do it by hand

# %%
people = 20
cats = 30
dogs = 15

dogs += 5
cats -= 10
people /= 2

print(dogs,"\n")
print(cats,"\n")
print(people)
# Out:
# 20
#
# 20
#
# 10.0

# %%
people = 20
cats = 30
dogs = 15

if people < cats:
    print("The world will seized by cats")

cats -= 15

if people > cats:
    print("Human race return!!!")
# Out:
# The world will seized by cats
# Human race return!!!

# %%
3 == 3 and (not ("testing" == "testing" or "Python" == "Fun"))
"chunky" == "bacon" and (not (3 == 4 or 3 == 3))
1==1 and (not("testing"==1 or 1==0))
not ("testing" == "testing" and "Zed" == "Cool Guy")
not(1!=10 or 3==4)
not (10 == 1 or 1000 == 1000)
not(1==1 and 0!=1)
not (True and False)
"test" == 1
"test" != "testing"
1!=0 and 2==1
"test" == "testing"
True or 1==1
False and 0!=0
True and 1==1
1==1 or 2!=1
"test" == "test"
1==1 and 2==1
False and True
True and True
# Out:
# True

# %%
3 == 3
# Out:
# True

# %%
4 >= 4
# Out:
# True

# %%
3 == 3 or (not ("testing" == "testing" or "Python" == "Fun"))
# Out:
# True

# %%
1 != 2 and 2 == 2
# Out:
# True

# %%
1 != 2 or 2 == 2
# Out:
# True

# %%
not ("testing" == "testing" and "Python" == "Fun")
# Out:
# True

# %%
"chunky" != "bacon" or (not (3 == 4 or 3 == 3))
# Out:
# True

# %%
not(3!=4)
# Out:
# False

# %%
door = input("<")
# Out:
# < 3

# %%
if door == "2":
    print("WHAT!!")

# %%
cats = 10
dogs = 20
ducks = 30
lambs = 50

if cats > dogs:
    print("Dogs had won the fight!")
elif cats < dogs:
    print("Cats always win the war!")
else:
    print("Ducks never afraid.")
# Out:
# Cats always win the war!

# %%
people = 30
cars = 40
trucks = 15

if cars > people:
    print("We should take the cars.")
elif cars < people:
    print("We should not take the cars.")
else:
    print("We can't decide.")
# Out:
# We should take the cars.

# %%
a = 3
b = 4
if a < b:
    print("Bravo!!!!")
# Out:
# Bravo!!!!

# %%
n = 100
 
sum = 0
counter = 1
while counter <= n:
    sum = sum + counter
    counter += 1
 
print("1 到 %d 之和为: %d" % (n,sum))
# Out:
# 1 到 100 之和为: 5050

# %%
n = 5

sum = 0
counter = 1
while counter <= n:
    sum = sum + counter
    counter += 1
    
print("1 到 %d 的和为%d" %(n,sum))
# Out:
# 1 到 5 的和为15

# %%
def save_grade(name,grade):
    grades = open('Score.txt','a')
    grades.write(f'姓名：{name},  成绩：{grade}\n')
    grades.close()

# %%
while True:
    name = input("请输入姓名：")
    grade = input('请输入成绩：')
    save_grade(name, grade)
    print(f'{name}的成绩已保存。')
    go_on = input('是否继续输入（yes or no）？')
    if go_on == 'yes':
        continue
    elif go_on == 'no':
        break
print('成绩输入结束。')
# Out:
# 请输入姓名： 小黄
# 请输入成绩： 12
# 小黄的成绩已保存。
# 是否继续输入（yes or no）？ yes
# 请输入姓名： 小黑
# 请输入成绩： 34
# 小黑的成绩已保存。
# 是否继续输入（yes or no）？ yes
# 请输入姓名： 小王
# 请输入成绩： 55
# 小王的成绩已保存。
# 是否继续输入（yes or no）？ yes
# 请输入姓名： 小狗
# 请输入成绩： 24
# 小狗的成绩已保存。
# 是否继续输入（yes or no）？ no
# 成绩输入结束。

# %%
while True:
    name = input("Please type the name: ")
    grade = input("Please type the grades: ")
    save_grade(name,grade)
    print(f"{name}'s grade had saved.")
    go_on = input("If you want continue?(yes or no)?")
    if go_on == "yes":
        continue
    elif go_on == "no":
        break
print("Finish!")
# Out:
# Please type the name:  Chung
# Please type the grades:  98
# Chung's grade had saved.
# If you want continue?(yes or no)? yes
# Please type the name:  Lee
# Please type the grades:  96
# Lee's grade had saved.
# If you want continue?(yes or no)? yes
# Please type the name:  Song
# Please type the grades:  100
# Song's grade had saved.
# If you want continue?(yes or no)? yes
# Please type the name:  Maria
# Please type the grades:  99
# Maria's grade had saved.
# If you want continue?(yes or no)? yes
# Please type the name:  Iryle
# Please type the grades:  88
# Iryle's grade had saved.
# If you want continue?(yes or no)? yes
# Please type the name:  Mikasa
# Please type the grades:  999999+
# Mikasa's grade had saved.
# If you want continue?(yes or no)? yes
# Please type the name:  Rain
# Please type the grades:  80
# Rain's grade had saved.
# If you want continue?(yes or no)? no
# Finish!

# %%
the_count = [1, 2, 3, 4, 5]
fruits = ['apples', 'oranges', 'pears', 'apricots']
change = [1, 'pennies', 2, 'dimes', 3, 'quarters']

# this first kind of for-loop goes through a list
for number in the_count:
    print(f"This is count {number}")

# same as above
for fruit in fruits:
    print(f"A fruit of type: {fruit}")

# also we can go through mixed lists too
# notice we have to use {} since we don't know what's in it
for i in change:
    print(f"I got {i}")

# we can also build lists, first start with an empty one
elements = []

# then use the range function to do 0 to 5 counts
for i in range(0, 6):
    print(f"Adding {i} to the list.")
    # append is a function that lists understand
    elements.append(i)

# now we can print them out too
for i in elements:
    print(f"Element was: {i}")
# Out:
# This is count 1
# This is count 2
# This is count 3
# This is count 4
# This is count 5
# A fruit of type: apples
# A fruit of type: oranges
# A fruit of type: pears
# A fruit of type: apricots
# I got 1
# I got pennies
# I got 2
# I got dimes
# I got 3
# I got quarters
# Adding 0 to the list.
# Adding 1 to the list.
# Adding 2 to the list.
# Adding 3 to the list.
# Adding 4 to the list.
# Adding 5 to the list.
# Element was: 0
# Element was: 1
# Element was: 2
# Element was: 3
# Element was: 4
# Element was: 5

# %%
fruits = ['apple','banana','orange','watermelon']

for fruit in fruits:
    print('水果类型： ',fruit)
    
print('Sayolala~~~!!')
# Out:
# 水果类型：  apple
# 水果类型：  banana
# 水果类型：  orange
# 水果类型：  watermelon
# Sayolala~~~!!

# %%
fruits = ['apple','banana','orange','watermelon']
for index in range(len(fruits)):
    print("水果类型：",fruits[index])
    
print("SAYOLALA!!!")
# Out:
# 水果类型： apple
# 水果类型： banana
# 水果类型： orange
# 水果类型： watermelon
# SAYOLALA!!!

# %%
numbers = [1,2,3,4,5]

for number in numbers:
    print("当前数字：",number)
    
print("结束！")
# Out:
# 当前数字： 1
# 当前数字： 2
# 当前数字： 3
# 当前数字： 4
# 当前数字： 5
# 结束！

# %%
numbers = [1,2,3,4,5]
for index in range(len(numbers)):
    print("当前数字：",numbers[index])
    
print("结束咯！！！")
# Out:
# 当前数字： 1
# 当前数字： 2
# 当前数字： 3
# 当前数字： 4
# 当前数字： 5
# 结束咯！！！

# %%
fruits = ['apple','banana','orange','watermelon']

for i in fruits:
    print(f"I got {i}.")
# Out:
# I got apple.
# I got banana.
# I got orange.
# I got watermelon.

# %%
fruits = ['apple','banana','orange','watermelon']

for index in range(len(fruits)):
    print("I got a bottle of ",fruits[index],"juice.")
# Out:
# I got a bottle of  apple juice.
# I got a bottle of  banana juice.
# I got a bottle of  orange juice.
# I got a bottle of  watermelon juice.

# %%
range(0,6)
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
Chung = "thekingofrabbish"
len(Chung)
# Out:
# 16

# %%
numbers = [1,2,3,4,5,6]
range(len(numbers))
# Out:
# range(0, 6)

# %%
list(range(9))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
fruits = ['appke',"banana","orange","coconut","cucumber"]

list(range(len(fruits)))

list(fruits)
# Out:
# ['appke', 'banana', 'orange', 'coconut', 'cucumber']

# %%
for i in range(6):
    print(f"Using {i} to divide another number.")
# Out:
# Using 0 to divide another number.
# Using 1 to divide another number.
# Using 2 to divide another number.
# Using 3 to divide another number.
# Using 4 to divide another number.
# Using 5 to divide another number.

# %%
element = []
for i in elements:
    print(f"Element was：{i}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-b0fc92c2b56c> in <module>
#       1 element = []
# ----> 2 for i in elements:
#       3     print(f"Element was：{i}")
#       4
#
# NameError: name 'elements' is not defined

# %%
def test():
    msg_inner = "I am not a local variable."
msg_inner
# Out:
# 'I am a local variable.'

# %%
a = 10
def test():
    a = a + 1
    print(a)
test()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-57-f07f36273c45> in <module>
#       4     print(a)
#       5     return a
# ----> 6 print(test())
#
# <ipython-input-57-f07f36273c45> in test()
#       1 a = 10
#       2 def test():
# ----> 3     a = a + 1
#       4     print(a)
#       5     return a
#
# UnboundLocalError: local variable 'a' referenced before assignment

# %%
a = 10
def test():
    a = a + 1
    print(a)
test()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-64-4212688e84b0> in <module>
#       3     a = a + 1
#       4     print(a)
# ----> 5 test()
#
# <ipython-input-64-4212688e84b0> in test()
#       1 a = 10
#       2 def test():
# ----> 3     a = a + 1
#       4     print(a)
#       5 test()
#
# UnboundLocalError: local variable 'a' referenced before assignment

# %%
a
# Out:
# 10

# %%
# Out:
#   File "<ipython-input-66-b4dec31a6241>", line 1
#     def test:
#             ^
# SyntaxError: invalid syntax
