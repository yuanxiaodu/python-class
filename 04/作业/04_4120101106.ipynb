# %%
import requests
url = 'https://item.jd.com/100006713417.html'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
# Out:
# 200

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
r.text[:1000]
# Out:
# "<script>window.location.href='https://passport.jd.com/uc/login?ReturnUrl=http%3A%2F%2Fitem.jd.com%2F100006713417.html'</script>"

# %%
import requests
url = 'https://item.jd.com/100006713417.html'
try:
    #r = requests.get(url)
    r.raise_for_status()
    r.encoding = r.apparent_encoding
    r = requests.get(url,timeout = 30)
    print(r.text[:1000])
except:
    print('爬取错误')
# Out:
# <script>window.location.href='https://passport.jd.com/uc/login?ReturnUrl=http%3A%2F%2Fitem.jd.com%2F100006713417.html'</script>

# %%
import requests
def httpjdtext(url):
    try:
        r=requests.get(url)
        r.raise_for_status()#如果状态不是200，则报错
        r.encoding=r.apparent_encoding
        return (r.text[:1000])
    except:
        print("爬取失败")
if __name__=="__main__":
    print(httpjdtext('https://item.jd.com/100004770249.html'))
# Out:
# <script>window.location.href='https://passport.jd.com/uc/login?ReturnUrl=http%3A%2F%2Fitem.jd.com%2F100004770249.html'</script>

# %%
import requests
url = 'https://www.amazon.cn/gp/product/B01M8L5Z3Y'
r = requests.get(url)
r.status_code
# Out:
# 503

# %%
r.encoding
# Out:
# 'ISO-8859-1'

# %%
r.encoding = r.apparent_encoding
r.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]> <html lang="zh-CN" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->\n<!--[if IE 7]>    <html lang="zh-CN" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->\n<!--[if IE 8]>    <html lang="zh-CN" class="a-no-js a-lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="a-no-js" lang="zh-CN"><!--<![endif]--><head>\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title dir="ltr">Amazon.cn</title>\n<meta name="viewport" content="width=device-width">\n<link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css">\n<script>\n\nif (true === true) {\n    var ue_t0 = (+ new Date()),\n        ue_csm = window,\n        ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },\n        ue_furl = "fls-cn.amazon.cn",\n        ue_mid = "
# ...

# %%
r.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
kv = {'user-agent':'Mozilla/5.0'}
r = requests.get(url,headers = kv)
r.status_code
# Out:
# 200

# %%
r.request.headers
# Out:
# {'user-agent': 'Mozilla/5.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
r.text[:1000]
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]> <html lang="zh-CN" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->\n<!--[if IE 7]>    <html lang="zh-CN" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->\n<!--[if IE 8]>    <html lang="zh-CN" class="a-no-js a-lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="a-no-js" lang="zh-CN"><!--<![endif]--><head>\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title dir="ltr">Amazon.cn</title>\n<meta name="viewport" content="width=device-width">\n<link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css">\n<script>\n\nif (true === true) {\n    var ue_t0 = (+ new Date()),\n        ue_csm = window,\n        ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },\n        ue_furl = "fls-cn.amazon.cn",\n        ue_mid = "
# ...

# %%
r.text[1000:2000]
# Out:
# '  ue_sid = (document.cookie.match(/session-id=([0-9-]+)/) || [])[1],\n        ue_sn = "opfcaptcha.amazon.cn",\n        ue_id = \'CKP0Z90B1XKTZF8S1PM0\';\n}\n</script>\n</head>\n<body>\n\n<!--\n        To discuss automated access to Amazon data please contact api-services-support@amazon.com.\n        For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.com.cn/index.html/ref=rm_c_sv, or our Product Advertising API at https://associates.amazon.cn/gp/advertising/api/detail/main.html/ref=rm_c_ac for advertising use cases.\n-->\n\n<!--\nCorreios.DoNotSend\n-->\n\n<div class="a-container a-padding-double-large" style="min-width:350px;padding:44px 0 !important">\n\n    <div class="a-row a-spacing-double-large" style="width: 350px; margin: 0 auto">\n\n        <div class="a-row a-spacing-medium a-text-center"><i class="a-icon a-logo"></i></div>\n\n        <div class="a-box a-alert a-alert-info a-spacing-base">\n            <div class="a
# ...

# %%
import requests
url = 'http://www.baidu.com/s'
keyword = 'Python'
try:
    kv = {'wd':keyword}
    r = requests.get(url,params = kv)
    print(r.request.url)
    r.raise_for_status()
    print(len(r.text))
except:
    print('爬虫失败')
# Out:
# http://www.baidu.com/s?wd=Python
# 630590

# %%
import requests
kv = {'q':'python'}
r = requests.get( 'http://www.so.com/s',params = kv)
r.status_code
r.encoding
print(r.request.url)
# Out:
# https://www.so.com/s?q=python

# %%
import requests
path = "F:/a.jpg"
url = "http://img0.dili360.com/ga/M00/48/F7/wKgBy1llvmCAAQOVADC36j6n9bw622.tub.jpg"
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
with open(path,'wb') as f:
    f.write(r.content)
    f.close()

# %%
import requests
import os
def httpimg(url):
    root='F://py项目//'
    path=root+url.split('/')[-1]
    try:
        if not os.path.exists(root):
            os.mkdir(root)
        if not os.path.exists(path):
            r=requests.get(url)
            r.raise_for_status()
            with open(path,'wb') as f:
                f.write(r.content)
                f.close()
                print('文件保存成功')
        else:
            print('文件已存在')
    except:
        print('爬取失败')
if __name__=="__main__":
    url=input()
    print(httpimg(url))
# Out:
# https://image.baidu.com/search/detail?ct=503316480&z=0&ipn=d&word=%E5%9B%BE%E7%89%87&step_word=&hs=0&pn=1&spn=0&di=8030&pi=0&rn=1&tn=baiduimagedetail&is=0%2C0&istype=2&ie=utf-8&oe=utf-8&in=&cl=2&lm=-1&st=-1&cs=2583035764%2C1571388243&os=2836418179%2C2424634836&simid=3454139158%2C448793287&adpicid=0&lpn=0&ln=1255&fr=&fmq=1608025198686_R&fm=result&ic=&s=undefined&hd=&latest=&copyright=&se=&sme=&tab=0&width=&height=&face=undefined&ist=&jit=&cg=&bdtype=0&oriquery=&objurl=http%3A%2F%2Fimg.aiimg.com%2Fuploads%2Fuserup%2F0909%2F2Z64022L38.jpg&fromurl=ippr_z2C%24qAzdH3FAzdH3Fooo_z%26e3Bwtt42_z%26e3Bv54AzdH3Frf1AzdH3FdaalalAzdH3F08ma_z%26e3Bip4s&gsm=2&rpstart=0&rpnum=0&islist=&querylist=&force=undefined
# 爬取失败
# None

# %%
print(url.split('/')[-1])
print(url.split("/"))
print(url)
# Out:
# wKgBy1llvmCAAQOVADC36j6n9bw622.tub.jpg
# ['http:', '', 'img0.dili360.com', 'ga', 'M00', '48', 'F7', 'wKgBy1llvmCAAQOVADC36j6n9bw622.tub.jpg']
# http://img0.dili360.com/ga/M00/48/F7/wKgBy1llvmCAAQOVADC36j6n9bw622.tub.jpg

# %%
import requests
def httpid(url):
    try:
        kv={'user-agent':'Mozilla/5.0'}
        r=requests.get(url,headers=kv)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        return (r.text[-500:])
    except:
        print("爬取失败")
if __name__=="__main__":
    a=input()
    url='https://m.ip138.com/iplookup.asp?ip='+a
    print(httpid(url))
# Out:
# 202.204.80.112
# hmt = _hmt || [];
# 		(function() {
# 		var hm = document.createElement("script");
# 		hm.src = "https://hm.baidu.com/hm.js?4513768e33b6903827b5a4ff6fef7639";
# 		var s = document.getElementsByTagName("script")[0];
# 		s.parentNode.insertBefore(hm, s);
# 		})();
# 		</script>
# 		<script>
# 		(function(){
# 		var src = "https://jspassport.ssl.qhimg.com/11.0.1.js?d182b3f28525f2db83acfaaf6e696dba";
# 		document.write('<script src="' + src + '" id="sozz"><\/script>');
# 		})();
# 		</script>
# 	</body>
# </html>

# %%
import requests
import bs4
from bs4 import BeautifulSoup
soup = BeautifulSoup(demo,"html.parser")
soup.title
# Out:
# <title>This is a python demo page</title>

# %%
import requests
r = requests.get("https://python123.io/ws/demo.html")
r.text
demo = r.text
print(demo+'\n\n')
from bs4 import BeautifulSoup
soup = BeautifulSoup(demo,"html.parser")
print(soup.prettify())
# Out:
# <html><head><title>This is a python demo page</title></head>
# <body>
# <p class="title"><b>The demo python introduces several python courses.</b></p>
# <p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# <a href="http://www.icourse163.org/course/BIT-268001" class="py1" id="link1">Basic Python</a> and <a href="http://www.icourse163.org/course/BIT-1001870001" class="py2" id="link2">Advanced Python</a>.</p>
# </body></html>
#
#
# <html>
#  <head>
#   <title>
#    This is a python demo page
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The demo python introduces several python courses.
#    </b>
#   </p>
#   <p class="course">
#    Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# ...

# %%
soup = BeautifulSoup('<p>data</p>','html.parser')
print(soup)
# Out:
# <p>data</p>

# %%
soup = BeautifulSoup(demo,"html.parser")
soup.title
# Out:
# <title>This is a python demo page</title>

# %%
tag = soup.a
tag
# Out:
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>

# %%
soup.a.name
# Out:
# 'a'

# %%
soup.a.parent.name
# Out:
# 'p'

# %%
soup.a.parent.parent.name
# Out:
# 'body'

# %%
soup.p.parent.name
# Out:
# 'body'

# %%
soup.body.parent.name
# Out:
# 'html'

# %%
tag.attrs
# Out:
# {'href': 'http://www.icourse163.org/course/BIT-268001',
#  'class': ['py1'],
#  'id': 'link1'}

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag.attrs['class']
# Out:
# ['py1']

# %%
soup.a
# Out:
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>

# %%
soup.a.string
# Out:
# 'Basic Python'

# %%
# %%cmd
# you-get https://www.bilibili.com/video/BV1FV411d7u7
# #you-get --debug https://stallman.org/rms.jpg
# Out:
# Microsoft Windows [版本 10.0.18363.1198]
# (c) 2019 Microsoft Corporation。保留所有权利。
#
# (base) C:\Users\Administrator\Desktop\python-class-main\04>you-get https://www.bilibili.com/video/BV1FV411d7u7
# site:                Bilibili
# title:               bilibili鐚�缁欐柊涓�浠ｇ殑婕旇�层�婂悗娴�銆� (P1. bilibili鐚�缁欐柊涓�浠ｇ殑婕旇�层�婂悗娴�銆�)
# stream:
#     - format:        flv
#       container:     flv
#       quality:       楂樻竻 1080P
#       size:          50.0 MiB (52415560 bytes)
#     # download-with: you-get --format=flv [URL]
#
# ...
#  100% ( 50.0/ 50.0MB) 鈹溾枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚枅鈻堚敜[1/1]  621 kB/s
#
# ...
#
#
# (base) C:\Users\Administrator\Desktop\python-class-main\04>#you-get --debug https://stallman.org/rms.jpg
#
# (base) C:\Users\Administrator\Desktop\python-class-main\04>
# you-get: This is a multipart video. (use --playlist to download all parts.)
# '#you-get' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
import altair as alt
from vega_datasets import data

source = alt.topo_feature(data.world_110m.url, 'countries')

base = alt.Chart(source).mark_geoshape(
    fill='#166266',
    stroke='red'
).properties(
    width=300,
    height=300
)

projections = ['equirectangular', 'mercator', 'orthographic', 'gnomonic']
charts = [base.project(proj).properties(title=proj)
          for proj in projections]

alt.concat(*charts, columns=2)
# Out:
# alt.ConcatChart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.cars()

alt.Chart(source).mark_circle(size=20).encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive()
# Out:
# alt.Chart(...)

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts.charts import Bar
from pyecharts import options as opts
# 内置主题类型可查看 pyecharts.globals.ThemeType
from pyecharts.globals import ThemeType

bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .add_yaxis("商家B", [15, 6, 45, 20, 35, 66])
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
)
bar.load_javascript()
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="c9a41ca402934fd7987367a0575524f8" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_c9a41ca402934fd7987367a0575524f8 = echarts.init(
#             document.getElementById('c9a41ca402934fd7987367a0575524f8'), 'light', {renderer: 'canvas'});
#         var option_c9a41ca402934fd7987367a0575524f8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
# ...

# %%
import face_recognition
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

image = face_recognition.load_image_file("akb48.jpeg")
face_locations = face_recognition.face_locations(image)

im=np.array(Image.open('akb48.jpeg'), dtype=np.uint8)

fig, ax = plt.subplots(1, figsize=(8, 8))
ax.imshow(im)

for face_loc in face_locations:
    rect = patches.Rectangle((face_loc[1], face_loc[0]), face_loc[3] - face_loc[1], face_loc[2] - face_loc[0], linewidth=2,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c1cc2d269f51> in <module>
# ----> 1 import face_recognition
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.patches as patches
#       4 from PIL import Image
#       5 import numpy as np
#
# C:\ProgramData\Anaconda3\lib\site-packages\face_recognition\__init__.py in <module>
#       5 __version__ = '1.2.3'
#       6
# ----> 7 from .api import load_image_file, face_locations, batch_face_locations, face_landmarks, face_encodings, compare_faces, face_distance
#
# C:\ProgramData\Anaconda3\lib\site-packages\face_recognition\api.py in <module>
#       2
#       3 import PIL.Image
# ----> 4 import dlib
#       5 import numpy as np
#       6 from PIL import ImageFile
#
# ModuleNotFoundError: No module named 'dlib'

# %%
import pandas as pd
import jieba

# 显示所有列
pd.set_option('display.max_columns', None)
# 显示所有行
pd.set_option('display.max_rows', None)
# 设置value的显示长度为100，默认为50
pd.set_option('max_colwidth', 100)
    
tweets = pd.read_csv('weibo_hashtag/weibo/#进击的巨人最终季#/#进击的巨人最终季#.csv', usecols=['正文'])
tweets['jieba分词'] = tweets.apply(lambda x: ';'.join(jieba.cut(x['正文'])), axis=1)
tweets
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\Administrator\AppData\Local\Temp\jieba.cache
# Loading model cost 0.716 seconds.
# Prefix dict has been built successfully.
#                                                                                                      正文  \
# 0                以你的心诠释我的爱今日开机，进击的巨人第四季全集12集都有了！！！ 幸福来得太突然了吧嘎嘎嘎 #进击的巨人##进击的巨人最终季# 。想看先 ！！！ ，来丝我！！！ ！！！
# 1   看完巨人最终季熟肉觉得真的超出预期了，也逐渐适应了新制作的画风，一直都维持水平，巨人第四季全集绝对可以封神了#进击的巨人# 看平仑区 #进击的巨人最终季# #进击的巨人 第四季# ！！快来丝我...
# 2                                                                        #进击的巨人最终季#制作不减当年啊，还是神仙打架凡人看戏。
# 3                                        #进击的巨人##进击的巨人最终季# 好家伙巨人最终季第一集看完了 艾伦兵长一个都没出现 就那个飞机下巨人雨经费已经在燃烧了
# 4                                                                               #进击的巨人最终季# 草草草，第一集太炸裂了
# 5                                       #进击的巨人最终季#终于来了，等了太久了。。。看动漫慢慢拾回看漫画内容的记忆。。。话说我漫画也忘了追到哪了，反正比动漫要快。
# ...

# %%
import requests
import bs4
from bs4 import BeautifulSoup

def gethttptext(url):
    try:
        r=requests.get(url,timeout=30)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        return r.text
    except:
        return ""

def fillunivlist(ulist,html):
    soup=BeautifulSoup(html,'html.parser')
    for tr in soup.find('tbody').children:
        if isinstance(tr,bs4.element.Tag):
            tds=tr('td')
            tda=tr('a')
            ulist.append([tds[0].get_text("",strip="true"),tda[0].string,tds[4].get_text("",strip="true")])

def printunivlist(ulist,num):
    tplt="{0:^10}\t{1:{3}^10}\t{2:^10}"
    print(tplt.format("排名","学校名称","总分",chr(12288)))
    for i in range(num):
        u=ulist[i]
        if u[2]!=None:
            print(tplt.format(u[0],u[1],u[2],chr(12288)))

def main():
    uinfo=[]
    url='http://www.shanghairanking.cn/rankings/bcur/2020'
    html=gethttptext(url)
    fillunivlist(uinfo,html)
    printunivlist(uinfo,100)

main()
# Out:
#     排名    	　　　学校名称　　　	    总分
#     1     	　　　清华大学　　　	  852.5
#     2     	　　　北京大学　　　	  746.7
#     3     	　　　浙江大学　　　	  649.2
#     4     	　　上海交通大学　　	  625.9
#     5     	　　　南京大学　　　	  566.1
#     6     	　　　复旦大学　　　	  556.7
#     7     	　中国科学技术大学　	  526.4
#     8     	　　华中科技大学　　	  497.7
#     9     	　　　武汉大学　　　	   488
#     10    	　　　中山大学　　　	  457.2
#     11    	　　西安交通大学　　	  452.5
#     12    	　哈尔滨工业大学　　	  450.2
#     13    	　北京航空航天大学　	  445.1
#     14    	　　北京师范大学　　	  440.9
#     15    	　　　同济大学　　　	   439
#     16    	　　　四川大学　　　	  435.7
#     17    	　　　东南大学　　　	  432.7
#     18    	　　中国人民大学　　	  409.7
#     19    	　　　南开大学　　　	  402.1
#     20    	　　北京理工大学　　	  395.6
#     21    	　　　天津大学　　　	  390.3
#     22    	　　　山东大学　　　	  387.9
#     23    	　　　厦门大学　　　	  383.3
#     24    	　　　吉林大学　　　	  379.5
#     25    	　　华南理工大学　　	  379.4
#     26    	　　　中南大学　　　	  378.6
#     27    	　　大连理工大学　　	  365.1
#     28    	　　西北工业大学　　	  359.6
#     29    	　　华东师范大学　　	   358
#     30    	　　中国农业大学　　	  351.5
# ...

# %%
import requests
import re
def gethttptext(url):
    try:
        kv = {
            
            'user-agent':'Mozilla/5.0','cookie':'__wpkreporterwid_=43e9b815-7f92-40df-1a53-01a825e56097; ctoken=Ke4tQL7LIBIhxYjFcp8D7oBi; lego2_cna=PPXPDMDUXPE1PDHWYHDDDXTT; _m_h5_tk=25d7101fb38f17dc8c6520f11a72187e_1608134204027; _m_h5_tk_enc=93d73d6f7cbaf4e4ae67ac964eca8f93; cna=kL/kF0zT1TcCAcrI7Na/TEcN; xlly_s=1; _samesite_flag_=true; cookie2=1b41849575dccacc942ca903124b99fb; t=9533ae98f06d8f87b08e8ca10ab624df; _tb_token_=e043ee573eee3; sgcookie=E100ThDrzASgIZ0kEGkGZ2Qb3HGqTIugDXxCmdBsvKxjHXgYSJRKpywirFEJ8bC7cfn76C%2F3gCWm7wAo%2BTWzTjFVNw%3D%3D; unb=2972447621; uc3=lg2=W5iHLLyFOGW7aA%3D%3D&vt3=F8dCuAJz9W5bdcKhQQo%3D&id2=UUGlTGOVDVpWRw%3D%3D&nk2=F6k3HMo8dBg885hZyfp%2F2VUrLtA%3D; csg=c21dbf29; lgc=t_1486632275443_0122; cookie17=UUGlTGOVDVpWRw%3D%3D; dnk=t_1486632275443_0122; skt=138ffc8cf6328a25; existShop=MTYwODEyNDUxNQ%3D%3D; uc4=nk4=0%40FbMocpyM2uQXj6XEvD6d23Ly7yVCIPhPAW57R7zhPQ%3D%3D&id4=0%40U2OSW31Hkv6qQmLGuioDUiV9gCEb; tracknick=t_1486632275443_0122; _cc_=V32FPkk%2Fhw%3D%3D; _l_g_=Ug%3D%3D; sg=21a; _nk_=t_1486632275443_0122; cookie1=BxY8%2BuQoTSRdK%2BI%2FM%2BNzPGa%2BbvM%2FGc4koRLG9bLMFFc%3D; mt=ci=25_1; uc1=cookie21=V32FPkk%2FgihF%2FS5nr3O5&existShop=false&pas=0&cookie15=URm48syIIVrSKA%3D%3D&cookie16=UIHiLt3xCS3yM2h4eKHS9lpEOw%3D%3D&cookie14=Uoe0ZeMK6crPCQ%3D%3D; thw=cn; tfstk=cpYABRY3UYDmu5CJTnnufAhal5GhweHOFS6gWXWnklIlGT10BeYpxenf1-Q-w; l=eBxtwYrVOV2r4MXEXOfanurza77OSIRYYuPzaNbMiOCP_ufB5YRGWZJw3hT6C3GVhsd6R3SxXm92BeYBq7VonxvtNSVsr4Dmn; isg=BKys-Vz436UKncuZvpmGLoVmfYreZVAPj4FqEgbtudf6EUwbLnW5nZIjNdmpmYhn'
        }
        r=requests.get(url,headers=kv,timeout=30)
        r.raise_for_status()
        r.encoding=r.apparent_encoding
        return r.text
    except:
        print("提取失败")
        return ""

def parsepage(ilt,html):
    try:
        plt = re.findall(r'\"view_price\"\:\"[\d\.]*\"', html)
        tlt = re.findall(r'\"raw_title\"\:\".*?\"', html)
        # print(tlt)
        print(len(plt))
        for i in range(len(plt)):
            price = eval(plt[i].split(':')[1])
            title = eval(tlt[i].split(':')[1])
            ilt.append([title, price])
        # print(ilist)
    except:
        print("解析出错")

def printgoodslist(ilt):
    tplt="{:4}\t{:8}\t{:16}"
    print(tplt.format("序号","价格","商品名称"))
    count=0
    for g in ilt:
        count=count+1
        print(tplt.format(count,g[0],g[1]))

if __name__=="__main__":
    goods='玫瑰花'
    depth=2
    start_url='https://s.taobao.com/search?q='+goods
    infolist=[]
    for i in range(depth):
        try:
            url=start_url+'&s='+str(44*i)
            html=gethttptext(url)
            parsepage(infolist,html)
        except:
            continue
    printgoodslist(infolist)
# Out:
# 48
# 44
# 序号  	价格      	商品名称
#    1	平阴玫瑰花冠茶30g袋装食用大朵无硫花冠王	58.00
#    2	SEEROSE进口永生花苔藓玫瑰小熊礼盒摆件圣诞情人节表白女友礼物	349.00
#    3	同仁堂玫瑰花养生茶花草茶泡水玫瑰80克甘肃苦水食用玫瑰花	45.00
#    4	白梅花玫瑰花茶各三克红特级和干花药材泡水中药组合正品共30小包	49.80
#    5	2020新货50g白梅花花苞干花中药材绿萼梅不熏硫白梅花茶干玫瑰花	48.80
#    6	鲜花速递同城配送生日玫瑰花束礼盒花店送花北京上海深圳杭州广州	98.00
#    7	白梅花玫瑰花茶中药材白梅花和红玫瑰花茶组合泡水干花正品各三克	58.80
#    8	艺福堂菊博士胎菊特级桐乡菊花茶叶杭白菊搭决明子枸杞玫瑰金银花	24.90
#    9	白梅花玫瑰花茶组合泡茶干花正品和红玫瑰花绿鄂梅非特级和各三克	22.80
#   10	手提花篮生日玫瑰鲜花速递北京上海广州深圳杭州武汉成都同城配送	168.00
#   11	99朵红玫瑰花束鲜花速递生日北京上海广州深圳成都杭州西安同城送	148.00
#   12	红枣桂圆黑枸杞茶姜丝玫瑰花菊花养生茶女人调理补气血组合花茶	29.90
#   13	ROSEONLY玫瑰公仔 告白气球熊永生玫瑰花礼盒 送女友爱人节日礼物	1799.00
#   14	Rose永生花独角兽玫瑰花礼盒送老婆男女友生日闺蜜结婚圣诞节礼物	135.00
#   15	玫瑰花茶金边玫瑰花茶云南野生无硫干玫瑰500g散装特级花蕾泡水喝	39.90
#   16	鲜花速递同城配送生日玫瑰花束礼盒花店送花北京上海深圳杭州南京	98.00
#   17	红枣桂圆枸杞茶玫瑰菊花五宝气血调理补气养血女人花茶组合养生茶	39.90
#   18	999朵520/365朵红玫瑰花束生日北京鲜花速递同城广州上海杭州武汉	258.00
#   19	买1送1玫瑰花茶干玫瑰干花泡茶花茶重瓣玫瑰花瓣食用泡水茶叶	19.00
#   20	鲜花速递同城99朵红玫瑰花束圣诞节北京上海广州深圳杭州店配送花	188.00
#   21	JANE永生花玫瑰花熊音乐旋转告白小熊圣诞节情人节礼物生日送女友	299.00
# ...

# %%
import os
import sqlite3
import requests
from win32.win32crypt import CryptUnprotectData
 
def getcookiefromchrome(host='.oschina.net'):
  cookiepath=os.environ['LOCALAPPDATA']+r"\Google\Chrome\User Data\Default\Cookies"
  sql="select host_key,name,encrypted_value from cookies where host_key='%s'" % host
  with sqlite3.connect(cookiepath) as conn:
    cu=conn.cursor()   
    cookies={name:CryptUnprotectData(encrypted_value)[1].decode() for host_key,name,encrypted_value in cu.execute(sql).fetchall()}
    print(cookies)
    return cookies
 
#运行环境windows 2012 server python3.4 x64 chrome 50
#以下是测试代码
#getcookiefromchrome()
#getcookiefromchrome('.baidu.com')
 
url='http://my.oschina.net/'
 
httphead={'User-Agent':'Safari/537.36',}
 
#设置allow_redirects为真，访问http://my.oschina.net/ 可以跟随跳转到个人空间
r=requests.get(url,headers=httphead,cookies=getcookiefromchrome('.oschina.net'),allow_redirects=1)
print(r.text)
# Out:
# {}
#
#
# <!DOCTYPE html>
# <html lang="zh">
# <head>
#     <meta charset="utf-8"/>
#     <meta http-equiv="Content-Language" content="zh-CN">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>
#     <meta name="referrer" content="always"/>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0"/>
#             <title>OSCHINA - 中文开源技术交流社区</title>
#             <meta name="keywords" content="开源,OSC,开源软件,开源硬件,开源网站,开源社区,java开源,perl开源,python开源,ruby开源,php开源,开源项目,开源代码"/>
#                 <meta name="description" content="OSCHINA.NET 是目前领先的中文开源技术社区。我们传播开源的理念，推广开源项目，为 IT 开发者提供了一个发现、使用、并交流开源技术的平台"/>
#         <link rel="stylesheet" type="text/css" href="https://static.oschina.net/new-osc/js/utils/semantic-ui/semantic.min.css?t=1585021363000"/>
# ...
