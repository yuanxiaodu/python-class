# %%
                                                                                                                                                                                                                                                    # This is a sample Python script.

# Press Shift+F10 to execute it or replace it with your code.
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.


def print_hi(name):
    # Use a breakpoint in the code line below to debug your script.
    print(f'Hi, {name}')  # Press Ctrl+F8 to toggle the breakpoint.


# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    print_hi('PyCharm')

# See PyCharm help at https://www.jetbrains.com/help/pycharm/
import  requests
import  json
import  time
import  pandas as pd

target_id="6130942571%26"
vid="%3Dt0034o74jpr"
df=pd.DataFrame()
for page in range(15,3214,30):
    headers={"User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"}
    url="https://mfm.video.qq.com/danmu?otype=json&timestamp={0}&target_id={1}vid{2}&count=80".format(page,target_id,vid)
    print("正在提取第"+str(page)+"页")
    html=requests.get(url,headers=headers)
    bs=json.loads(html.text,strict=False)
    time.sleep(1)

    for i in bs["comments"]:
        content=i["content"]
        upcount=i["upcount"]
        user_degree=i["uservip_degree"]
        timepoint=i["timepoint"]
        comment_id=i["commentid"]
        opername=i["opername"]
        cache=pd.DataFrame({"弹幕":[content],"会员等级":[user_degree],"发布时间":[timepoint],"弹幕点赞":[upcount],"弹幕id":[comment_id],"用户昵称":[opername]})
        df = pd.concat([df,cache])
    df.to_csv("面试篇.csv",encoding="utf-8")
# Out:
# Hi, PyCharm
# 正在提取第15页
# 正在提取第45页
# 正在提取第75页
# 正在提取第105页
# 正在提取第135页
# 正在提取第165页
# 正在提取第195页
# 正在提取第225页
# 正在提取第255页
# 正在提取第285页
# 正在提取第315页
# 正在提取第345页
# 正在提取第375页
# 正在提取第405页
# 正在提取第435页
# 正在提取第465页
# 正在提取第495页
# 正在提取第525页
# 正在提取第555页
# 正在提取第585页
# 正在提取第615页
# 正在提取第645页
# 正在提取第675页
# 正在提取第705页
# 正在提取第735页
# 正在提取第765页
# 正在提取第795页
# 正在提取第825页
# 正在提取第855页
# 正在提取第885页
# 正在提取第915页
# 正在提取第945页
# 正在提取第975页
# 正在提取第1005页
# 正在提取第1035页
# 正在提取第1065页
# 正在提取第1095页
# 正在提取第1125页
# 正在提取第1155页
# 正在提取第1185页
# 正在提取第1215页
# 正在提取第1245页
# 正在提取第1275页
# 正在提取第1305页
# 正在提取第1335页
# 正在提取第1365页
# 正在提取第1395页
# 正在提取第1425页
# 正在提取第1455页
# 正在提取第1485页
# 正在提取第1515页
# 正在提取第1545页
# 正在提取第1575页
# 正在提取第1605页
# 正在提取第1635页
# 正在提取第1665页
# 正在提取第1695页
# 正在提取第1725页
# 正在提取第1755页
# 正在提取第1785页
# 正在提取第1815页
# 正在提取第1845页
# 正在提取第1875页
# 正在提取第1905页
# 正在提取第1935页
# 正在提取第1965页
# 正在提取第1995页
# 正在提取第2025页
# 正在提取第2055页
# 正在提取第2085页
# 正在提取第2115页
# 正在提取第2145页
# 正在提取第2175页
# 正在提取第2205页
# 正在提取第2235页
# 正在提取第2265页
# 正在提取第2295页
# 正在提取第2325页
# ...

# %%
from pyecharts.globals import CurrentConfig, NotebookType  
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("C:/Users/lenovo/douban/douban/面试篇.csv")
df1["期数"] = "面试篇"
df2 = pd.read_csv("C:/Users/lenovo/douban/douban/第八期.csv")
df2["期数"] = "第八期"
df3 = pd.read_csv("C:/Users/lenovo/douban/douban/第十期.csv")
df3["期数"] = "第十期"
df = pd.concat([df1,df2,df3])
df.sample(100)
# Out:
#        Unnamed: 0                 弹幕  会员等级  发布时间  弹幕点赞                 弹幕id  \
# 21195           0              哇哇哇好帅     0  7833     0  6750404355929862395
# 7298            0              摔伤了？？     0  2608     0  6751846570624484543
# 9202            0              反应挺快的     0  1445     4  6732918585142256207
# 3336            0       骁哥和晋晔   肯定的呀     2  4212     0  6752946090958583771
# 17588           0       总感觉煜成有点大男子主义     0  5950     0  6750582653771251535
# ...           ...                ...   ...   ...   ...                  ...
# 5253            0  咸鱼 : 应该是算合租吧 不是转租     5  1808     1  6750614408109689452
# 17999           0               央视要他     0  2932     1  6735790840607160452
# 445             0                撒撒勒     0   137     0  6750030136310165731
# 387             0       又可以开始追爱看的综艺啦     0    45     1  6729729843471612902
# 15249           0         面试永远不能实话实说     0  2484     1  6734789240557119446
#
#           用户昵称   期数
# 21195      翛 然  第八期
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46194 entries, 0 to 5708
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  46194 non-null  int64
#  1   弹幕          46194 non-null  object
#  2   会员等级        46194 non-null  int64
#  3   发布时间        46194 non-null  int64
#  4   弹幕点赞        46194 non-null  int64
#  5   弹幕id        46194 non-null  int64
#  6   用户昵称        17341 non-null  object
#  7   期数          46194 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 3.2+ MB

# %%
df.rename(columns={'用户昵称':'用户昵称','弹幕':'弹幕内容','发布时间':'发送时间','弹幕点赞':'弹幕点赞','期数':'所属期数',"会员等级":"会员等级"})
# Out:
#       Unnamed: 0                 弹幕内容  会员等级  发送时间  弹幕点赞                 弹幕id  \
# 0              0                   第一     3     7     1  6729722427573023767
# 1              0                深深我来了     3     8    19  6729722167279688122
# 2              0                   来啦     3     6     0  6729721814806180098
# 3              0         就喜欢你这个不准时的样子     5     5    22  6729722910517785568
# 4              0        好不准时呀，我好喜欢！！！     0     5    18  6729720700446734386
# ...          ...                  ...   ...   ...   ...                  ...
# 5704           0          咸鱼 : 哈哈哈哈       3  8625     0  6753220874570541421
# 5705           0  就这样结束了，因为丁辉才注意到这个节目     2  8697     0  6753184140663132876
# 5706           0                   拜拜     4  8736     0  6752983409699782933
# 5707           0               杨天真真厉害     4  8745     0  6753039043007072615
# 5708           0                   秋怡     2  8776     0  6753147735919572089
#
#           用户昵称 所属期数
# 0        Chico  面试篇
# ...

# %%
df.sample(100)
# Out:
#        Unnamed: 0                         弹幕  会员等级  发布时间  弹幕点赞  \
# 17640           0           撒贝宁应该说曾经主持过春晚啊。。     0  2872     3
# 10017           0                     ？？骚话真多     0  3528     6
# 5698            0                      期待很东西     1  8576     0
# 6559            0              可是女人是前一个会过的幸福     0   968     0
# 3758            0               咸鱼 : 秋怡改变超大的     1  5212     1
# ...           ...                        ...   ...   ...   ...
# 462             0                  咸鱼 : 花钱花钱     3   143     0
# 21371           0      我盲猜，三个李晋烨，詹秋怡，刘煜诚/何旻哲     3  7984     0
# 2119            0                    秋怡的英文真秀     5  1301     2
# 5843            0  23岁研究生毕业？？？wsl，22岁的我本科刚毕业     3   851    15
# 5631            0                       好好看啊     0   817     3
#
#                       弹幕id     用户昵称   期数
# 17640  6729844856403980388      NaN  面试篇
# 10017  6750049943639541105  我要努力学民法  第八期
# 5698   6752962469644761341       安仔  第十期
# 6559   6732722612829976887     意云拉姆  面试篇
# ...

# %%
def time_change(seconds):
    m, s = divmod(seconds, 60)
    h, m = divmod(m, 60)
    ss_time = "%d:%02d:%02d" % (h, m, s)
    print(ss_time)
    return ss_time
time_change(seconds=8888)
# Out:
# 2:28:08
# '2:28:08'

# %%
df["发布时间"] = df["发布时间"].apply(time_change)
# Out:
# 0:00:07
# 0:00:08
# 0:00:06
# 0:00:05
# 0:00:05
# 0:00:07
# 0:00:07
# 0:00:09
# 0:00:08
# 0:00:09
# 0:00:05
# 0:00:09
# 0:00:08
# 0:00:05
# 0:00:08
# 0:00:05
# 0:00:07
# 0:00:07
# 0:00:09
# 0:00:07
# 0:00:06
# 0:00:07
# 0:00:07
# 0:00:05
# 0:00:09
# 0:00:05
# 0:00:08
# 0:00:06
# 0:00:08
# 0:00:09
# 0:00:05
# 0:00:06
# 0:00:09
# 0:00:08
# 0:00:09
# 0:00:08
# 0:00:06
# 0:00:06
# 0:00:06
# 0:00:06
# 0:00:11
# 0:00:14
# 0:00:13
# 0:00:14
# 0:00:13
# 0:00:10
# 0:00:10
# 0:00:13
# 0:00:10
# 0:00:10
# 0:00:12
# 0:00:13
# 0:00:13
# 0:00:14
# 0:00:10
# 0:00:11
# 0:00:13
# 0:00:12
# 0:00:13
# 0:00:13
# 0:00:10
# 0:00:14
# 0:00:14
# 0:00:11
# 0:00:14
# 0:00:12
# 0:00:14
# 0:00:14
# 0:00:12
# 0:00:10
# 0:00:12
# 0:00:11
# 0:00:11
# 0:00:10
# 0:00:12
# 0:00:11
# 0:00:12
# 0:00:12
# 0:00:11
# 0:00:11
# 0:00:29
# 0:00:26
# 0:00:27
# 0:00:29
# 0:00:27
# 0:00:27
# 0:00:26
# 0:00:26
# 0:00:29
# 0:00:27
# 0:00:25
# 0:00:25
# 0:00:27
# 0:00:25
# 0:00:27
# 0:00:25
# 0:00:29
# 0:00:26
# 0:00:26
# 0:00:28
# ...

# %%
df["发布时间"]=pd.to_datetime(df["发布时间"])
df["发布时间"]=df["发布时间"].apply(lambda x:x.strftime('%H:%M:%S'))

# %%
df["弹幕"] = df["弹幕"].astype("str")

# %%
def yasuo(st):
    for i in range(1,int(len(st)/2)+1):
        for j in range(len(st)):
            if st[j:j+i] == st[j+i:j+2*i]:
                k = j + i
                while st[k:k+i] == st[k+i:k+2*i] and k<len(st):   
                    k = k + i
                st = st[:j] + st[k:]    
    return st
yasuo(st="Python真的真的真的很难很难")
# Out:
# 'Python真的很难'

# %%
df["弹幕"] = df["弹幕"].apply(yasuo)

# %%
df['弹幕'] = df['弹幕'].str.extract(r"([\u4e00-\u9fa5]+)")
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17191 entries, 0 to 5703
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  17191 non-null  int64
#  1   弹幕          17191 non-null  object
#  2   会员等级        17191 non-null  int64
#  3   发布时间        17191 non-null  object
#  4   弹幕点赞        17191 non-null  int64
#  5   弹幕id        17191 non-null  int64
#  6   用户昵称        17191 non-null  object
#  7   期数          17191 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 1.2+ MB

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
from pyecharts.charts import Bar
import pyecharts.options as opts
from pyecharts.charts import *
from pyecharts.globals import ThemeType  
import matplotlib.pyplot as plt

# %%
df7 = df["期数"].value_counts()
print(df7.index.to_list())
print(df7.to_list())

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add_xaxis(df7.index.to_list())
    .add_yaxis("",df7.to_list()) 
    .set_global_opts(title_opts=opts.TitleOpts(title="各期弹幕数量",subtitle="数据来源：腾讯视频 \t制图：张帆",pos_left = 'left'),
                       xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=13)), #更改横坐标字体大小
                       yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=13)), #更改纵坐标字体大小
                       )
    .set_series_opts(label_opts=opts.LabelOpts(font_size=16,position='top'))
    )
c.load_javascript()
# Out:
# ['第八期', '面试篇', '第十期']
# [7982, 6977, 2232]

# %%
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="94a71fa17c2d43dea52c5056756cbb19" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_94a71fa17c2d43dea52c5056756cbb19 = echarts.init(
#             document.getElementById('94a71fa17c2d43dea52c5056756cbb19'), 'dark', {renderer: 'canvas'});
#         var option_94a71fa17c2d43dea52c5056756cbb19 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 7982,
#                 6977,
#                 2232
#             ],
#             "showBackground": false,
# ...

# %%
df8 = df["用户昵称"].value_counts()[1:11]
df8 = df8.sort_values(ascending=True)
df8 = df8.tail(10)
print(df8.index.to_list())
print(df8.to_list())
c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add_xaxis(df8.index.to_list())
    .add_yaxis("",df8.to_list()).reversal_axis() #X轴与y轴调换顺序
    .set_global_opts(title_opts=opts.TitleOpts(title="弹幕发送数量TOP10",subtitle="数据来源：腾讯视频 \t制图：张帆",pos_left = 'left'),
                       xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=13)), #更改横坐标字体大小
                       yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=13)), #更改纵坐标字体大小
                       )
    .set_series_opts(label_opts=opts.LabelOpts(font_size=16,position='right'))
    )
c.render_notebook()
# Out:
# ['星洲泛泛.', '圣雪天使', '中行个贷部信贷专员   吉恒', '.', '为时不晚i', '来自黄土地的一粒沙子', 'ベ☆小强呐', '。', '白龙吟', 'Angela-J🔥']
# [41, 45, 45, 55, 62, 66, 69, 76, 78, 92]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="35e080516d01495d9935224a962d7a1b" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_35e080516d01495d9935224a962d7a1b = echarts.init(
#             document.getElementById('35e080516d01495d9935224a962d7a1b'), 'dark', {renderer: 'canvas'});
#         var option_35e080516d01495d9935224a962d7a1b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
# ...

# %%
df[df["用户昵称"]=="Angela-J🔥"].sample(90)
# Out:
#        Unnamed: 0               弹幕  会员等级      发布时间  弹幕点赞                 弹幕id  \
# 5816            0       这说啥了就让人受不了     0  00:34:03     0  6750629799174274613
# 5061            0              所草组     3  00:28:25     0  6750627202137784347
# 17796           0          资助我家多好啊     0  01:41:12     2  6750649677911361384
# 3603            0               加油     3  00:16:47     0  6750624229127344112
# 7320            0      养了十几年养了个白眼狼     0  00:43:19     3  6750631520101760396
# ...           ...              ...   ...       ...   ...                  ...
# 4940            0        居然有点喜欢王骁了     3  00:26:38     4  6750626754806877413
# 5709            0               咸鱼     3  00:33:03     1  6750629538101184194
# 854             0          因为有丁辉存在     0  00:05:16     0  6750621708483836442
# 3420            0           我也是台州的     0  00:15:37     0  6750623933768650233
# 7377            0  不可能回来看见没收拾家就扔东西     0  00:43:32     0  6750631576394203370
#
#             用户昵称   期数
# ...

# %%
df2 = df["会员等级"].astype("str").value_counts()
print(df2)
df2 = df2.sort_values(ascending=False)
regions = df2.index.to_list()
values = df2.to_list()
c = (
        Pie(init_opts=opts.InitOpts(theme=ThemeType.DARK))
        .add("", list(zip(regions,values)))
        .set_global_opts(legend_opts = opts.LegendOpts(is_show = False),title_opts=opts.TitleOpts(title="会员等级分布",subtitle="数据来源：腾讯视频\t制图：张帆",pos_top="0.5%",pos_left = 'left'))
        .set_series_opts(label_opts=opts.LabelOpts(formatter="等级{b}占比:{d}%",font_size=14))
        
    )
c.render_notebook()
# Out:
# 0    11605
# 1     1416
# 3     1219
# 2     1060
# 4      946
# 5      472
# 6      409
# 7       62
# 8        2
# Name: 会员等级, dtype: int64
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="6791d87360e34157ac59152ee037e4d5" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_6791d87360e34157ac59152ee037e4d5 = echarts.init(
#             document.getElementById('6791d87360e34157ac59152ee037e4d5'), 'dark', {renderer: 'canvas'});
#         var option_6791d87360e34157ac59152ee037e4d5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
# ...

# %%
import numpy as np
import pandas as pd
import glob
import re
import jieba 

#可视化库
import stylecloud
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
from pyecharts.charts import *
from pyecharts import options as opts 
from pyecharts.globals import ThemeType  
from IPython.display import Image 

# 定义分词函数

def get_cut_words(content_series):
    stop_words = []
    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())
    # 添加关键词
    my_words = ['撒老师', '范丞丞','第一季']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['好像', '真的','感觉']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected

# 绘制词云图
text1 = get_cut_words(content_series=df['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text1), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-square',
                          size=653,
                          #palette='matplotlib.Inferno_9',
                          output_name='./offer.jpg')
Image(filename='./offer.jpg')
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 1.464 seconds.
# Prefix dict has been built successfully.

# %%
tmp=[]
for i in df["弹幕"]:
    if "王骁" in i:
        tmp.append("王骁")
    elif "丁辉" in i:
        tmp.append("丁辉")
    elif "一暄" in i:
        tmp.append("朱一暄")
    elif "晋晔" in i:
        tmp.append("李晋晔")
    elif "泽林" in i:
        tmp.append("瞿泽林")
    elif "颖飞" in i:
        tmp.append("王颖飞")
    elif "秋怡" in i:
        tmp.append("詹秋怡")
    elif "煜成" in i:
        tmp.append("刘煜成") 
    elif "南希" in i:
        tmp.append("赵南希")
    elif "旻哲" in i:
        tmp.append("何旻哲")
    else:
        tmp.append("其他")
df['人物提及'] = tmp

# %%
df8 = df["人物提及"].value_counts()[1:11]
print(df8.index.to_list())
print(df8.to_list())
c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add_xaxis(df8.index.to_list())
    .add_yaxis("",df8.to_list()) 
    .set_global_opts(title_opts=opts.TitleOpts(title="人物提及次数",subtitle="数据来源：腾讯视频 \t制图：菜J学Python",pos_left = 'left'),
                       xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=13)), #更改横坐标字体大小
                       yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=13)), #更改纵坐标字体大小
                       )
    .set_series_opts(label_opts=opts.LabelOpts(font_size=16,position='top'))
    )
c.render_notebook()
# Out:
# ['赵南希', '詹秋怡', '王骁', '丁辉', '王颖飞', '李晋晔', '刘煜成', '朱一暄', '何旻哲', '瞿泽林']
# [208, 157, 132, 67, 65, 55, 55, 21, 12, 4]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="51ad47af729441b488e386f2a6986d2a" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_51ad47af729441b488e386f2a6986d2a = echarts.init(
#             document.getElementById('51ad47af729441b488e386f2a6986d2a'), 'dark', {renderer: 'canvas'});
#         var option_51ad47af729441b488e386f2a6986d2a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 208,
# ...

# %%
import paddlehub as hub
#这里使用了百度开源的成熟NLP模型来预测情感倾向
senta = hub.Module(name="senta_bilstm")
texts = df['弹幕'].tolist()
input_data = {'text':texts}
res = senta.sentiment_classify(data=input_data)
df['情感分值'] = [x['positive_probs'] for x in res]
#重采样至15分钟
df.index = df['发布时间']
data = df.resample('15min').mean().reset_index()
# Out:
# [2021-01-21 15:29:10,262] [    INFO] - Installing senta_bilstm module
# [2021-01-21 15:29:10,321] [    INFO] - Module senta_bilstm already installed in C:\Users\lenovo\.paddlehub\modules\senta_bilstm
# [2021-01-21 15:29:18,127] [    INFO] - Installing lac module
# [2021-01-21 15:29:18,264] [    INFO] - Module lac already installed in C:\Users\lenovo\.paddlehub\modules\lac

# %%
import seaborn as sns
color_map = sns.light_palette('orange', as_cmap=True)  #light_palette调色板
data.style.background_gradient(color_map)
# Out:
# <style  type="text/css" >
#     #T_807c666e_5bba_11eb_b746_aa02e9724cf0row0_col1 {
#             background-color:  #f3f0ee;
#             color:  #000000;
#         }    #T_807c666e_5bba_11eb_b746_aa02e9724cf0row0_col2 {
#             background-color:  #f3f0ee;
#             color:  #000000;
#         }    #T_807c666e_5bba_11eb_b746_aa02e9724cf0row0_col3 {
#             background-color:  #fbc158;
#             color:  #000000;
#         }    #T_807c666e_5bba_11eb_b746_aa02e9724cf0row0_col4 {
#             background-color:  #f5e6cd;
#             color:  #000000;
#         }    #T_807c666e_5bba_11eb_b746_aa02e9724cf0row0_col5 {
#             background-color:  #fcbb44;
#             color:  #000000;
#         }    #T_807c666e_5bba_11eb_b746_aa02e9724cf0row1_col1 {
#             background-color:  #f3f0ee;
#             color:  #000000;
#         }    #T_807c666e_5bba_11eb_b746_aa02e9724cf0row1_col2 {
#             background-color:  #f4e8d3;
#             color:  #000000;
# ...

# %%
c = (
        Line(init_opts=opts.InitOpts(theme=ThemeType.DARK))
       .add_xaxis(data["发布时间"].to_list())
       .add_yaxis('情感倾向', list(data["情感分值"].round(2)), is_smooth=True,is_connect_nones=True,areastyle_opts=opts.AreaStyleOpts(opacity=0.5))
       .set_global_opts(title_opts=opts.TitleOpts(title="情感倾向",subtitle="数据来源：腾讯视频 \t制图：张帆",pos_left = 'left'))
    )
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5c96c61da86b4c55991b2168b8159d7f" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_5c96c61da86b4c55991b2168b8159d7f = echarts.init(
#             document.getElementById('5c96c61da86b4c55991b2168b8159d7f'), 'dark', {renderer: 'canvas'});
#         var option_5c96c61da86b4c55991b2168b8159d7f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "\u60c5\u611f\u503e\u5411",
#             "connectNulls": true,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
# ...

# %%
df.head()
# Out:
#                      Unnamed: 0    弹幕  会员等级                发布时间  弹幕点赞  \
# 发布时间
# 2021-01-21 00:00:07           0    第一     3 2021-01-21 00:00:07     1
# 2021-01-21 00:00:08           0  深我来了     3 2021-01-21 00:00:08    19
# 2021-01-21 00:00:09           0   我来啦     3 2021-01-21 00:00:09     8
# 2021-01-21 00:00:08           0    来了     0 2021-01-21 00:00:08     6
# 2021-01-21 00:00:07           0    范丞     0 2021-01-21 00:00:07     4
#
#                                     弹幕id      用户昵称   期数 人物提及    情感分值
# 发布时间
# 2021-01-21 00:00:07  6729722427573023767     Chico  面试篇   其他  0.6786
# 2021-01-21 00:00:08  6729722167279688122  柯琳妮尔一指私密  面试篇   其他  0.7624
# 2021-01-21 00:00:09  6729723914807126335   糯米酱吃肉肉🍳  面试篇   其他  0.8098
# 2021-01-21 00:00:08  6729723906480078016    Wewewe  面试篇   其他  0.5754
# 2021-01-21 00:00:07  6729754105642161605       Fcc  面试篇   其他  0.6104

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="丁辉"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="赵南希"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="詹秋怡"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="王骁"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="李晋晔"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="朱一暄"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="何旻哲"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="王颖飞"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="刘煜成"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [] 

    with open("C:/Users/lenovo/douban/douban/stop_words.txt", 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['', '']  
    
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['感觉', '确实']   
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected
dinghui = df[df["人物提及"]=="瞿泽林"]
text = get_cut_words(content_series=dinghui['弹幕'])
stylecloud.gen_stylecloud(text=' '.join(text), max_words=100,
                          collocations=False,
                          font_path='字体圈欣意吉祥宋.ttf',
                          icon_name='fas fa-heart',
                          #palette='matplotlib.Inferno_9',
                          size=653,
                          output_name='./dinghui.png')
Image(filename='./dinghui.png')
