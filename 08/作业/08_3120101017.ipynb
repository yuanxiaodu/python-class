# %%
'''
readme
main.py中启动了爬虫爬取了数据并将数据存储于data.json中
post_p.py中对data.json数据进行了后处理并做了数据可视化
'''

# %%
# %run main.py
# Out:
# 2021-01-21 10:50:42 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: spider_2)
# 2021-01-21 10:50:42 [scrapy.utils.log] INFO: Versions: lxml 4.5.2.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.8.3 (default, Jul  2 2020, 17:30:36) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.9.2, Platform Windows-10-10.0.18362-SP0
# 2021-01-21 10:50:42 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-01-21 10:50:42 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'spider_2',
#  'NEWSPIDER_MODULE': 'spider_2.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['spider_2.spiders']}
# 2021-01-21 10:50:43 [scrapy.extensions.telnet] INFO: Telnet Password: a5932c6c7ef2633f
# 2021-01-21 10:50:43 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...

# %%
# %run post_p.py
# Out:
# 2021-01-21 10:51:19 [matplotlib] DEBUG: CONFIGDIR=C:\Users\XJ\.matplotlib
# 2021-01-21 10:51:19 [matplotlib] DEBUG: (private) matplotlib data path: F:\Software_work\anaconda3\envs\common\lib\site-packages\matplotlib\mpl-data
# 2021-01-21 10:51:19 [matplotlib] DEBUG: matplotlib data path: F:\Software_work\anaconda3\envs\common\lib\site-packages\matplotlib\mpl-data
# 2021-01-21 10:51:19 [matplotlib] DEBUG: loaded rc file F:\Software_work\anaconda3\envs\common\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 2021-01-21 10:51:19 [matplotlib] DEBUG: matplotlib version 3.2.2
# 2021-01-21 10:51:19 [matplotlib] DEBUG: interactive is False
# 2021-01-21 10:51:19 [matplotlib] DEBUG: platform is win32
# ...
