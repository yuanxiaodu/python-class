# %%
import turtle
import time
import math as m
class Sheep(object):

    def __init__(self,xsize):
        self.t = turtle.Turtle()
        self.xsize = xsize
        t = self.t
        # 画笔设置
        t.screen.screensize(canvwidth=1000,canvheight=500,bg='white')
        t.pensize(2)
        t.speed(10)
        # t.hideturtle()
        #初始化画笔位置
        t.penup()
        t.setpos(self.xsize,0)
        t.pendown()

    # 设置画笔坐标
    def setxy(self,x,y):
        t = self.t
        t.penup()
        pos_x = t.position()[0]
        pos_y = t.position()[1]
        t.setpos(pos_x + x,pos_y + y)
        t.pendown()

    def create_sheep(self):
        t = self.t
        #输出文字
        printer = turtle.Turtle()
        printer.hideturtle()
        printer.penup()
        printer.back(200)
        printer.write("-----第一次python作业    \n\n", align="left", font=("楷体", 16, "bold"))
        printer.write("        两只羊\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("           from 陈曦", align="center", font=("楷体", 12, "normal"))

        # 羊头
        self.setxy(-200,0)
        t.fillcolor('black')
        t.begin_fill()
        t.circle(100)
        t.end_fill()

        # 眼睛
        # 眼白
        print(t.position())
        self.setxy(-20,120)

        t.fillcolor('white')
        t.begin_fill()
        t.seth(45)
        t.circle(18,-280)
        t.seth(45)
        t.circle(-20,292)
        t.end_fill()
        # 眼珠
        self.setxy(3,12)
        t.fillcolor('black')
        t.begin_fill()
        t.seth(85)
        t.circle(10)
        t.seth(85)
        t.circle(-10)
        t.end_fill()
        # 眼心
        t.fillcolor('white')
        t.begin_fill()
        t.seth(85)
        t.circle(3)
        t.seth(85)
        t.circle(-3)
        t.end_fill()

        # 嘴
        self.setxy(0,-100)
        t.color('red')
        t.seth(300)
        t.forward(8)
        self.setxy(-1, 3)
        t.seth(0)
        t.circle(80,60)
        self.setxy(2, -2)
        t.seth(145)
        t.forward(8)
        t.color('black')

        # 耳朵
        self.setxy(-145,120)
        p1 = t.position()
        t.fillcolor('black')
        t.begin_fill()
        t.seth(0)
        t.circle(-120,20)
        p2 = t.position()
        t.setpos(p1)
        t.seth(60)
        t.circle(-30,120)
        t.goto(p2)
        t.end_fill()

        # 身体
        self.setxy(41,12)
        t.seth(45)
        t.circle(-150,100)
        t.pensize(5)
        t.seth(0)
        t.circle(-120,30)
        t.seth(60)
        t.circle(-15,320)
        t.seth(330)
        t.circle(-80,180)
        t.seth(210)
        t.circle(-80,90)

        #4条腿
        t.pensize(2)
        for leg in range(4):
            self.setxy(8+15*leg,0)
            t.seth(270)
            t.forward(80)
            t.seth(0)
            t.forward(8)
            t.seth(90)
            t.forward(80)

        #草
        self.setxy(-200,-80)
        p3 = t.position()
        t.color('green')
        t.fillcolor('green')
        t.begin_fill()
        t.seth(120)
        t.forward(10)
        t.seth(330)
        t.forward(20)
        t.seth(60)
        t.forward(30)
        t.seth(60)
        t.forward(40)
        t.seth(260)
        t.forward(45)
        t.setpos(p3)
        t.end_fill()
        #meaningless count
        printer.write(" 1\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 2\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 3\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("4\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("5\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("6\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("7\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("8\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("9\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("10\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("11\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("12\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("13\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("14\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("15\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("16\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("17\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("18\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("19\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("20\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 1\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 2\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 3\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("4\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("5\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("6\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("7\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("8\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("9\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("10\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("11\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("12\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("13\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("14\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("15\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("16\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("17\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("18\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("19\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("20\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 1\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 2\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write(" 3\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("4\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("5\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("6\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("7\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("8\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("9\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("10\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("11\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("12\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("13\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("14\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("15\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("16\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("17\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("18\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("19\n\n", align="right", font=("楷体", 16, "bold"))
        printer.write("20\n\n", align="right", font=("楷体", 16, "bold"))

if __name__ == '__main__':
    print("this is my first homework")
    for x in (0,350):
        sheep = Sheep(x)
        sheep.create_sheep()
    time.sleep(5)
# Out:
# this is my first homework
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-1-7d4d021877b4> in <module>
#     211     for x in (0,350):
#     212         sheep = Sheep(x)
# --> 213         sheep.create_sheep()
#     214     time.sleep(5)
#
# <ipython-input-1-7d4d021877b4> in create_sheep(self)
#      42         t.fillcolor('black')
#      43         t.begin_fill()
# ---> 44         t.circle(100)
#      45         t.end_fill()
#      46
#
# ~/opt/anaconda3/lib/python3.7/turtle.py in circle(self, radius, extent, steps)
#    1988         self._rotate(w2)
#    1989         for i in range(steps):
# -> 1990             self.speed(speed)
#    1991             self._go(l)
#    1992             self.speed(0)
#
# ~/opt/anaconda3/lib/python3.7/turtle.py in speed(self, speed)
#    2172         else:
#    2173             speed = 0
# -> 2174         self.pen(speed=speed)
#    2175
#    2176     def color(self, *args):
#
# ~/opt/anaconda3/lib/python3.7/turtle.py in pen(self, pen, **pendict)
#    2457             self._shapetrafo = ( scx*ca, scy*(shf*ca + sa),
#    2458                                 -scx*sa, scy*(ca - shf*sa))
# -> 2459         self._update()
#    2460
#    2461 ## three dummy methods to be implemented by child class:
#
# ~/opt/anaconda3/lib/python3.7/turtle.py in _update(self)
#    2658             return
#    2659         elif screen._tracing == 1:
# -> 2660             self._update_data()
#    2661             self._drawturtle()
#    2662             screen._update()                  # TurtleScreenBase
#
# ~/opt/anaconda3/lib/python3.7/turtle.py in _update_data(self)
#    2644
#    2645     def _update_data(self):
# -> 2646         self.screen._incrementudc()
#    2647         if self.screen._updatecounter != 0:
#    2648             return
#
# ~/opt/anaconda3/lib/python3.7/turtle.py in _incrementudc(self)
#    1290         if not TurtleScreen._RUNNING:
#    1291             TurtleScreen._RUNNING = True
# -> 1292             raise Terminator
#    1293         if self._tracing > 0:
#    1294             self._updatecounter += 1
#
# Terminator:
