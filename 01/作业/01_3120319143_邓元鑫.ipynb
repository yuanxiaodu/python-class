# %%
a,b=1,2
c=a+b
c
# Out:
# 3

# %%
1+2
# Out:
# 3

# %%
num1=15/3
print(num1)
# Out:
# 5.0

# %%
T=True
F=False
print(T,F)
# Out:
# True False

# %%
T=True
print(T+10)
# Out:
# 11

# %%
F=bool(0)
print(F)
# Out:
# False

# %%
print(1>2)
# Out:
# False

# %%
T=True
F=False
#F=bool(0)
print(T or F)
print(T and F)
print(not F)
# Out:
# True
# False
# True

# %%
print(1>2 and 2<1)
# Out:
# False

# %%
coml=15.0j
print(type(coml))
# Out:
# <class 'complex'>

# %%
coml=15.j
print(complex(1))
print(complex("3+5j"))
print(complex(3,2))
print(complex())
print(coml)
# Out:
# (1+0j)
# (3+5j)
# (3+2j)
# 0j
# 15j

# %%
str1="hello world"
str2="I am fine, and you?"

print=("str1原文: ", str1)
print=("str2原文: ", str2)

print("1.str1[1]: ", str1[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e3bf1d2c868e> in <module>
#       5 print=("str2原文: ", str2)
#       6
# ----> 7 print("1.str1[1]: ", str1[1])
#
# TypeError: 'tuple' object is not callable

# %%
strl="hello"
str2="python"
str3="!"
strjoin1=str1+" "+str2+" "+str3
print("1.+拼接: ", strjoin1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-90eaf0cc3f25> in <module>
#       3 str3="!"
#       4 strjoin1=str1+" "+str2+" "+str3
# ----> 5 print("1.+拼接: ", strjoin1)
#
# TypeError: 'tuple' object is not callable

# %%
str="Runoob"

print(str)
print(str[0;2])
print(str[0])
print(str[2;5])
print(str[2;])
print(str[1;5;2])
print(str*2)
print(str+"你好")
# Out:
#   File "<ipython-input-34-af7d687a6b34>", line 4
#     print(str[0;2])
#                ^
# SyntaxError: invalid syntax

# %%
z="s"
u="t"

print(z)
print(u)

print('------------')

print( z, end=" ")
print( u, end=" ")
print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-42c18c10e2aa> in <module>
#       2 u="t"
#       3
# ----> 4 print(z)
#       5 print(u)
#       6
#
# TypeError: 'tuple' object is not callable

# %%
counter = 100          
miles   = 1000.0        
name    = "runoob"      

print (counter)
print (miles)
print (name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-5be2a8ab4729> in <module>
#       3 name    = "runoob"
#       4
# ----> 5 print (counter)
#       6 print (miles)
#       7 print (name)
#
# TypeError: 'tuple' object is not callable

# %%
tup=4,5,6
tup
# Out:
# (4, 5, 6)

# %%
(3, 'hello','hi')+(1,2)+('python',)
# Out:
# (3, 'hello', 'hi', 1, 2, 'python')

# %%
b
# Out:
# 2

# %%
a
# Out:
# 1

# %%
c
# Out:
# 3

# %%
a=[3,1,5,2,9]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 3, 5, 9]

# %%
print("I love you")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-3b46fafedcb2> in <module>
# ----> 1 print("I love you")
#
# TypeError: 'tuple' object is not callable

# %%
counter = 100          # 整型变量
miles   = 1000.0       # 浮点型变量
name    = "runoob"     # 字符串

# %%
counter
# Out:
# 100

# %%
miles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8bc0a7e54fe4> in <module>
# ----> 1 miles
#
# NameError: name 'miles' is not defined

# %%
a=b=c=1

# %%
a
# Out:
# 1

# %%
b
# Out:
# 1

# %%
c
# Out:
# 1

# %%
print("Hens", 25 + 42 / 6)
# Out:
# Hens 32.0

# %%
5+2+8-9+6%2-2/6+9
# Out:
# 14.666666666666668

# %%
print("That is OK", 6>2)
# Out:
# That is OK True

# %%
7>=4
# Out:
# True

# %%
6>6
# Out:
# False

# %%
7>=7
# Out:
# True

# %%
3+8<10+4
# Out:
# True

# %%
a,b=7,8

# %%
c=a+b

# %%
c
# Out:
# 15

# %%
my_name="Damon"
my_age=25#not a lie
my_height=67#inches
my_weight=181#lbs

print(f"Let's talk about {my_name}.")
print(f"He's {my_height} inches tall.")
print(f"He's {my_weight} pounds heavy.")

# this line is tricky, try to get it exactly right
total = my_age + my_height + my_weight
print(f"If I add {my_age}, {my_height}, and {my_weight} I get {total}.")
# Out:
# Let's talk about Damon.
# He's 67 inches tall.
# He's 181 pounds heavy.
# If I add 25, 67, and 181 I get 273.

# %%
formatter = "{} {} {} {}"

print(formatter.format(1, 2, 3, 4))
print(formatter.format("one", "two", "three", "four"))
print(formatter.format(True, False, False, True))
print(formatter.format(formatter, formatter, formatter, formatter))
print(formatter.format(
    "I had this thing.",
    "That you could type up right.",
    "But it didn't sing.",
    "So I said goodnight."
))
# Out:
# 1 2 3 4
# one two three four
# True False False True
# {} {} {} {} {} {} {} {} {} {} {} {} {} {} {} {}
# I had this thing. That you could type up right. But it didn't sing. So I said goodnight.

# %%
print("How old are you?", end=' ')
age = input()
print("How tall are you?", end=' ')
height = input()
print("How much do you weigh?", end=' ')
weight = input()

print(f"So, you're {age} old, {height} tall and {weight} heavy.")
# Out:
# How old are you? 25
# How tall are you? 181
# How much do you weigh? 67
# So, you're 25 old, 181 tall and 67 heavy.

# %%
# Here's some new strange stuff, remember type it exactly.

days = "Mon Tue Wed Thu Fri Sat Sun"
months = "Jan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug"

print("Here are the days: ", days)
print("Here are the months: ", months)

print("""
There's something going on here.
With the three double-quotes.
We'll be able to type as much as we like.
Even 4 lines if we want, or 5, or 6.
""")
# Out:
# Here are the days:  Mon Tue Wed Thu Fri Sat Sun
# Here are the months:  Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug
#
# There's something going on here.
# With the three double-quotes.
# We'll be able to type as much as we like.
# Even 4 lines if we want, or 5, or 6.

# %%
tabby_cat = "\tI'm tabbed in."
persian_cat = "I'm split\non a line."
backslash_cat = "I'm \\ a \\ cat."

fat_cat = """
I'll do a list:
\t* Cat food
\t* Fishies
\t* Catnip\n\t* Grass
"""

print(tabby_cat)
print(persian_cat)
print(backslash_cat)
print(fat_cat)
# Out:
# 	I'm tabbed in.
# I'm split
# on a line.
# I'm \ a \ cat.
#
# I'll do a list:
# 	* Cat food
# 	* Fishies
# 	* Catnip
# 	* Grass
