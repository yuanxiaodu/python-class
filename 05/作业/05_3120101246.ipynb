# %%
import tkinter.messagebox as msgbox
from PIL import ImageTk,Image
import webbrowser
#创建窗口
import tkinter as tk

forml=tk.Tk()
forml.title("公子羽的空间")
forml.geometry("600x500+700+200")
forml.wm_resizable(False,False)
#添加背景图片
canvas=tk.Canvas(forml,width=700,height=600,bd=0,highlightthickness=0)
imgpath='./1.gif'
img=Image.open(imgpath)
photo=ImageTk.PhotoImage(img)
canvas.create_image(250,150,image=photo)
canvas.pack()

imgpath1='./2.jpeg'#子窗口画布背景
img1=Image.open(imgpath1)
img1=img1.resize((972,762))
photo1=ImageTk.PhotoImage(img1)

a='childeyu126'
b='1leiting1!'
#定义函数

def del_thing():
    lblname.place_forget()
    entryName.place_forget()
    lblpass.place_forget()
    entryPass.place_forget()
    btnOk.place_forget()
    btnReset.place_forget()
def quit12():
    forml.destroy()
def btnOk_Click():
    if entryName.get()=="0913" and entryPass.get()=="0913":
        forml2=tk.Toplevel()
        forml2.title("更改设置")
        forml2.geometry("972x762+400+200")
        forml2.wm_resizable(False,False)
        canvas1=tk.Canvas(forml2,width=972,height=762,bg='blue')
        canvas1.create_image(0,0,image=photo1,anchor='nw')
        canvas1.pack()
        def btnOk1_Click():
            global a,b
            a=entryName1.get()
            b=entryPass1.get()
            msgbox.showinfo("O的K","更改成功！")
            forml2.destroy()
            btnReset_Click()
            return a,b
        lblname1=tk.Label(forml2,text="更改用户名")
        lblname1.place(x=15,y=20,width=90,height=25)
        varName1=tk.StringVar()
        entryName1=tk.Entry(forml2,textvariable=varName1)
        entryName1.place(x=130,y=20,width=200,height=25)
        lblpass1=tk.Label(forml2,text="更改密码")
        lblpass1.place(x=15,y=75,width=90,height=25)
        varPass1=tk.StringVar()
        entryPass1=tk.Entry(forml2,textvariable=varPass1)
        entryPass1.place(x=130,y=75,width=200,height=25)
        btnOk1=tk.Button(forml2,text="确定更改",activebackground='Light green',command=btnOk1_Click,width=8)
        btnOk1.place(x=145,y=135,width=80,height=25)
        n0=tk.Entry(forml2)
        forml2.mainloop()
        
    elif entryName.get()==a and entryPass.get()==b:
        del_thing()
        webbrowser.open("https://www.bilibili.com/")
        btnquit=tk.Button(forml,text="退出",width=3,height=2,command=quit12)
        btnquit.place(x=250,y=350,width=80,height=25)
                
    else:
        msgbox.showinfo("消息","用户名或密码错误")
        varPass.set("")
        varName.set("")
        
def btnReset_Click():
    varPass.set("")
    varName.set("")
    
forml.attributes("-alpha",0.95)

#创建用户名标签
lblname=tk.Label(forml,text="用户名")
lblname.place(x=150,y=200,width=80,height=25)
#创建当前输入行
varName=tk.StringVar()
entryName=tk.Entry(forml,textvariable=varName)
entryName.place(x=300,y=200,width=200,height=25)

#创建密码标签
lblpass=tk.Label(forml,text="密码")
lblpass.place(x=150,y=250,width=80,height=25)
#创建当前输入行
varPass=tk.StringVar()
entryPass=tk.Entry(forml,textvariable=varPass,show="*")
entryPass.place(x=300,y=250,width=200,height=25)

#创建按钮
btnOk=tk.Button(forml,text="登入",activebackground='Light green',command=btnOk_Click,width=8)
btnOk.place(x=150,y=350,width=80,height=25)
btnReset=tk.Button(forml,text="重置",activebackground='blue',command=btnReset_Click,width=8)
btnReset.place(x=350,y=350,width=80,height=25)

forml.mainloop()
print("登录界面")
# Out:
# 登录界面

# %%
from tkinter import *
from tkinter import messagebox


class zhuce(Frame):
    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.pack()
        self.createWidget()

    def createWidget(self):
        self.label01 = Label(self, text='用户名')
        self.label01.grid(row=0, column=0)

        v1 = StringVar()  # 用户名输入
        self.entry01 = Entry(self, textvariable=v1)
        self.entry01.grid(row=0, column=1, columnspan=2)

        self.label02 = Label(self, text='密码')
        self.label02.grid(row=1, column=0)

        v2 = StringVar()  # 密码输入
        self.entry02 = Entry(self, textvariable=v2, show='*')
        self.entry02.grid(row=1, column=1, columnspan=2)

        self.label03 = Label(self, text='确认密码')
        self.label03.grid(row=2, column=0)

        v2 = StringVar()  # 确认密码输入
        self.entry03 = Entry(self, textvariable=v2, show='*')
        self.entry03.grid(row=2, column=1, columnspan=2)

        Button(self, text='确定', command=self.login1) \
            .grid(row=3, column=1, padx=10, sticky=NSEW)
        Button(self, text='取消', command=self.cancel) \
            .grid(row=3, column=2, sticky=NSEW)

    def login1(self):
        pass

    def cancel(self):
        pass


class Applicantion(Frame):

    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.pack()
        self.createWidget()

    def createWidget(self):
        self.label01 = Label(self, text='用户名')
        self.label01.grid(row=0, column=0)

        v1 = StringVar()  # 用户名输入
        self.entry01 = Entry(self, textvariable=v1)
        self.entry01.grid(row=0, column=1,columnspan=2)

        self.label02 = Label(self, text='密码')
        self.label02.grid(row=1, column=0)

        v2 = StringVar()  # 密码输入
        self.entry02 = Entry(self, textvariable=v2, show='*')
        self.entry02.grid(row=1, column=1, columnspan=2)

        # 登录 注册 按钮事件绑定
        Button(self, text='登录', command=self.login)\
            .grid(row=2, column=1, padx=10, sticky=NSEW)
        Button(self, text='注册', command=self.set)\
            .grid(row=2, column=2, sticky=NSEW)

    def login(self):  # 登录事件
        username = self.entry01.get()
        pwd = self.entry02.get()

        if username == '123' and pwd == '123456':
            messagebox.showinfo('登录系统', '登录成功')
        else:
            messagebox.showinfo('登录系统', '登录失败，用户名或密码错误')

    def set(self):  # 注册事件
        root1 = Tk()
        root1.geometry('300x100+210+310')
        root1.title('注册系统')
        table = zhuce(master=root1)
        root1.mainloop()


if __name__ == '__main__':
    root = Tk()
    root.geometry('300x100+200+300')
    root.title('用户登录系统')
    app = Applicantion(master=root)
    root.mainloop()
print("登录界面")
# Out:
# 登录界面
