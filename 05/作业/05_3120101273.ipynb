# %% [markdown]
# # you-get

# %%
you-get 'https://www.bilibili.com/video/BV1FV411d7u7'
# Out:
#   File "<ipython-input-17-d25be266dbc1>", line 1
#     you-get 'https://www.bilibili.com/video/BV1FV411d7u7'
#                                                         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
grads = pd.read_excel(r'D:\desktop\python\python-class-main\01\成绩.xlsx',index_col="id")
grads
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120105068      7.0           7.0            6.0    225.0     19.0
# 3120301259     21.0          21.0           20.0    163.0     25.0
# 3120332023     37.0          37.0           35.0    164.0     28.0
# 3120132004     37.0          37.0           36.0    171.0     26.0
# 3120118053    104.0         104.0          101.0    203.0     22.0
# ...             ...           ...            ...      ...      ...
# 3120132011     37.0          37.0           35.0    172.0     27.0
# 3120305403      NaN           NaN            NaN      NaN      3.0
# 3120109017     37.0          30.0           19.0    112.0     12.0
# 20118038        NaN           NaN            NaN      NaN     38.0
# 3120303087     99.0          97.0           94.0    126.0     33.0
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120105068          19.0           18.0    298.0     14.0          14.0
# 3120301259          24.0           22.0    162.0     27.0          26.0
# 3120332023          28.0           27.0    376.0     94.0          94.0
# 3120132004          26.0           25.0    368.0     57.0          57.0
# 3120118053          22.0           20.0    264.0     67.0          67.0
# ...                  ...            ...      ...      ...           ...
# 3120132011          25.0           24.0    351.0     94.0          94.0
# 3120305403           3.0            2.0     73.0      NaN           NaN
# 3120109017          10.0            3.0     20.0      NaN           NaN
# 20118038            38.0           26.0    372.0      NaN           NaN
# 3120303087          33.0           32.0    155.0      NaN           NaN
#
#             valid_cell_03  line_03  cell_04  code_cell_04  valid_cell_04  \
# id
# 3120105068           14.0    201.0     14.0          14.0           14.0
# 3120301259           25.0    204.0     19.0          19.0           18.0
# 3120332023           93.0    521.0      NaN           NaN            NaN
# 3120132004           56.0    250.0      NaN           NaN            NaN
# 3120118053           65.0    345.0     35.0          34.0           32.0
# ...                   ...      ...      ...           ...            ...
# 3120132011           93.0    524.0     29.0          29.0           28.0
# 3120305403            NaN      NaN      5.0           5.0            4.0
# 3120109017            NaN      NaN      NaN           NaN            NaN
# 20118038              NaN      NaN      NaN           NaN            NaN
# 3120303087            NaN      NaN      NaN           NaN            NaN
#
#             line_04
# id
# 3120105068    203.0
# 3120301259    191.0
# 3120332023      NaN
# 3120132004      NaN
# 3120118053    340.0
# ...             ...
# 3120132011    376.0
# 3120305403    207.0
# 3120109017      NaN
# 20118038        NaN
# 3120303087      NaN
#
# [82 rows x 16 columns]

# %%
def id_to_school(id):
    id = str(id)
    if id.startwith("3120101" or "3120301"):
        return "机械"
    elif id.startwith("3120103"):
        return "能源"
    elif id.startwith("3120104"):
        return "电气"
    elif id.startwith("3120105" or "3120305"):
        return "电信"
    elif id.startwith("3120118"):
        return "公共"
    else:
        return "其他"

# %%
import selenium.webdriver as webdriver
import time
import subprocess

if __name__ == "__main__":
    display = True
    option = webdriver.ChromeOptions()
    #这里修改成自己chrome浏览器的安装路径
    option.binary_location = r"C:\Program Files (x86)\Google\Chrome\Application\chrome.exe"
    #设置成有浏览器界面的模式，目前没针对无头浏览器开发，display改成true会报错
    if not display:
        option.set_headless()
    #这里修改成自己chromedriver的路径
    driver = webdriver.Chrome(r'D:\desktop\chromedriver_win32\chromedriver.exe', options=option)
    driver.set_window_rect(width=1366, height=768)

    target_url = r'http://yjskq.xjtu.edu.cn'
    driver.get(target_url)

    time.sleep(2)
    userName: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector('#form1 > input.username')
    passWord: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector('#form1 > input.pwd')
    login_btn: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector('#account_login')
    #这里改成自己的学号
    userName.send_keys('xuehao')
    #这里改成自己的密码
    passWord.send_keys('mima')
    login_btn.click()
    time.sleep(2)

    search_tab: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector(
        '#app > div > div.header.flex-box.flex-between.bg-white.box-shadow.fixed.top > div.navbar > ul > li:nth-child(3)')
    search_tab.click()
    time.sleep(2)

    date_cell: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector(
        '#app > div > div.content > div > div.main.container.box-shadow.border-radius-10.bg-white > div > div.panel-body > div.table.table-no-border.table-bg-color > div.el-table.el-table--fit.el-table--striped.el-table--enable-row-hover.el-table--enable-row-transition > div.el-table__body-wrapper.is-scrolling-none > table > tbody > tr:nth-child(1) > td.el-table_2_column_10 > div')
    clas_cell: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector(
        '#app > div > div.content > div > div.main.container.box-shadow.border-radius-10.bg-white > div > div.panel-body > div.table.table-no-border.table-bg-color > div.el-table.el-table--fit.el-table--striped.el-table--enable-row-hover.el-table--enable-row-transition > div.el-table__body-wrapper.is-scrolling-none > table > tbody > tr:nth-child(1) > td.el-table_2_column_12 > div')
    stat_cell: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector(
        '#app > div > div.content > div > div.main.container.box-shadow.border-radius-10.bg-white > div > div.panel-body > div.table.table-no-border.table-bg-color > div.el-table.el-table--fit.el-table--striped.el-table--enable-row-hover.el-table--enable-row-transition > div.el-table__body-wrapper.is-scrolling-none > table > tbody > tr:nth-child(1) > td.el-table_2_column_13 > div')
    cltm_cell: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector(
        '#app > div > div.content > div > div.main.container.box-shadow.border-radius-10.bg-white > div > div.panel-body > div.table.table-no-border.table-bg-color > div.el-table.el-table--fit.el-table--striped.el-table--enable-row-hover.el-table--enable-row-transition > div.el-table__body-wrapper.is-scrolling-none > table > tbody > tr:nth-child(1) > td.el-table_2_column_14 > div')
    time_cell: webdriver.remote.webdriver.WebElement = driver.find_element_by_css_selector(
        '#app > div > div.content > div > div.main.container.box-shadow.border-radius-10.bg-white > div > div.panel-body > div.table.table-no-border.table-bg-color > div.el-table.el-table--fit.el-table--striped.el-table--enable-row-hover.el-table--enable-row-transition > div.el-table__body-wrapper.is-scrolling-none > table > tbody > tr:nth-child(1) > td.el-table_2_column_15 > div')

    message = date_cell.text+'_'+clas_cell.text + '_' + stat_cell.text + '_' + cltm_cell.text + '_' + time_cell.text
    print(message)
    
    #激活自己安装有selenium的conda环境，而后执行发送邮件指令
    #我激活的环境是spider，如果你安装selenium在base下，应改成conda activate base & python sendmail_release.py --message={message}
    #发送邮件需要使用自己邮箱的授权码，具体怎么获取，可以去百度一下，想尝试的可以把下面代码的注释去掉

    # cmd = f'conda activate spider & python sendmail_release.py --message={message}'
    # p=subprocess.Popen(cmd, shell=True)
    # p.wait()
    # p.kill()

    time.sleep(10)
    driver.quit()
# Out:
# 2020-12-22_现代信号处理技术及应用_9-11_正常_18:53:57

# %%
#! /usr/bin/env python
#coding=utf-8

from email.mime.text import MIMEText
from email.header import Header
from smtplib import SMTP_SSL
import argparse

parser = argparse.ArgumentParser(description='9')
parser.add_argument('--times', type=int, default = 0)
parser.add_argument('--success', type=str, default = 'None')
parser.add_argument('--message', type=str, default = 'None')
args = parser.parse_args()
print(args.times)

#qq邮箱smtp服务器
host_server = 'smtp.qq.com'
#sender_qq为发件人的qq号码
sender_qq = '27******74@qq.com'
#pwd为qq邮箱的授权码，怎么开通自己授权码可以百度一下
pwd = 'an**********jbi' 
#发件人的邮箱
sender_qq_mail = '27*******74@qq.com'
#收件人邮箱
receiver = 'c******8@qq.com'
#邮件的正文内容ov.,
mail_content = f'上课打卡情况已发送'
#邮件的标题内容ov.,
mail_title = f'打卡  {args.message}'
print("邮件已发送")

#ssl登录
smtp = SMTP_SSL(host_server)
#set_debuglevel()是用来调试的。参数值为1表示开启调试模式，参数值为0关闭调试模式
smtp.set_debuglevel(0)
smtp.ehlo(host_server)
smtp.login(sender_qq, pwd)

msg = MIMEText(mail_content, "plain", 'utf-8')
msg["Subject"] = Header(mail_title, 'utf-8')
msg["From"] = sender_qq_mail
msg["To"] = receiver
smtp.sendmail(sender_qq_mail, receiver, msg.as_string())
smtp.quit()
# Out:
# usage: ipykernel_launcher.py [-h] [--times TIMES] [--success SUCCESS]
#                              [--message MESSAGE]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\huwyo\AppData\Roaming\jupyter\runtime\kernel-4c9da893-3aba-47fa-94ae-b698f086e992.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
import datetime as dt
import time
import subprocess
if __name__ == "__main__":
    print('date:20201218-v1 \nCome on! WorkMan')
    done = False
    #激活你装有selenium的conda虚拟环境，我的虚拟环境名为spider，如果使用base环境，请改为conda activate base & python yjskq_auto_release.py'
    cmd0 = 'conda activate spider & python yjskq_auto_release.py'
    while True:
        current_time = dt.datetime.now().time()
        print(current_time)
        if current_time.hour == 8 and done == False:
            p0 = subprocess.Popen(cmd0,shell=True)
            p0.wait()
            p0.kill()
            done = True
        if current_time.hour == 9:
            done = False

        if current_time.hour == 10 and current_time.minute > 10 and done == False:
            p0 = subprocess.Popen(cmd0,shell=True)
            p0.wait()
            p0.kill()
            done = True
        if current_time.hour == 11:
            done = False

        if current_time.hour == 14 and done == False:
            p0 = subprocess.Popen(cmd0,shell=True)
            p0.wait()
            p0.kill()
            done = True
        if current_time.hour == 15:
            done = False

        if current_time.hour == 16 and current_time.minute > 10 and done==False:
            p0 = subprocess.Popen(cmd0,shell=True)
            p0.wait()
            p0.kill()
            done = True
        if current_time.hour == 17:
            done = False

        time.sleep(60)
# Out:
# date:20201218-v1
# Come on! WorkMan
# 20:30:45.280546
# 20:31:45.281486
# 20:32:45.282302
# 20:33:45.282825
# 20:34:45.283375
# 20:35:45.283535
# 20:36:45.283807
# 20:37:45.284034
# 20:38:45.284107
# 20:39:45.284349
# 20:40:45.284852
# 20:41:45.285761
# 20:42:45.286739
# 20:43:45.286937
# 20:44:45.287244
# 20:45:45.287429
# 20:46:45.288117
# 20:47:45.288632
# 20:48:45.288737
# 20:49:45.289026
# 20:50:45.289840
# 20:51:45.290637
# 20:52:45.290908
# 20:53:45.291488
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-5289607f3065> in <module>
#      42             done = False
#      43
# ---> 44         time.sleep(60)
#      45
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
# plt.show()
# plt.savefig('test.pdf', format='pdf')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.

# %%
# OO-style
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
# pyplot-style

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
plt.plot(t**2, c='C2', ls='-.', marker='o', label='my label')
plt.legend()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
t = plt.xlabel('my data', fontsize=14, color='red')

# %%
plt.title(r'$\sigma_i=15$')
# Out:
# Text(0.5, 1.0, '$\\sigma_i=15$')

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()
