# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np
# fig, ax = plt.subplots()
# ax.plot([1,2,3,4],[1,4,2,3])
# plt.show()

# %%
import numpy as np
import pandas as pd
fpath = './作业.xlsx'
ratings = pd.read_excel(fpath)

# %%
ratings.head()
# Out:
#            id  line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# 0  3120105068    225.0           7.0      7.0            6.0      298
# 1  3120301259    163.0          21.0     21.0           20.0      162
# 2  3120332023    316.0          57.0     57.0           55.0      376
# 3  3120132004    171.0          37.0     37.0           36.0      368
# 4  3120118053    203.0         104.0    104.0          101.0      264
#
#    valid_cell_02  code_cell_02  cell_02  cell_03  ...  valid_cell_03  \
# 0             18            19       19     14.0  ...           14.0
# 1             22            24       25     27.0  ...           25.0
# 2             27            28       28     94.0  ...           93.0
# 3             25            26       26     57.0  ...           56.0
# 4             20            22       22     67.0  ...           65.0
#
#    code_cell_03  line_04  valid_cell_04  code_cell_04  cell_04  valid_cell_05  \
# ...

# %%
ratings.shape
# Out:
# (84, 21)

# %%
ratings.columns
# Out:
# Index(['id', 'line_01', 'code_cell_01', 'cell_01', 'valid_cell_01', 'line_02',
#        'valid_cell_02', 'code_cell_02', 'cell_02', 'cell_03', 'line_03',
#        'valid_cell_03', 'code_cell_03', 'line_04', 'valid_cell_04',
#        'code_cell_04', 'cell_04', 'valid_cell_05', 'line_05', 'cell_05',
#        'code_cell_05'],
#       dtype='object')

# %%
ratings.index
# Out:
# RangeIndex(start=0, stop=84, step=1)

# %%
ratings.dtypes
# Out:
# id                 int64
# line_01          float64
# code_cell_01     float64
# cell_01          float64
# valid_cell_01    float64
# line_02            int64
# valid_cell_02      int64
# code_cell_02       int64
# cell_02            int64
# cell_03          float64
# line_03          float64
# valid_cell_03    float64
# code_cell_03     float64
# line_04          float64
# valid_cell_04    float64
# code_cell_04     float64
# cell_04          float64
# valid_cell_05    float64
# line_05          float64
# cell_05          float64
# code_cell_05     float64
# dtype: object

# %%
tips = pd.read_csv('./tips.csv')

# %%
tips.head
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
s1 = pd.Series([1,'a',5.2,7])
s1
# Out:
# 0      1
# 1      a
# 2    5.2
# 3      7
# dtype: object

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s1.values
# Out:
# array([1, 'a', 5.2, 7], dtype=object)

# %%
s2 = pd.Series([1,'a',5.2,7],index = ['d','b','a','c'])
s2
# Out:
# d      1
# b      a
# a    5.2
# c      7
# dtype: object

# %%
s2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
ratings['line_01']
# Out:
# 0     225.0
# 1     163.0
# 2     316.0
# 3     171.0
# 4     203.0
#       ...
# 79    232.0
# 80    233.0
# 81      NaN
# 82    112.0
# 83      NaN
# Name: line_01, Length: 84, dtype: float64

# %%
ratings[['line_01','cell_01']]
# Out:
#     line_01  cell_01
# 0     225.0      7.0
# 1     163.0     21.0
# 2     316.0     57.0
# 3     171.0     37.0
# 4     203.0    104.0
# ..      ...      ...
# 79    232.0     43.0
# 80    233.0     41.0
# 81      NaN      NaN
# 82    112.0     37.0
# 83      NaN      NaN
#
# [84 rows x 2 columns]

# %%
ratings.loc[1]
# Out:
# id               3.120301e+09
# line_01          1.630000e+02
# code_cell_01     2.100000e+01
# cell_01          2.100000e+01
# valid_cell_01    2.000000e+01
# line_02          1.620000e+02
# valid_cell_02    2.200000e+01
# code_cell_02     2.400000e+01
# cell_02          2.500000e+01
# cell_03          2.700000e+01
# line_03          2.040000e+02
# valid_cell_03    2.500000e+01
# code_cell_03     2.600000e+01
# line_04          1.910000e+02
# valid_cell_04    1.800000e+01
# code_cell_04     1.900000e+01
# cell_04          1.900000e+01
# valid_cell_05             NaN
# line_05                   NaN
# cell_05                   NaN
# code_cell_05              NaN
# Name: 1, dtype: float64

# %%
ratings.head
# Out:
# <bound method NDFrame.head of             id  line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# 0   3120105068    225.0           7.0      7.0            6.0      298
# 1   3120301259    163.0          21.0     21.0           20.0      162
# 2   3120332023    316.0          57.0     57.0           55.0      376
# 3   3120132004    171.0          37.0     37.0           36.0      368
# 4   3120118053    203.0         104.0    104.0          101.0      264
# ..         ...      ...           ...      ...            ...      ...
# 79  3120305697    232.0          17.0     43.0           17.0      378
# 80  3120132011    233.0          41.0     41.0           39.0      351
# 81  3120305403      NaN           NaN      NaN            NaN       73
# 82  3120109017    112.0          30.0     37.0           19.0       20
# 83    20118038      NaN           NaN      NaN            NaN      372
#
#     valid_cell_02  code_cell_02  cell_02  cell_03  ...  valid_cell_03  \
# ...

# %%
ratings.index
# Out:
# RangeIndex(start=0, stop=84, step=1)

# %% [raw]
# ratings.index = ratings['id']

# %%
ratings.dtypes
# Out:
# id                 int64
# line_01          float64
# code_cell_01     float64
# cell_01          float64
# valid_cell_01    float64
# line_02            int64
# valid_cell_02      int64
# code_cell_02       int64
# cell_02            int64
# cell_03          float64
# line_03          float64
# valid_cell_03    float64
# code_cell_03     float64
# line_04          float64
# valid_cell_04    float64
# code_cell_04     float64
# cell_04          float64
# valid_cell_05    float64
# line_05          float64
# cell_05          float64
# code_cell_05     float64
# dtype: object

# %%
ratings.index = ratings['id']

# %%
ratings
# Out:
#                     id  line_01  code_cell_01  cell_01  valid_cell_01  \
# id
# 3120105068  3120105068    225.0           7.0      7.0            6.0
# 3120301259  3120301259    163.0          21.0     21.0           20.0
# 3120332023  3120332023    316.0          57.0     57.0           55.0
# 3120132004  3120132004    171.0          37.0     37.0           36.0
# 3120118053  3120118053    203.0         104.0    104.0          101.0
# ...                ...      ...           ...      ...            ...
# 3120305697  3120305697    232.0          17.0     43.0           17.0
# 3120132011  3120132011    233.0          41.0     41.0           39.0
# 3120305403  3120305403      NaN           NaN      NaN            NaN
# 3120109017  3120109017    112.0          30.0     37.0           19.0
# 20118038      20118038      NaN           NaN      NaN            NaN
#
#             line_02  valid_cell_02  code_cell_02  cell_02  cell_03  ...  \
# ...

# %%
ratings.index
# Out:
# Int64Index([3120105068, 3120301259, 3120332023, 3120132004, 3120118053,
#             3120305718, 3120132006, 3120301183, 3120303014, 3120305664,
#             3120301047, 3120319111, 3120101220, 3120301223, 3120332025,
#             3120305660, 3120103152, 3120101059, 3120305679, 3120305601,
#             3120332044, 3120319056, 3120101202, 3120305686, 3120101127,
#             3120101238, 3120101019, 3120101240, 4120101106, 3120101221,
#             3120999178, 3120118049, 3120305683, 3120101282, 3120101246,
#             3120105015, 3120332026, 3120301080, 3120305442, 3120118037,
#             3120101260, 3120103153, 3120319071, 3120104196, 3120305579,
#             3120101244, 3120305689, 3120103322, 3120319059, 3120301233,
#             3120301231, 3120101273, 3120101017, 3120301269, 3120101212,
#             3120303087, 3120118047, 3120305694, 3120101074, 3120332011,
#             3120101015, 3120332035, 3120101271, 3120118038, 3120319067,
# ...

# %%
ratings[['line_01','line_02']]
# Out:
#             line_01  line_02
# id
# 3120105068    225.0      298
# 3120301259    163.0      162
# 3120332023    316.0      376
# 3120132004    171.0      368
# 3120118053    203.0      264
# ...             ...      ...
# 3120305697    232.0      378
# 3120132011    233.0      351
# 3120305403      NaN       73
# 3120109017    112.0       20
# 20118038        NaN      372
#
# [84 rows x 2 columns]

# %%
ratings.loc[ratings['line_01']>500,:]
# Out:
#                     id  line_01  code_cell_01  cell_01  valid_cell_01  \
# id
# 3120301223  3120301223    586.0         203.0    203.0          195.0
# 3120101238  3120101238    514.0          74.0     74.0           70.0
#
#             line_02  valid_cell_02  code_cell_02  cell_02  cell_03  ...  \
# id                                                                  ...
# 3120301223      458            194           201      201     54.0  ...
# 3120101238      364             29            30       30     23.0  ...
#
#             valid_cell_03  code_cell_03  line_04  valid_cell_04  code_cell_04  \
# id
# 3120301223           52.0          54.0    168.0           76.0          79.0
# 3120101238           20.0          21.0    244.0            5.0           8.0
#
#             cell_04  valid_cell_05  line_05  cell_05  code_cell_05
# id
# 3120301223     79.0            NaN      NaN      NaN           NaN
# 3120101238      8.0           17.0    383.0     30.0          18.0
#
# ...

# %%
ratings.loc[ratings['id']==4120101106,:]
# Out:
#                     id  line_01  code_cell_01  cell_01  valid_cell_01  \
# id
# 4120101106  4120101106    277.0          90.0     90.0           87.0
#
#             line_02  valid_cell_02  code_cell_02  cell_02  cell_03  ...  \
# id                                                                  ...
# 4120101106      244             61            65       65     86.0  ...
#
#             valid_cell_03  code_cell_03  line_04  valid_cell_04  code_cell_04  \
# id
# 4120101106           78.0          86.0    328.0           43.0          46.0
#
#             cell_04  valid_cell_05  line_05  cell_05  code_cell_05
# id
# 4120101106     46.0            NaN      NaN      NaN           NaN
#
# [1 rows x 21 columns]

# %%
ratings.loc[(ratings['line_01']>=200) & (ratings['line_02']>=200) & (ratings['line_03']>=200),:]
# Out:
#                     id  line_01  code_cell_01  cell_01  valid_cell_01  \
# id
# 3120105068  3120105068    225.0           7.0      7.0            6.0
# 3120332023  3120332023    316.0          57.0     57.0           55.0
# 3120118053  3120118053    203.0         104.0    104.0          101.0
# 3120305718  3120305718    279.0          36.0     37.0           21.0
# 3120132006  3120132006    460.0          64.0     64.0           61.0
# 3120301183  3120301183    292.0          76.0     76.0           71.0
# 3120305664  3120305664    389.0         147.0    156.0          142.0
# 3120301047  3120301047    307.0          56.0     57.0           55.0
# 3120319111  3120319111    214.0         182.0    182.0          162.0
# 3120301223  3120301223    586.0         203.0    203.0          195.0
# 3120332025  3120332025    307.0         280.0    280.0          185.0
# 3120103152  3120103152    363.0         125.0    125.0          120.0
# ...

# %%
dates = pd.date_range('20130101',periods = 6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('20200101',periods = 6)
dates2
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('20201001',periods = 6)
dates2
# Out:
# DatetimeIndex(['2020-10-01', '2020-10-02', '2020-10-03', '2020-10-04',
#                '2020-10-05', '2020-10-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('20201212',periods = 6)
dates2
# Out:
# DatetimeIndex(['2020-12-12', '2020-12-13', '2020-12-14', '2020-12-15',
#                '2020-12-16', '2020-12-17'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('20201220',periods = 6)
dates2
# Out:
# DatetimeIndex(['2020-12-20', '2020-12-21', '2020-12-22', '2020-12-23',
#                '2020-12-24', '2020-12-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('20201222',periods = 6)
dates2
# Out:
# DatetimeIndex(['2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('20201228',periods = 6)
dates2
# Out:
# DatetimeIndex(['2020-12-28', '2020-12-29', '2020-12-30', '2020-12-31',
#                '2021-01-01', '2021-01-02'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range('19980514',periods = 10000)
dates2
# Out:
# DatetimeIndex(['1998-05-14', '1998-05-15', '1998-05-16', '1998-05-17',
#                '1998-05-18', '1998-05-19', '1998-05-20', '1998-05-21',
#                '1998-05-22', '1998-05-23',
#                ...
#                '2025-09-19', '2025-09-20', '2025-09-21', '2025-09-22',
#                '2025-09-23', '2025-09-24', '2025-09-25', '2025-09-26',
#                '2025-09-27', '2025-09-28'],
#               dtype='datetime64[ns]', length=10000, freq='D')

# %%
s = pd.Series([1,3,5,np,6,6.8])
s
# Out:
# 0                                                    1
# 1                                                    3
# 2                                                    5
# 3    <module 'numpy' from 'E:\\anaconda3\\lib\\site...
# 4                                                    6
# 5                                                  6.8
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(6,6),index = dates, columns = list('ABCDEF'))
df
# Out:
#                    A         B         C         D         E         F
# 2013-01-01  0.280737  0.812092  0.233287 -0.425452  0.498893 -1.395909
# 2013-01-02 -0.334286 -0.193609 -1.597487  0.278255  0.399411 -2.205286
# 2013-01-03 -0.087786  0.719579 -1.686942  0.405506 -0.119346  0.078797
# 2013-01-04  0.386188  1.547047 -0.882765  0.332559 -0.366752 -0.729321
# 2013-01-05  0.363220  0.808448  1.135529 -0.295051  2.045491  0.873994
# 2013-01-06  2.210063 -0.096020 -0.457209 -1.182156  0.931313  0.469159

# %%
grads = pd.read_excel('./作业.xlsx', index_col='id')
grads
# Out:
#             line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# id
# 3120105068    225.0           7.0      7.0            6.0      298
# 3120301259    163.0          21.0     21.0           20.0      162
# 3120332023    316.0          57.0     57.0           55.0      376
# 3120132004    171.0          37.0     37.0           36.0      368
# 3120118053    203.0         104.0    104.0          101.0      264
# ...             ...           ...      ...            ...      ...
# 3120305697    232.0          17.0     43.0           17.0      378
# 3120132011    233.0          41.0     41.0           39.0      351
# 3120305403      NaN           NaN      NaN            NaN       73
# 3120109017    112.0          30.0     37.0           19.0       20
# 20118038        NaN           NaN      NaN            NaN      372
#
#             valid_cell_02  code_cell_02  cell_02  cell_03  line_03  \
# id
# 3120105068             18            19       19     14.0    201.0
# ...

# %%
grads.head(3)
# Out:
#             line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# id
# 3120105068    225.0           7.0      7.0            6.0      298
# 3120301259    163.0          21.0     21.0           20.0      162
# 3120332023    316.0          57.0     57.0           55.0      376
#
#             valid_cell_02  code_cell_02  cell_02  cell_03  line_03  \
# id
# 3120105068             18            19       19     14.0    201.0
# 3120301259             22            24       25     27.0    204.0
# 3120332023             27            28       28     94.0    521.0
#
#             valid_cell_03  code_cell_03  line_04  valid_cell_04  code_cell_04  \
# id
# 3120105068           14.0          14.0    203.0           14.0          14.0
# 3120301259           25.0          26.0    191.0           18.0          19.0
# 3120332023           93.0          94.0    276.0           40.0          42.0
#
#             cell_04  valid_cell_05  line_05  cell_05  code_cell_05
# id
# ...

# %%
grads.tail(3)
# Out:
#             line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# id
# 3120305403      NaN           NaN      NaN            NaN       73
# 3120109017    112.0          30.0     37.0           19.0       20
# 20118038        NaN           NaN      NaN            NaN      372
#
#             valid_cell_02  code_cell_02  cell_02  cell_03  line_03  \
# id
# 3120305403              2             3        3      NaN      NaN
# 3120109017              3            10       12      NaN      NaN
# 20118038               26            38       38      NaN      NaN
#
#             valid_cell_03  code_cell_03  line_04  valid_cell_04  code_cell_04  \
# id
# 3120305403            NaN           NaN    207.0            4.0           5.0
# 3120109017            NaN           NaN      NaN            NaN           NaN
# 20118038              NaN           NaN      NaN            NaN           NaN
#
#             cell_04  valid_cell_05  line_05  cell_05  code_cell_05
# id
# ...

# %%
grads.describe()
# Out:
#           line_01  code_cell_01     cell_01  valid_cell_01     line_02  \
# count   82.000000     82.000000   82.000000      82.000000   84.000000
# mean   241.231707     69.780488   72.000000      63.036585  268.297619
# std    101.265486     58.088486   58.756245      51.069414  104.990049
# min      0.000000      1.000000    1.000000       0.000000    0.000000
# 25%    171.250000     27.500000   30.250000      22.000000  207.500000
# 50%    229.500000     55.000000   55.500000      50.500000  266.000000
# 75%    295.000000     93.000000   93.000000      86.250000  349.500000
# max    586.000000    280.000000  280.000000     197.000000  561.000000
#
#        valid_cell_02  code_cell_02     cell_02     cell_03     line_03  \
# count      84.000000     84.000000   84.000000   81.000000   81.000000
# mean       36.964286     42.357143   44.214286   63.962963  303.950617
# std        34.057516     38.763926   40.198025   46.879752  139.508145
# ...

# %%
grads.sort_index()
# Out:
#             line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# id
# 20118038        NaN           NaN      NaN            NaN      372
# 3120101015    131.0           7.0      7.0            6.0      222
# 3120101016    236.0           4.0      4.0            3.0      356
# 3120101017    139.0          12.0     12.0            9.0      181
# 3120101019    162.0          23.0     23.0           22.0      249
# ...             ...           ...      ...            ...      ...
# 3120332035    230.0          51.0     51.0           49.0      321
# 3120332036    141.0          38.0     38.0           32.0      298
# 3120332044    222.0          62.0     62.0           60.0      338
# 3120999178    118.0          41.0     41.0           40.0      191
# 4120101106    277.0          90.0     90.0           87.0      244
#
#             valid_cell_02  code_cell_02  cell_02  cell_03  line_03  \
# id
# 20118038               26            38       38      NaN      NaN
# ...

# %%
grads.sort_values(by='line_01')
# Out:
#             line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# id
# 3120101097      0.0           1.0      1.0            0.0        0
# 3120305694     42.0          18.0     18.0            7.0       46
# 3120101221     76.0          21.0     22.0           11.0      106
# 3120109017    112.0          30.0     37.0           19.0       20
# 3120305660    114.0          65.0     69.0           58.0      399
# ...             ...           ...      ...            ...      ...
# 3120132006    460.0          64.0     64.0           61.0      344
# 3120101238    514.0          74.0     74.0           70.0      364
# 3120301223    586.0         203.0    203.0          195.0      458
# 3120305403      NaN           NaN      NaN            NaN       73
# 20118038        NaN           NaN      NaN            NaN      372
#
#             valid_cell_02  code_cell_02  cell_02  cell_03  line_03  \
# id
# 3120101097              0             4        4      1.0      0.0
# ...

# %%
grads[0:3]
# Out:
#             line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# id
# 3120105068    225.0           7.0      7.0            6.0      298
# 3120301259    163.0          21.0     21.0           20.0      162
# 3120332023    316.0          57.0     57.0           55.0      376
#
#             valid_cell_02  code_cell_02  cell_02  cell_03  line_03  \
# id
# 3120105068             18            19       19     14.0    201.0
# 3120301259             22            24       25     27.0    204.0
# 3120332023             27            28       28     94.0    521.0
#
#             valid_cell_03  code_cell_03  line_04  valid_cell_04  code_cell_04  \
# id
# 3120105068           14.0          14.0    203.0           14.0          14.0
# 3120301259           25.0          26.0    191.0           18.0          19.0
# 3120332023           93.0          94.0    276.0           40.0          42.0
#
#             cell_04  valid_cell_05  line_05  cell_05  code_cell_05
# id
# ...

# %%
grads.loc[[3120332023, 3120301259], ['line_01', 'line_02']]
# Out:
#             line_01  line_02
# id
# 3120332023    316.0      376
# 3120301259    163.0      162

# %%
grads.loc[4120101106,['line_01','line_02','line_03','line_04','line_05']]
# Out:
# line_01    277.0
# line_02    244.0
# line_03    214.0
# line_04    328.0
# line_05      NaN
# Name: 4120101106, dtype: float64

# %%
grads.at[4120101106,'line_01']
# Out:
# 277.0

# %%
grads.iloc[[1,3],[2,4]]
# Out:
#             cell_01  line_02
# id
# 3120301259     21.0      162
# 3120132004     37.0      368

# %%
grads.iat[1,1]
# Out:
# 21.0

# %%
grads[grads['line_01'] >= 200]
# Out:
#             line_01  code_cell_01  cell_01  valid_cell_01  line_02  \
# id
# 3120105068    225.0           7.0      7.0            6.0      298
# 3120332023    316.0          57.0     57.0           55.0      376
# 3120118053    203.0         104.0    104.0          101.0      264
# 3120305718    279.0          36.0     37.0           21.0      245
# 3120132006    460.0          64.0     64.0           61.0      344
# 3120301183    292.0          76.0     76.0           71.0      284
# 3120303014    281.0         129.0    129.0          116.0      220
# 3120305664    389.0         147.0    156.0          142.0      366
# 3120301047    307.0          56.0     57.0           55.0      561
# 3120319111    214.0         182.0    182.0          162.0      305
# 3120301223    586.0         203.0    203.0          195.0      458
# 3120332025    307.0         280.0    280.0          185.0      303
# 3120103152    363.0         125.0    125.0          120.0      273
# ...

# %%
grads.loc[:, 'line_01'] = np.array([200] * len(grads))
grads.loc[:, 'line_01']
# Out:
# id
# 3120105068    200
# 3120301259    200
# 3120332023    200
# 3120132004    200
# 3120118053    200
#              ...
# 3120305697    200
# 3120132011    200
# 3120305403    200
# 3120109017    200
# 20118038      200
# Name: line_01, Length: 84, dtype: int32

# %%
grads['total'] = np.nan
grads['total']
# Out:
# id
# 3120105068   NaN
# 3120301259   NaN
# 3120332023   NaN
# 3120132004   NaN
# 3120118053   NaN
#               ..
# 3120305697   NaN
# 3120132011   NaN
# 3120305403   NaN
# 3120109017   NaN
# 20118038     NaN
# Name: total, Length: 84, dtype: float64

# %%
import re
import requests
import traceback
from bs4 import BeautifulSoup
def gethttptext(url,code='utf-8'):
    try:
        r=requests.get(url,timeout=30)
        r.raise_for_status()
        r.encoding=code
        #print(r.status_code)
        return r.text
    except:
        return ""
def getstocklist(list,stockurl):
    html=gethttptext(stockurl)
    soup=BeautifulSoup(html,'html.parser')
    a=soup.find_all('tr')
    for i in a:
        try:
            href=i.attrs['id']
            list.append(re.findall(r'[tr]\d{6}',href)[0])
        except:
            continue

def getstockinfo(list,stockurl,fpath):
    count=0
    for stock in list:
        url=stockurl+stock[1:]+".html"
        html=gethttptext(url)
        try:
            if html=='':
                continue
            infodict={}
            soup=BeautifulSoup(html,'html.parser')
            stockinfo=soup.find('div',attrs={'class':'merchandiseDetail'})

            name=stockinfo.find_all(attrs={'class':'fundDetail-tit'})[0]
            infodict.update({'股票名称':name.text.split()[0]})

            keylist=stockinfo.find_all('dt')
            valuelist=stockinfo.find_all('dd')
            for i in range(len(keylist)):
                key=keylist[i].text
                val=valuelist[i].text
                infodict[key]=val
            with open(fpath,'a',encoding='utf-8') as f:
                f.write(str(infodict)+'\n')
                count=count+1
                print('\r当前速度：{:.2f}%'.format(count*100/len(list)),end='')

        except:
            count = count + 1
            print('\r当前速度：{:.2f}%'.format(count * 100 / len(list)), end='')
            traceback.print_exc()
            continue

if __name__=="__main__":
    stock_list_url="https://fund.eastmoney.com/fund.html#os_0;isall_0;ft_;pt_1"
    stock_info_url="https://fund.eastmoney.com/"
    output_fire="F://py项目//BaiduStockInfo.txt"
    slist=[]
    getstocklist(slist,stock_list_url)
    getstockinfo(slist,stock_info_url,output_fire)
# Out:
# 当前速度：100.00%

# %%
import numpy as np
import pandas as pd
df = pd.read_table('./BaiduStockInfo.txt')

# %%
df.head()
# Out:
#   {'股票名称': '融通通优债券(003146)', '净值估算(20-12-25 15:00)净值估算每个交易日9：30-15：00盘中实时更新（QDII基金为海外交易时段）。': '--', '单位净值 (2020-12-24)': '近1月：5.08%', '累计净值': '近1年：6.14%'}
# 0  {'股票名称': '招商中证煤炭等权指数分级(161724)', '净值估算(20-12-2...
# 1  {'股票名称': '九泰天宝灵活配置混合A(000892)', '净值估算(20-12-25...
# 2  {'股票名称': '九泰天宝灵活配置混合C(002028)', '净值估算(20-12-25...
# 3  {'股票名称': '北信瑞丰产业升级(168501)', '净值估算(20-12-25 15...
# 4  {'股票名称': '长信国防军工量化混合C(008960)', '净值估算(20-12-25...

# %%
df.head
# Out:
# <bound method NDFrame.head of     {'股票名称': '融通通优债券(003146)', '净值估算(20-12-25 15:00)净值估算每个交易日9：30-15：00盘中实时更新（QDII基金为海外交易时段）。': '--', '单位净值 (2020-12-24)': '近1月：5.08%', '累计净值': '近1年：6.14%'}
# 0    {'股票名称': '招商中证煤炭等权指数分级(161724)', '净值估算(20-12-2...
# 1    {'股票名称': '九泰天宝灵活配置混合A(000892)', '净值估算(20-12-25...
# 2    {'股票名称': '九泰天宝灵活配置混合C(002028)', '净值估算(20-12-25...
# 3    {'股票名称': '北信瑞丰产业升级(168501)', '净值估算(20-12-25 15...
# 4    {'股票名称': '长信国防军工量化混合C(008960)', '净值估算(20-12-25...
# ..                                                 ...
# 194  {'股票名称': '博时研究精选持有期混合C(009592)', '净值估算(20-12-2...
# 195  {'股票名称': '浙商中华预期高股息A(007178)', '净值估算--净值估算每个交易...
# 196  {'股票名称': '富国美丽中国混合(002593)', '净值估算(20-12-25 15...
# 197  {'股票名称': '前海开源沪港深新硬件C(004315)', '净值估算(20-12-25...
# 198  {'股票名称': '前海开源沪港深新硬件A(004314)', '净值估算(20-12-25...
#
# [199 rows x 1 columns]>

# %%
df = pd.read_csv('./beijing_tianqi_2018.csv')
df.head
# Out:
# <bound method NDFrame.head of             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3    2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4    2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 362  2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 363  2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# ...

# %%
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
df.set_index('ymd',inplace = True)

# %%
df.loc[:,'bWendu'] = df['bWendu'].str.replace('℃','').astype('int32')

# %%
df.dtypes
# Out:
# ymd          object
# bWendu        int32
# yWendu       object
# tianqi       object
# fengxiang    object
# fengli       object
# aqi           int64
# aqiInfo      object
# aqiLevel      int64
# dtype: object

# %%
df.head()
# Out:
#             bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-01       3    -6℃   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02       2    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03       2    -5℃     多云        北风   1-2级   28       优         1
# 2018-01-04       0    -8℃      阴       东北风   1-2级   28       优         1
# 2018-01-05       3    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
df.loc[:,'yWendu'] = df['yWendu'].str.replace('℃','').astype('int32')

# %%
df.head()
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1

# %%
df.loc[df['yWendu']<-10,:]
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-23      -4     -12      晴       西北风   3-4级   31       优         1
# 2018-01-24      -4     -11      晴       西南风   1-2级   34       优         1
# 2018-01-25      -3     -11     多云       东北风   1-2级   27       优         1
# 2018-12-26      -2     -11   晴~多云       东北风     2级   26       优         1
# 2018-12-27      -5     -12   多云~晴       西北风     3级   48       优         1
# 2018-12-28      -3     -11      晴       西北风     3级   40       优         1
# 2018-12-29      -3     -12      晴       西北风     2级   29       优         1
# 2018-12-30      -2     -11   晴~多云       东北风     1级   31       优         1

# %%
dates2 = pd.date_range('20180617',periods = 1000)
dates2
# Out:
# DatetimeIndex(['2018-06-17', '2018-06-18', '2018-06-19', '2018-06-20',
#                '2018-06-21', '2018-06-22', '2018-06-23', '2018-06-24',
#                '2018-06-25', '2018-06-26',
#                ...
#                '2021-03-03', '2021-03-04', '2021-03-05', '2021-03-06',
#                '2021-03-07', '2021-03-08', '2021-03-09', '2021-03-10',
#                '2021-03-11', '2021-03-12'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
dates2 = pd.date_range('20180617',periods = 10000)
dates2
# Out:
# DatetimeIndex(['2018-06-17', '2018-06-18', '2018-06-19', '2018-06-20',
#                '2018-06-21', '2018-06-22', '2018-06-23', '2018-06-24',
#                '2018-06-25', '2018-06-26',
#                ...
#                '2045-10-23', '2045-10-24', '2045-10-25', '2045-10-26',
#                '2045-10-27', '2045-10-28', '2045-10-29', '2045-10-30',
#                '2045-10-31', '2045-11-01'],
#               dtype='datetime64[ns]', length=10000, freq='D')

# %%
df.loc[:,'wencha'] = df['bWendu']-df['yWendu']

# %%
df.head()
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# ymd
# 2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1
#
#             wencha
# ymd
# 2018-01-01       9
# 2018-01-02       7
# 2018-01-03       7
# 2018-01-04       8
# 2018-01-05       9

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  
plt.plot(x, x**2, label='quadratic')  
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]
plt.figure(figsize=(9, 3))
plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
