# %%
import matplotlib.pyplot as plt
import numpy as np

fig,ax = plt.subplots()
x = [i for i in np.arange(0,10,0.1)]
y = [i**2 for i in x]
ax.plot(x,y)
plt.show()
#plt.savefig('test.pdf',format='pdf')

# %%
#00-style
x = np.linspace(0,2,100)   #返回列表，0-2,100份
#print(x)

fig,ax1 = plt.subplots(figsize=(13,10))
ax1.plot(x,x,label='linear')
ax1.plot(x,x**2,label="quadratic")
ax1.plot(x,x**3,label='cubic')
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')
ax1.set_title('Simple Plot')
ax1.legend(loc='upper center')

# %%
#pyplot-style
import numpy as np
from matplotlib import pyplot as plt
x = np.linspace(0,2,100)

#plot some data on the (implicit) axes.在（隐式）轴上绘制一些数据
plt.plot(x,x,label='linear') 
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('Simple Plot')
plt.legend()

# %%
#plt.plot(x,y)
#t = np.arange(0,5,0.2)  
t = np.linspace(2,6,6)      #横坐标为点的指针
#t = [i for i in range(6)]  #报错
#t = range(6)               #报错
plt.plot(t**2,c='C2',linestyle='-.',marker='*',label='My_label')  #x——点的指针；y——f(t)点的值 *****
plt.show()
print('70')
# Out:
# 70

# %%
#ro修改默认蓝色折线为红点
plt.plot([1,2,3,4],[1,3,7,13],'ro') 
#plt.axis([]) 设置两轴取值范围
plt.axis([0,6,0,20])
t = np.arange(0.,5.,0.2)
#括号内变量加字符串参数一起，可以一直这样画下去
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = {
    'a':np.arange(50),
    'c':np.random.randint(0,50,50),      #随机生成0-50的50个整数，表示颜色参数
    'd':np.random.randn(50),             #生成50个标准正太分布点，取值范围（-1,1）
}
data['b'] = data['a'] + 10*np.random.randn(50)
data['d'] = np.abs(data['d'])*100        #标签d中元素取绝对值，再乘100
#plt.scatter表示绘制散点图;a,b表示点的坐标；c表示color;s表示散点图点的直径
plt.scatter('a','b',c='c',s='d',data=data) 
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
names =['group_a','group_b','group_c']
values = [1,10,100]

plt.figure(figsize=(9,3))

#摆放位置可用一个连续的三位数来表示
plt.subplot(131)
plt.bar(names,values)       #直方图
plt.subplot(132)
plt.scatter(names,values)   #散点图
plt.subplot(133)
plt.plot(names,values)      #折线图
plt.suptitle('Catagorical Plotting')
plt.show()
print('100')
# Out:
# 100

# %%
mu,sigma = 100,15
x = mu + sigma*np.random.randn(10000)

#the histogram of the data
#绘制直方图，（一位数组，图柱数量，未知，颜色，透明度）
n,bins,patches = plt.hist(x,50,density=1,facecolor='g',alpha=0.75)
# print(n)          #直方图向量
# print(bins)       #返回各个bins的区间范围
# print(patches)    #返回每个bin里包含的数据，是一个列表

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60,.025,r'$\mu=100,\ \sigma=15$')   #数学公式表达式，可用于显示希腊字母
plt.axis([40,160,0,0.03])
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
t = plt.xlabel('my data',fontsize=14,color='red')    #设置标签大小及颜色
plt.title(r'$\sigma_i=15$')
# Out:
# Text(0.5, 1.0, '$\\sigma_i=15$')

# %%
#ax1,ax2 = plt.subplot(121),plt.subplot(122)
ax = plt.subplot(111)

t = np.arange(0.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line = plt.plot(t,s,lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )
plt.ylim(-2,2)
plt.show()
print('130')
# Out:
# 130

# %%
np.random.seed(19680801)

y = np.random.normal(loc=0.5,scale=0.4,size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

plt.figure()

#linear
plt.subplot(221)
plt.plot(x,y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

#log
plt.subplot(222)
plt.plot(x,y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

#symmetric log
plt.subplot(223)
plt.plot(x,y - y.mean())
plt.yscale('symlog',linthresh=0.01)
plt.title('symlog')
plt.grid(True)

#logit
plt.subplot(224)
plt.plot(x,y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
plt.subplots_adjust(top=0.92,bottom=0.08,left=0.10,right=0.95,hspace=0.25,
                   wspace=0.35)
plt.show()
print('170')
# Out:
# 170

# %%
import seaborn as sns
import pandas as pd
sns.set_theme(style = "darkgrid")
penguins = pd.read_csv("penguins.csv")
tips = pd.read_csv('tips.csv')
fmri = pd.read_csv('fmri.csv')
sns.histplot(data=penguins,x='flipper_length_mm',hue='species',multiple='stack')
#sns.kdeplot(data=penguins,x='flipper_length_mm',hue='species',multiple='stack')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.kdeplot(data=penguins,x='flipper_length_mm',hue='species',multiple='stack')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
def id_to_school(id):
    id = str(id)
    if id.startWith('31203'):
        return '机械工程学院'
    else:
        return '新媒体学院'

grads['学院'] = grads.apply(lambda x: id_to_shcool(x.name),axis=1)
total_result = grads.groupby('学院').sum()

# %%
import numpy as np
import pandas as pd

s = pd.Series([1,3,5,np.nan,6,8])
dates = pd.date_range('20130101',periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import selenium.webdriver as webd

if __name__ == '__main__':
    
    display = True
    option = webd.ChromeOptions()
    option.binary_location(r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe",options=option)
    driver.implicitly_wait(10)
    driver.set_windoe_rect(width=1366,height=768)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-8eb4f26d76ab> in <module>
#       5     display = True
#       6     option = webd.ChromeOptions()
# ----> 7     option.binary_location(r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe",options=option)
#       8     driver.implicitly_wait(10)
#       9     driver.set_windoe_rect(width=1366,height=768)
#
# TypeError: 'str' object is not callable

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.629586  2.197586  0.823793 -1.319422
# 2013-01-02  0.106322  0.176208  1.856000  0.629278
# 2013-01-03  0.842129 -0.206763 -1.593661 -0.680234
# 2013-01-04  0.299095 -0.610368 -0.360334 -0.601970
# 2013-01-05  0.429361  0.378943 -0.505776  0.684360
# 2013-01-06 -0.613437 -0.479754  0.749975  0.248171

# %%
import pandas
print(170)
# Out:
# 170

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4*np.pi,4*np.pi,100)   #对应图中四圈
z = np.linspace(-2,2,100)                   #z轴数据
r = z**2 + 1                                #整体参数
x = r * np.sin(theta)
y = r * np.cos(theta)                       #y轴参数
ax.plot(x,y,z,label='parametric curve')     #三维绘图
ax.legend()

plt.show()
print('190')
# Out:
# 190

# %%
'''
3D plots as subplots
**********************
Demonstrate including 3D plots as subplots.
演示包括三维图作为子图
'''
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D,get_test_data
from matplotlib import cm
import numpy as np

#set up a figure twice as wide as it is tall
fig = plt.figure(figsize=plt.figaspect(0.5))

#First subplot
#set up the axes for the first plot
ax = fig.add_subplot(1,2,1,projection='3d')

#plot a 3D surface like in the example mpot3d/surface3d_demo
X = np.arange(-5,5,0.25)
Y = np.arange(-5,5,0.25)
X,Y = np.meshgrid(X,Y)     #生成网格点坐标矩阵
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap = cm.coolwarm,linewidth=0,
                      antialiased=False)
ax.set_zlim(-1.01,1.01)
fig.colorbar(surf,shrink=0.5,aspect=10)

#Second subplot
ax = fig.add_subplot(1,2,2,projection='3d')

#plot a 3D wireframe like in the example mplot3d/wire3d_demo
X,Y,Z = get_test_data(0.05)
ax.plot_wireframe(X,Y,Z,rstride=10,cstride=10)
plt.show()
print('227')
# Out:
# 227
