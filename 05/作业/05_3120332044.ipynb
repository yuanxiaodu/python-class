# %% [markdown]
# 1. Matplotlib

# %% [markdown]
# 1.1 Intro to pyplot（matplotlib中如果只画一张图的话，可以直接用pyplot）
#
# 1.一般的做法是：
#
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(20,8),dpi=90) # 设置画布大小及像素
#
# plt.xticks()  # 设置x坐标刻度
#
# plt.yticks() # 设置y坐标刻度
#
# plt.xlabel() # 设置x坐标名
#
# plt.ylabel() # 设置y坐标名
#
# plt.title() # 设置主题
#
# plt.plot() # 画图
#
# plt.legend(loc='') # 显示图例
#
# 2.当需要在一张图中画两个坐标系，需要用到subplots，具体用法如下：
#
# import matplotlib.pyplot as plt
#
# fig,ax = plt.subplots(nrows=n,ncols=m,figsize=(20,8)) # fig为返回的图像，ax为返回的坐标系（为一个数组）
#
# ax[0],set_xticks() #设置各个坐标系的刻度
#
# ax[0].set_yticks() # 需要注意，这里每个坐标系都需要单独设置刻度，坐标轴名称，主题，图例等
#
# ax[0].set_xlabel()
#
# ax[0].set_ylabel()
#
# ax[0].set_title()
#
# ax[0].legend(loc='')
#
# ax[0].plot()

# %%
import matplotlib.pyplot as plt #Matplotlib 是一个 Python 的 2D绘图库,直方图，功率谱，条形图，错误图，散点图等
import numpy #NumPy 通常与 SciPy（Scientific Python）和 Matplotlib（绘图库）一起使用。 这种组合广泛用于替代 MatLab，是一个流行的技术计算平台。

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
# plt.show()
# plt.savefig('test.pdf', format='pdf')
# plt.savefig('test.jpg', format='jpg')#存成pdf jpg png等格式打开文件后有图像但都是空白的，解决方法：先调用savefig再调用show
plt.savefig('test.jpg', format='jpg')
plt.show() #保存成功

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.猜测 这些参数是在秒点吗

# %%
#test
# a=np.linspace(1,4,6)
fig, ax = plt.subplots() 
# ax.plot(a, a,label='linear')
ax.plot([4,2.5,2,1.5],[2,3,4,5])  #ax.plot()第一个参数列表指定了各个点的y坐标，第二个参数列表指定了各个点的x坐标，第二个参数列表默认是[0,1,2,……]

# %% [markdown]
# 结果是一样的，区别在于：
#
# （1）plt.plot()先生成一个figure画布，然后在这个画布上隐式生成的画图区域上画图
#
# （2）ax.plot()同时生成了fig和ax对象，然后用ax对象在其区域上画图，推荐使用该方式  plt想象成一个画布，ax想象成画布的局部区域

# %%
# OO-style
x = np.linspace(0, 2, 100) #用来创建等差数列 
#linespace()参数
# start:返回样本数据开始点
# stop:返回样本数据结束点
# num:生成的样本数据量，默认为50
# endpoint：True则包含stop；False则不包含stop
# retstep：If True, return (samples, step), where step is the spacing between samples.(即如果为True则结果会给出数据间隔)
# dtype：输出数组类型
# axis：0(默认)或-1

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes(坐标轴)

#理解ax.plot()的参数：
# 只画一条线 ax.plot([x],y,[fmt],data=None,**kwargs)
# 坐标轴里画多条线 ax.plot([x],y,[fmt],[x2],y2,[fmt2],……,**kwargs)
# 可选参数[fmt] 是一个字符串来定义图的基本属性如：颜色（color），点型（marker），线型（linestyle），
# 具体形式  fmt = '[color][marker][line]'

# fmt接收的是每个属性的单个字母缩写，
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend(loc='best')  # Add a legend.   括号里的参数自己找找，出错了，面向对象和面向过程不要混着用
# best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') #r是红色 o是圆圈  定义一个x轴和y轴  o是marker 没有设置marker就只有一条红线
#plt.plot()第一个参数列表是点的x轴坐标，第二个列表是点的y轴坐标
plt.axis([0, 6, 0, 20])   #x轴和y轴的最小和最大
plt.show()

# %% [markdown]
# np.arange()函数返回一个有终点和起点的固定步长的排列，如[1,2,3,4,5]，起点是1，终点是6，步长为1。
#
# 参数个数情况： np.arange()函数分为一个参数，两个参数，三个参数三种情况
#
# 1）一个参数时，参数值为终点，起点取默认值0，步长取默认值1。
#
# 2）两个参数时，第一个参数为起点，第二个参数为终点，步长取默认值1。
#
# 3）三个参数时，第一个参数为起点，第二个参数为终点，第三个参数为步长。其中步长支持小数

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)   #python里用整数 numpy用小数  
#感觉arrange和linspace差不多
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')#x轴 y轴 样式 x轴 y轴 样式……  老师的文件里有style
plt.show()

# %%
plt.plot(t**2, c='C2', ls='-.', marker='*', label='my label')  #color就是c ls是linestyle   c2对应的hexcode在老师那个文件里
plt.legend(loc='best')

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),    #0-50的随机数 生成50份  
        'd': np.random.randn(50)} #一个标准正态分布里随机取50个数 大量数都接近于0
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d',marker='p',data=data)#画散点图 ，c定义成颜色 s是size
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()#画线的函数也可以画点 scatter和plot  scatter可以指定点的大小 颜色  用一样的大小颜色可以用plot 比较快

# %%
#test
x=np.arange(1,10) #注意不是两个r
# y=np.random.randn(50)  ValueError: x and y must be the same size
y=x
plt.scatter(x,y,c='r',marker='*')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))   #面向过程的调法

plt.subplot(131) #一行三列第一幅图
plt.bar(names, values)
plt.subplot(132)#同理
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
# plt.subplot(134)
# plt.scatter(names,values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)  #画三角函数的图 文科生不用
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')  #文字 均值 方差 r不转义 插入特殊希腊字母 $可以去掉  latex语法
plt.axis([40, 160, 0, 0.03])
plt.grid(True)  #显示label的地方都会画一条线
plt.show()

# %%
t = plt.xlabel('my data', fontsize=14, color='red')   #x轴

# %%
plt.title(r'$\sigma_i=15$')
# Out:
# Text(0.5, 1.0, '$\\sigma_i=15$')

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),   #箭头
             )

plt.ylim(-2, 2)
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)   #伪随机数的起始值 传不传都行

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)    #取了1000个数字
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()   #logit机器学习
# Out:
# <ipython-input-68-d048e4a465c1>:30: MatplotlibDeprecationWarning: SymmetricalLogScale got an unexpected keyword argument 'linthresh'. In the future this will raise TypeError
#   plt.yscale('symlog', linthresh=0.01)

# %%
#

# %%
#

# %% [markdown]
# 2. Seaborn seaborn绘图功能

# %% [markdown]
# Seaborn是一个基于matplotlib的Python数据可视化库。它提供了一个高级界面，用于绘制吸引人的信息丰富的统计图形

# %% [markdown]
# 2.1 Similar functions for similar tasks

# %%
import seaborn as sns
import pandas as pd
sns.set_theme(style="darkgrid")

penguins = pd.read_csv("penguins.csv")
tips = pd.read_csv('tips.csv')
fmri = pd.read_csv('fmri.csv')

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %% [markdown]
# 2.2 Figure-level vs. axes-level functions

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack", kind="kde")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %%
# Axes-level functions make self-contained plots¶

f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.8, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()

# %% [markdown]
# 2.3 Visualizing statistical relationships

# %%
sns.relplot(x="total_bill", y="tip", data=tips);
# sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);
# sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker", data=tips);
# sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips);
# sns.relplot(x="total_bill", y="tip", hue="size", data=tips);
# sns.relplot(x="total_bill", y="tip", hue="size", palette="ch:r=-.5,l=.75", data=tips);
# sns.relplot(x="total_bill", y="tip", size="size", data=tips);
# sns.relplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=tips);
# sns.relplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips);

# %%
# More complex datasets will have multiple measurements for the same value of the x variable. 
# The default behavior in seaborn is to aggregate the multiple measurements at each x value by 
# plotting the mean and the 95% confidence interval around the mean:
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);

# The confidence intervals are computed using bootstrapping, which can be time-intensive for 
# larger datasets. It’s therefore possible to disable them:
# sns.relplot(x="timepoint", y="signal", ci=None, kind="line", data=fmri);

# Another good option, especially with larger data, is to represent the spread of the 
# distribution at each timepoint by plotting the standard deviation instead of a confidence 
# interval:
# sns.relplot(x="timepoint", y="signal", kind="line", ci="sd", data=fmri);

# To turn off aggregation altogether, set the estimator parameter to None This might produce 
# a strange effect when the data have multiple observations at each point.
# sns.relplot(x="timepoint", y="signal", estimator=None, kind="line", data=fmri);

# sns.relplot(x="timepoint", y="signal", hue="event", kind="line", data=fmri);

# sns.relplot(x="timepoint", y="signal", hue="region", style="event",
#             dashes=False, markers=True, kind="line", data=fmri);

# sns.relplot(x="timepoint", y="signal", hue="region",
#             units="subject", estimator=None,
#             kind="line", data=fmri.query("event == 'stim'"));

# sns.relplot(x="timepoint", y="signal", hue="subject",
#             col="region", row="event", height=3,
#             kind="line", estimator=None, data=fmri);

# %% [markdown]
# 2.4 Visualizing distributions of data

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.pairplot(data=penguins, hue="species")

# %% [markdown]
# 2.5 Plotting with categorical data

# %%
sns.catplot(x="day", y="total_bill", data=tips)
# sns.catplot(x="day", y="total_bill", kind="box", data=tips)
# sns.catplot(x='day', y='total_bill', kind='bar', hue='sex', data=tips)

# %% [markdown]
# 2.6 Visualizing regression models

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# %%
#

# %%
#

# %% [markdown]
# 3. Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 3.1 Object creation

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.079920 -0.780236  1.517341 -0.703642
# 2013-01-02  0.774538  0.751514 -1.407173  0.511679
# 2013-01-03  0.037125 -0.615317 -1.709978 -0.255202
# 2013-01-04  1.790328 -1.706390 -0.137980  0.687297
# 2013-01-05 -0.079285  1.401738 -0.866924 -0.857064
# 2013-01-06 -1.483742 -1.116068  0.294861  0.634294

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# 3.2 Viewing data

# %%
grads = pd.read_excel('成绩.xlsx', index_col='id')
grads
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120105068      7.0           7.0            6.0    225.0     19.0
# 3120301259     21.0          21.0           20.0    163.0     25.0
# 3120332023     37.0          37.0           35.0    164.0     28.0
# 3120132004     37.0          37.0           36.0    171.0     26.0
# 3120118053    104.0         104.0          101.0    203.0     22.0
# ...             ...           ...            ...      ...      ...
# 3120132011     37.0          37.0           35.0    172.0     27.0
# 3120305403      NaN           NaN            NaN      NaN      3.0
# 3120109017     37.0          30.0           19.0    112.0     12.0
# 20118038        NaN           NaN            NaN      NaN     38.0
# 3120303087     99.0          97.0           94.0    126.0     33.0
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120105068          19.0           18.0    298.0     14.0          14.0
# ...

# %%
grads.head()
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120105068      7.0           7.0            6.0    225.0     19.0
# 3120301259     21.0          21.0           20.0    163.0     25.0
# 3120332023     37.0          37.0           35.0    164.0     28.0
# 3120132004     37.0          37.0           36.0    171.0     26.0
# 3120118053    104.0         104.0          101.0    203.0     22.0
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120105068          19.0           18.0    298.0     14.0          14.0
# 3120301259          24.0           22.0    162.0     27.0          26.0
# 3120332023          28.0           27.0    376.0     94.0          94.0
# 3120132004          26.0           25.0    368.0     57.0          57.0
# 3120118053          22.0           20.0    264.0     67.0          67.0
#
#             valid_cell_03  line_03  cell_04  code_cell_04  valid_cell_04  \
# id
# ...

# %%
grads.tail(3)
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120109017     37.0          30.0           19.0    112.0     12.0
# 20118038        NaN           NaN            NaN      NaN     38.0
# 3120303087     99.0          97.0           94.0    126.0     33.0
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120109017          10.0            3.0     20.0      NaN           NaN
# 20118038            38.0           26.0    372.0      NaN           NaN
# 3120303087          33.0           32.0    155.0      NaN           NaN
#
#             valid_cell_03  line_03  cell_04  code_cell_04  valid_cell_04  \
# id
# 3120109017            NaN      NaN      NaN           NaN            NaN
# 20118038              NaN      NaN      NaN           NaN            NaN
# 3120303087            NaN      NaN      NaN           NaN            NaN
#
#             line_04
# id
# 3120109017      NaN
# 20118038        NaN
# 3120303087      NaN

# %%
grads.index
# Out:
# Int64Index([3120105068, 3120301259, 3120332023, 3120132004, 3120118053,
#             3120305718, 3120132006, 3120301183, 3120303014, 3120305664,
#             3120301047, 3120319111, 3120101220, 3120301223, 3120332025,
#             3120305660, 3120103152, 3120101059, 3120305679, 3120305601,
#             3120332044, 3120319056, 3120101202, 3120101127, 3120101238,
#             3120101019, 3120101240, 4120101106, 3120101221, 3120999178,
#             3120118049, 3120305683, 3120101246, 3120105015, 3120332026,
#             3120301080, 3120305442, 3120118037, 3120101260, 3120103153,
#             3120319071, 3120104196, 3120305579, 3120101244, 3120305689,
#             3120103322, 3120319059, 3120301233, 3120301231, 3120101273,
#             3120101017, 3120301269, 3120101212, 3120118047, 3120305694,
#             3120101074, 3120332011, 3120101015, 3120332035, 3120101271,
#             3120118038, 3120319067, 3120101097, 3120305456, 3120305454,
# ...

# %%
grads.columns
# Out:
# Index(['cell_01', 'code_cell_01', 'valid_cell_01', 'line_01', 'cell_02',
#        'code_cell_02', 'valid_cell_02', 'line_02', 'cell_03', 'code_cell_03',
#        'valid_cell_03', 'line_03', 'cell_04', 'code_cell_04', 'valid_cell_04',
#        'line_04'],
#       dtype='object')

# %%
grads.describe()
# Out:
#           cell_01  code_cell_01  valid_cell_01     line_01     cell_02  \
# count   79.000000     79.000000      79.000000   79.000000   81.000000
# mean    72.000000     69.708861      62.974684  232.772152   43.691358
# std     59.942066     59.264975      51.976320  102.178696   40.684039
# min      1.000000      1.000000       0.000000    0.000000    3.000000
# 25%     29.000000     25.500000      22.000000  167.500000   22.000000
# 50%     54.000000     53.000000      49.000000  222.000000   36.000000
# 75%     96.000000     95.500000      89.500000  286.500000   45.000000
# max    280.000000    280.000000     197.000000  586.000000  201.000000
#
#        code_cell_02  valid_cell_02     line_02     cell_03  code_cell_03  \
# count     81.000000       81.00000   81.000000   78.000000     78.000000
# mean      41.888889       36.37037  264.493827   63.333333     60.884615
# std       39.154182       34.30213  105.482478   47.886410     45.349431
# ...

# %%
grads.sort_index()
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 20118038        NaN           NaN            NaN      NaN     38.0
# 3120101015      7.0           7.0            6.0    131.0      5.0
# 3120101016      4.0           4.0            3.0    236.0     45.0
# 3120101017     12.0          12.0            9.0    139.0      4.0
# 3120101019     23.0          23.0           22.0    162.0     40.0
# ...             ...           ...            ...      ...      ...
# 3120332035     51.0          51.0           49.0    230.0     45.0
# 3120332036     38.0          38.0           32.0    141.0     21.0
# 3120332044     62.0          62.0           60.0    222.0     37.0
# 3120999178     41.0          41.0           40.0    118.0     64.0
# 4120101106     90.0          90.0           87.0    277.0     65.0
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 20118038            38.0           26.0    372.0      NaN           NaN
# ...

# %%
grads.sort_values(by='line_01')
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120101097      1.0           1.0            0.0      0.0      4.0
# 3120305694     18.0          18.0            7.0     42.0      8.0
# 3120301255      4.0           4.0            3.0     71.0     14.0
# 3120101221     22.0          21.0           11.0     76.0     22.0
# 3120305718     27.0          26.0           25.0     98.0     75.0
# ...             ...           ...            ...      ...      ...
# 3120101238     74.0          74.0           70.0    514.0      3.0
# 3120301223    203.0         203.0          195.0    586.0    201.0
# 3120319071      NaN           NaN            NaN      NaN     12.0
# 3120305403      NaN           NaN            NaN      NaN      3.0
# 20118038        NaN           NaN            NaN      NaN     38.0
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120101097           4.0            0.0      0.0      1.0           1.0
# ...

# %% [markdown]
# 3.3 Selection

# %% [markdown]
# 3.3.1 Getting

# %%
grads[['line_01', 'line_02']]
# Out:
#             line_01  line_02
# id
# 3120105068    225.0    298.0
# 3120301259    163.0    162.0
# 3120332023    164.0    376.0
# 3120132004    171.0    368.0
# 3120118053    203.0    264.0
# ...             ...      ...
# 3120132011    172.0    351.0
# 3120305403      NaN     73.0
# 3120109017    112.0     20.0
# 20118038        NaN    372.0
# 3120303087    126.0    155.0
#
# [82 rows x 2 columns]

# %%
grads[0:3]
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120105068      7.0           7.0            6.0    225.0     19.0
# 3120301259     21.0          21.0           20.0    163.0     25.0
# 3120332023     37.0          37.0           35.0    164.0     28.0
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120105068          19.0           18.0    298.0     14.0          14.0
# 3120301259          24.0           22.0    162.0     27.0          26.0
# 3120332023          28.0           27.0    376.0     94.0          94.0
#
#             valid_cell_03  line_03  cell_04  code_cell_04  valid_cell_04  \
# id
# 3120105068           14.0    201.0     14.0          14.0           14.0
# 3120301259           25.0    204.0     19.0          19.0           18.0
# 3120332023           93.0    521.0      NaN           NaN            NaN
#
#             line_04
# id
# 3120105068    203.0
# 3120301259    191.0
# 3120332023      NaN

# %% [markdown]
# 3.3.2 Selection by label

# %%
grads.loc[[3120332023, 3120301259], ['line_01', 'line_02']]
# Out:
#             line_01  line_02
# id
# 3120332023    164.0    376.0
# 3120301259    163.0    162.0

# %%
grads.at[3120301259, 'line_01']
# Out:
# 163.0

# %% [markdown]
# 3.3.3 Selection by position

# %%
grads.iloc[[1, 3], [2, 4]]
# Out:
#             valid_cell_01  cell_02
# id
# 3120301259           20.0     25.0
# 3120132004           36.0     26.0

# %%
grads.iat[1, 1]
# Out:
# 21.0

# %% [markdown]
# 3.3.4 Boolean indexing

# %%
grads[grads['line_01'] >= 200]
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120105068      7.0           7.0            6.0    225.0     19.0
# 3120118053    104.0         104.0          101.0    203.0     22.0
# 3120301183     76.0          76.0           71.0    292.0     26.0
# 3120303014    129.0         129.0          116.0    281.0     66.0
# 3120305664    156.0         147.0          142.0    389.0     37.0
# 3120301047     57.0          56.0           55.0    307.0     41.0
# 3120319111    182.0         182.0          162.0    214.0    196.0
# 3120301223    203.0         203.0          195.0    586.0    201.0
# 3120332025    280.0         280.0          185.0    307.0     20.0
# 3120103152    125.0         125.0          120.0    363.0     45.0
# 3120305679     62.0          62.0           61.0    278.0     28.0
# 3120332044     62.0          62.0           60.0    222.0     37.0
# 3120101238     74.0          74.0           70.0    514.0      3.0
# ...

# %%
grads['line_01'] >= 200
# Out:
# id
# 3120105068     True
# 3120301259    False
# 3120332023    False
# 3120132004    False
# 3120118053     True
#               ...
# 3120132011    False
# 3120305403    False
# 3120109017    False
# 20118038      False
# 3120303087    False
# Name: line_01, Length: 82, dtype: bool

# %%
grads[grads == np.nan]  #再看一下
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120105068      NaN           NaN            NaN      NaN      NaN
# 3120301259      NaN           NaN            NaN      NaN      NaN
# 3120332023      NaN           NaN            NaN      NaN      NaN
# 3120132004      NaN           NaN            NaN      NaN      NaN
# 3120118053      NaN           NaN            NaN      NaN      NaN
# ...             ...           ...            ...      ...      ...
# 3120132011      NaN           NaN            NaN      NaN      NaN
# 3120305403      NaN           NaN            NaN      NaN      NaN
# 3120109017      NaN           NaN            NaN      NaN      NaN
# 20118038        NaN           NaN            NaN      NaN      NaN
# 3120303087      NaN           NaN            NaN      NaN      NaN
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120105068           NaN            NaN      NaN      NaN           NaN
# ...

# %% [markdown]
# 3.3.5 Setting

# %%
grads.iat[1, 1] = 0
grads.iat[1, 1]
# Out:
# 0.0

# %%
grads.loc[:, 'line_01'] = np.array([200] * len(grads))
grads.loc[:, 'line_01']
# Out:
# id
# 3120105068    200
# 3120301259    200
# 3120332023    200
# 3120132004    200
# 3120118053    200
#              ...
# 3120132011    200
# 3120305403    200
# 3120109017    200
# 20118038      200
# 3120303087    200
# Name: line_01, Length: 82, dtype: int32

# %%
grads['total'] = np.nan
grads['total']
# Out:
# id
# 3120105068   NaN
# 3120301259   NaN
# 3120332023   NaN
# 3120132004   NaN
# 3120118053   NaN
#               ..
# 3120132011   NaN
# 3120305403   NaN
# 3120109017   NaN
# 20118038     NaN
# 3120303087   NaN
# Name: total, Length: 82, dtype: float64

# %% [markdown]
# 3.4 Missing data

# %%
good = grads.dropna(how='any')
good.shape
# Out:
# (0, 17)

# %%
grads['line_01'].fillna(value=1000)
# Out:
# id
# 3120105068    200
# 3120301259    200
# 3120332023    200
# 3120132004    200
# 3120118053    200
#              ...
# 3120132011    200
# 3120305403    200
# 3120109017    200
# 20118038      200
# 3120303087    200
# Name: line_01, Length: 82, dtype: int32

# %%
grads.isna()
# Out:
#             cell_01  code_cell_01  valid_cell_01  line_01  cell_02  \
# id
# 3120105068    False         False          False    False    False
# 3120301259    False         False          False    False    False
# 3120332023    False         False          False    False    False
# 3120132004    False         False          False    False    False
# 3120118053    False         False          False    False    False
# ...             ...           ...            ...      ...      ...
# 3120132011    False         False          False    False    False
# 3120305403     True          True           True    False    False
# 3120109017    False         False          False    False    False
# 20118038       True          True           True    False    False
# 3120303087    False         False          False    False    False
#
#             code_cell_02  valid_cell_02  line_02  cell_03  code_cell_03  \
# id
# 3120105068         False          False    False    False         False
# ...

# %% [markdown]
# 3.5 Operations

# %% [markdown]
# 3.5.1 Stats

# %%
grads.mean()
# Out:
# cell_01           72.000000
# code_cell_01      69.443038
# valid_cell_01     62.974684
# line_01          200.000000
# cell_02           43.691358
# code_cell_02      41.888889
# valid_cell_02     36.370370
# line_02          264.493827
# cell_03           63.333333
# code_cell_03      60.884615
# valid_cell_03     57.500000
# line_03          297.089744
# cell_04           41.969231
# code_cell_04      40.507692
# valid_cell_04     37.446154
# line_04          403.846154
# total                   NaN
# dtype: float64

# %%
grads.mean(1)
# Out:
# id
# 3120105068     66.375000
# 3120301259     62.687500
# 3120332023    130.833333
# 3120132004     97.916667
# 3120118053    113.875000
#                  ...
# 3120132011    125.187500
# 3120305403     55.777778
# 3120109017     41.375000
# 20118038      134.800000
# 3120303087     92.875000
# Length: 82, dtype: float64

# %% [markdown]
# 3.5.2 Apply

# %%
grads['total'] = grads[['line_01', 'line_02', 'line_03', 'line_04']].apply(np.sum, axis=1)
grads['total']
# Out:
# id
# 3120105068     902.0
# 3120301259     757.0
# 3120332023    1097.0
# 3120132004     818.0
# 3120118053    1149.0
#                ...
# 3120132011    1451.0
# 3120305403     480.0
# 3120109017     220.0
# 20118038       572.0
# 3120303087     355.0
# Name: total, Length: 82, dtype: float64

# %%
grads.groupby('cell_01').sum()
# Out:
#          code_cell_01  valid_cell_01  line_01  cell_02  code_cell_02  \
# cell_01
# 1.0               1.0            0.0      200      4.0           4.0
# 4.0               8.0            6.0      400     59.0          45.0
# 7.0              14.0           12.0      400     24.0          24.0
# 10.0             10.0            9.0      200      3.0           3.0
# 11.0             11.0            9.0      200     19.0          19.0
# ...               ...            ...      ...      ...           ...
# 202.0           202.0          183.0      200     47.0          47.0
# 203.0           203.0          195.0      200    201.0         201.0
# 204.0           204.0          197.0      200     43.0          43.0
# 244.0           213.0          163.0      200    171.0         131.0
# 280.0           280.0          185.0      200     20.0          20.0
#
#          valid_cell_02  line_02  cell_03  code_cell_03  valid_cell_03  \
# cell_01
# ...

# %% [markdown]
# 3.5.3 Save

# %%
grads.to_excel('new_grads.xlsx')
