# %%
c = input("请输入一个字符: ")
a = int(input("请输入一个ASCII码: "))
 
print( c + " 的ASCII 码为", ord(c))
print( a , " 对应的字符为", chr(a))
# Out:
# 请输入一个字符:  c
# 请输入一个ASCII码:  202
# c 的ASCII 码为 99
# 202  对应的字符为 Ê

# %%
import calendar
monthRange = calendar.monthrange(2077,9)
print(monthRange)
#第一个输出星期几，第二个输出天数
# Out:
# (2, 30)

# %%
# 30 个人在一条船上，超载，需要 15 人下船。
# 于是人们排成一队，排队的位置即为他们的编号。
# 报数，从 1 开始，数到 9 的人下船。
# 如此循环，直到船上仅剩 15 人为止，问都有哪些编号的人下船了呢？
people={}
for x in range(1,31):
    people[x]=1
# print(people)
check=0
i=1
j=0
while i<=31:
    if i == 31:
        i=1
    elif j == 15:
        break
    else:
        if people[i] == 0:
            i+=1
            continue
        else:
            check+=1
            if check == 9:
                people[i]=0
                check = 0
                print("{}号下船了".format(i))
                j+=1
            else:
                i+=1
                continue
# Out:
# 9号下船了
# 18号下船了
# 27号下船了
# 6号下船了
# 16号下船了
# 26号下船了
# 7号下船了
# 19号下船了
# 30号下船了
# 12号下船了
# 24号下船了
# 8号下船了
# 22号下船了
# 5号下船了
# 23号下船了

# %%
# A、B、C、D、E 五人在某天夜里合伙去捕鱼，到第二天凌晨时都疲惫不堪，于是各自找地方睡觉。
# 日上三杆，A 第一个醒来，他将鱼分为五份，把多余的一条鱼扔掉，拿走自己的一份。
# B 第二个醒来，也将鱼分为五份，把多余的一条鱼扔掉拿走自己的一份。 。
# C、D、E依次醒来，也按同样的方法拿鱼。
# 问他们至少捕了多少条鱼?
def main():
    fish = 1
    while True:
        total, enough = fish, True
        for _ in range(6):
            if (total - 1) % 5 == 0:
                total = (total - 1)  //  5 * 4
            else:
                enough = False
                break
        if enough:
            print(f'总共有{fish}条鱼')
            break
        fish += 1


if __name__ == '__main__':
    main()
# Out:
# 总共有15621条鱼

# %%
#插入排序
def insertionSort(arr): 
  
    for i in range(1, len(arr)): 
  
        key = arr[i] 
  
        j = i-1
        while j >=0 and key < arr[j] : 
                arr[j+1] = arr[j] 
                j -= 1
        arr[j+1] = key 
  
  
arr = [10, 11, 13, 5, 6, 12, 15, 19, 20] 
insertionSort(arr) 
print ("排序后的数组:") 
for i in range(len(arr)): 
    print ("%d" %arr[i])
# Out:
# 排序后的数组:
# 5
# 6
# 10
# 11
# 12
# 13
# 15
# 19
# 20

# %%
#快速排序
def partition(arr,low,high): 
    i = ( low-1 )         # 最小元素索引
    pivot = arr[high]     
  
    for j in range(low , high): 
  
        # 当前元素小于或等于 pivot 
        if   arr[j] <= pivot: 
          
            i = i+1 
            arr[i],arr[j] = arr[j],arr[i] 
  
    arr[i+1],arr[high] = arr[high],arr[i+1] 
    return ( i+1 ) 

def quickSort(arr,low,high): 
    if low < high: 
  
        pi = partition(arr,low,high) 
  
        quickSort(arr, low, pi-1) 
        quickSort(arr, pi+1, high) 
  
arr = [10, 7, 8, 9, 1, 85,42,43] 
n = len(arr) 
quickSort(arr,0,n-1) 
print ("排序后的数组:") 
for i in range(n): 
    print ("%d" %arr[i]),
# Out:
# 排序后的数组:
# 1
# 7
# 8
# 9
# 10
# 42
# 43
# 85

# %%
#选择排序
import sys 
A = [64, 25, 47, 22, 11] 
  
for i in range(len(A)): 
      
   
    min_idx = i 
    for j in range(i+1, len(A)): 
        if A[min_idx] > A[j]: 
            min_idx = j 
                
    A[i], A[min_idx] = A[min_idx], A[i] 
  
print ("排序后的数组：") 
for i in range(len(A)): 
    print("%d" %A[i]),
# Out:
# 排序后的数组：
# 11
# 22
# 25
# 47
# 64

# %%
#冒泡排序
def bubbleSort(arr):
    n = len(arr)
 
    # 遍历所有数组元素
    for i in range(n):
 
        # Last i elements are already in place
        for j in range(0, n-i-1):
 
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]
 
arr = [64, 34, 25, 12, 22, 11, 90]
 
bubbleSort(arr)
 
print ("排序后的数组:")
for i in range(len(arr)):
    print ("%d" %arr[i]),
# Out:
# 排序后的数组:
# 11
# 12
# 22
# 25
# 34
# 64
# 90

# %%
list1 = [10, 20, 1, 45, 99]
 
print("最小元素为:", min(list1))
# Out:
# 最小元素为: 1

# %%
list1 = [10, 20, 1, 45, 99]
 
print("最大元素为:", max(list1))
# Out:
# 最大元素为: 99

# %%
# 模拟淘宝客服自动回复
def find_answer(question):
    with open('reply.txt','r') as f :
         while True:
            line=f.readline()
            if  not line:   
                break
            keyword=line.split('|')[0]
            reply=line.split('|')[1]
            if keyword in question:
                     return reply
         return '对不起，没有你想要找的问题'
          
if __name__ =='__main__':
        question=input('请输入想要提问的内容：')
        while True:
            if question=='bye':
                break
            reply=find_answer(question)
            if not reply:
                question=input("小蜜不懂您在说什么，您可以问一些与订单、账户和支付相关的内容（退出请输入bye）：")
            else:
                print(reply)
                question=input("您可以问一些与订单、账户和支付相关的内容（退出请输入bye）：")
            print('谢谢，再见！')
# Out:
# 请输入想要提问的内容： 你在哪
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-81424dabca75> in <module>
#      17             if question=='bye':
#      18                 break
# ---> 19             reply=find_answer(question)
#      20             if not reply:
#      21                 question=input("小蜜不懂您在说什么，您可以问一些与订单、账户和支付相关的内容（退出请输入bye）：")
#
# <ipython-input-35-81424dabca75> in find_answer(question)
#       1 # 模拟淘宝客服自动回复
#       2 def find_answer(question):
# ----> 3     with open('reply.txt','r') as f :
#       4          while True:
#       5             line=f.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'reply.txt'

# %%
import re
str_test='abcdefgHABC123456中华民族'

num_regex = re.compile(r'[0-9]')
zimu_regex = re.compile(r'[a-zA-z]')
hanzi_regex = re.compile(r'[\u4E00-\u9FA5]')

print('输入字符串:',str_test)
num_list = num_regex.findall(str_test)
print('包含的数字:',num_list)
zimu_list = zimu_regex.findall(str_test)
print('包含的字母:',zimu_list)
hanzi_list = hanzi_regex.findall(str_test)
print('包含的汉字:',hanzi_list)
# Out:
# 输入字符串: abcdefgHABC123456中华民族
# 包含的数字: ['1', '2', '3', '4', '5', '6']
# 包含的字母: ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'H', 'A', 'B', 'C']
# 包含的汉字: ['中', '华', '民', '族']

# %%
for i in range(1,10):
    for j in range(1,10-i):
         print(end='       ')   
    for k in  range(1,i+1):
         print("%d*%d=%2d"%(k,i,k*i),end=' ')
    print("")
# Out:
#                                                         1*1= 1
#                                                  1*2= 2 2*2= 4
#                                           1*3= 3 2*3= 6 3*3= 9
#                                    1*4= 4 2*4= 8 3*4=12 4*4=16
#                             1*5= 5 2*5=10 3*5=15 4*5=20 5*5=25
#                      1*6= 6 2*6=12 3*6=18 4*6=24 5*6=30 6*6=36
#               1*7= 7 2*7=14 3*7=21 4*7=28 5*7=35 6*7=42 7*7=49
#        1*8= 8 2*8=16 3*8=24 4*8=32 5*8=40 6*8=48 7*8=56 8*8=64
# 1*9= 9 2*9=18 3*9=27 4*9=36 5*9=45 6*9=54 7*9=63 8*9=72 9*9=81

# %%
import pygame
from pygame.locals import *
import random
import time,sys

# 游戏对象的类 surface:表示图片 rect: 坐标属性，
class SnakeNibble:
    """移动蛇，当蛇吃果子时，身体会变大，撞墙或者撞到自己时游戏结束"""
    def __init__(self,width=400,edge=20):
        self.width = self.height = 400 # 屏幕尺寸
        self.edge = edge # 蛇的格子尺寸
        self.ball = pygame.Surface((edge, edge)) # Surface对象
    
    def makeSnake(self):
        '''创建蛇 初始方向 右'''
        self.ball.fill((220,20,60)) # 红色
        ballrect = self.ball.get_rect() # 获取 rect 对象
        a = self.edge * 5
        snake = []
        for i in range(3):
            ballrect2 = ballrect.copy() 
            ballrect2.left += a
            ballrect2.top = 100
            a -= self.edge
            snake.append(ballrect2)
        return snake

    def move(self,snake,direct):
        """按照方向移动 并返回更新之前 snake 的尾巴"""
        for i in range(len(snake)):
            if i==0: # 每次只更新队列第一个的方向，其他方向照旧
                rect = snake[0].copy()
                temp = self._get_nextRect(rect,direct)
        snake.insert(0,temp) # 加入头部的新位置
        endPop = snake.pop() # 删除末尾
        return endPop

    def strike(self,snake,food):
        '''蛇的撞击检测
        ：param snake：蛇的 Rect 对象序列
        ：param food：食物的 Rect 对像
        ：return ：撞墙，撞自己返回 0,代表游戏结束,吃果子返回 1，无碰撞返回 3
        '''
        # 撞墙
        if snake[0].left < 0 or snake[0].right > self.width: return 0
        if snake[0].top < 0 or snake[0].bottom > self.height: return 0
        # 撞自己
        for sr in snake[1:]:
            if sr.colliderect(snake[0]):
                return 0
        # 吃食物
        if food.colliderect(snake[0]):
            return 1
        return 2 

    def _get_nextRect(self,rect,direct):
        """蛇 获取头部的新位置"""
        if direct == 0: rect.top += self.edge # 向下
        elif direct == 1: rect.top -= self.edge # 向上
        elif direct == 2: rect.left += self.edge # 向右
        elif direct == 3: rect.left -= self.edge # 向左
        return rect
        
 
class Food:
    """位置随机生成的食物"""
    def __init__(self,width=400,edge=20):
        self.width = self.height = 400
        self.edge = edge
        self.food = pygame.Surface((self.edge, self.edge)) # surface 对象

    def get_food(self):
        """生成食物 rect 对象"""
        self.food.fill((0,0,255)) # 蓝色
        fr = self.food.get_rect() 
        return fr
    
    def get_foodpos(self,food,snake):
        '''获取食物新位置'''
        while True:
            food.left, food.top = random.randrange(self.edge,self.height,self.edge),random.randrange(self.edge,self.height,self.edge) # 更新 fr 的位置
            foodpos = True
            for sn in snake: # 食物更新位置不能在蛇的身体内部
                if food.colliderect(sn):
                    foodpos = False
                    break
            if foodpos == True:
                break
        if foodpos == True: # 有位置
            return True

class Background:
    def __init__(self,width=400,edge=20):
        self.width = self.height = 400
        self.edge = edge
        self.scoref = pygame.font.SysFont('Arial', 30) # 字体对象

    def drawGrid(self,surface):
        # 画全屏幕格子线条
        rows = self.width // self.edge
        sizeBtwn = self.edge
        x,y = 0,0
        for _ in range(rows):
            x += sizeBtwn
            y += sizeBtwn
            pygame.draw.line(surface,(219,112,147),(x,0),(x,self.width))
            pygame.draw.line(surface, (219,112,147),(0,y),(self.width,y))

def main(best):
    """初始化并在循环中运行直到有返回"""
    # 初始化
    pygame.init()
    direct = 2 # 初始方向 右. 向上 1，向下 0，向左 3，向右 2
    validDirect = direct # 有效速度
    edge = 20 # 格子尺寸
    black = 0,0,0 # 背景颜色
    width,height = 400,400 # 窗口尺寸
    screen = pygame.display.set_mode((width,height)) # 初始化一个窗口
    pygame.display.set_caption('Snake')
    
    # 对象准备
    # 蛇
    s = SnakeNibble(width,edge) # 蛇身体尺寸=格子尺寸
    snake = s.makeSnake() # 创建蛇 生成 rect 序列
    # 食物
    f = Food(width,edge) # 食物格子尺寸=格子尺寸
    foodr = f.get_food() # 生成 rect 对象
    f.get_foodpos(foodr,snake) # 随机生成食物位置
    # 格子
    b = Background(width,edge)

    c = 0 # 计数
    dt = 0 # 计时
    score = 0 # 得分
    going = True # 状态
    endPop = None # snake 尾巴
    interval = 300 # 每 interval 毫秒移动 10 个像素位置。速率 1/30，间隔越小游戏运行越快 #----------------------------1 移动的时间间隔，越小速度越快-------------------
    clock = pygame.time.Clock() # 创建帮助记录时间的对象
    while going:
        lastt = clock.tick(60) # 帧率 60
        dt += lastt # 累计时间
        c += 1
        print('循环次数 %d, 前一次的时间 %d，目前总时间 %d 单位毫秒'%(c,lastt,dt)) # 游戏帧率
        # 0 键盘按压等事件响应
        for event in pygame.event.get():
            if event.type == pygame.QUIT: sys.exit()
            elif event.type == KEYDOWN:
                if event.key == K_UP and validDirect != 0: direct = 1 # 按了向上 1 并且当前方向不是向下 0 ，则向上
                elif event.key == K_DOWN and validDirect != 1: direct = 0 # 向上 1 ，向下 0
                elif event.key == K_LEFT and validDirect != 2: direct = 3 # 向左 3， 向右 2
                elif event.key == K_RIGHT and validDirect != 3: direct = 2 

        # 0.1 画全屏的黑色背景
        screen.fill(black)
        # 1 判断是否移动
        if dt > interval: # 移动的时间间隔
            validDirect = direct
            dt = 0 # 初始化时间
            endPop = s.move(snake,direct)
        # 1.1 画蛇
        for i in snake:
            screen.blit(s.ball, i)
        
        # 2 画线条
        b.drawGrid(screen) # ------------------------------------------------------------------------------------2 若不显示格子，则注释掉这句话就行了-------------
        # 3.1 分数更新
        scoret=b.scoref.render(str(score), True, (255, 255, 255)) # 实时得分
        screen.blit(scoret, (0, 0)) # 实时分数
        scoret2=b.scoref.render('best:'+str(best), True, (255, 255, 255)) # 最佳得分
        screen.blit(scoret2, (width-6*edge, 0)) # 最佳分数
        # 3.2 食物
        screen.blit(f.food, foodr) # 根据 fr(Rect 对象) 更新 food(Surface 对象) 位置 ，绘图
        # 4 判断撞击
        clli = s.strike(snake,foodr)
        if clli == 0: # 撞墙 撞自己
            going = False
        elif clli == 1: # 吃果实
            snake.append(endPop) # 长尾巴
            score += 1
            if not f.get_foodpos(foodr,snake): going = False # 生成 food 新位置, 如果占满全屏，则退出
        # 5 屏幕刷新
        pygame.display.flip() # 显示图形
    
    # 游戏最佳记录
    if score > best:
        return score
    else:
        return best
                
if __name__ == '__main__':
    best = 0 # 本次游戏的最佳分数
    while True:
        best = main(best) 
        time.sleep(1)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 循环次数 1, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 2, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 3, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 4, 前一次的时间 17，目前总时间 65 单位毫秒
# 循环次数 5, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 6, 前一次的时间 17，目前总时间 98 单位毫秒
# 循环次数 7, 前一次的时间 17，目前总时间 115 单位毫秒
# 循环次数 8, 前一次的时间 17，目前总时间 132 单位毫秒
# 循环次数 9, 前一次的时间 17，目前总时间 149 单位毫秒
# 循环次数 10, 前一次的时间 17，目前总时间 166 单位毫秒
# 循环次数 11, 前一次的时间 17，目前总时间 183 单位毫秒
# 循环次数 12, 前一次的时间 17，目前总时间 200 单位毫秒
# 循环次数 13, 前一次的时间 17，目前总时间 217 单位毫秒
# 循环次数 14, 前一次的时间 17，目前总时间 234 单位毫秒
# 循环次数 15, 前一次的时间 17，目前总时间 251 单位毫秒
# 循环次数 16, 前一次的时间 16，目前总时间 267 单位毫秒
# 循环次数 17, 前一次的时间 17，目前总时间 284 单位毫秒
# 循环次数 18, 前一次的时间 17，目前总时间 301 单位毫秒
# 循环次数 19, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 20, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 21, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 22, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 23, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 24, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 25, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 26, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 27, 前一次的时间 17，目前总时间 145 单位毫秒
# 循环次数 28, 前一次的时间 17，目前总时间 162 单位毫秒
# 循环次数 29, 前一次的时间 17，目前总时间 179 单位毫秒
# 循环次数 30, 前一次的时间 17，目前总时间 196 单位毫秒
# 循环次数 31, 前一次的时间 17，目前总时间 213 单位毫秒
# 循环次数 32, 前一次的时间 17，目前总时间 230 单位毫秒
# 循环次数 33, 前一次的时间 17，目前总时间 247 单位毫秒
# 循环次数 34, 前一次的时间 17，目前总时间 264 单位毫秒
# 循环次数 35, 前一次的时间 17，目前总时间 281 单位毫秒
# 循环次数 36, 前一次的时间 17，目前总时间 298 单位毫秒
# 循环次数 37, 前一次的时间 17，目前总时间 315 单位毫秒
# 循环次数 38, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 39, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 40, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 41, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 42, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 43, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 44, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 45, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 46, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 47, 前一次的时间 17，目前总时间 161 单位毫秒
# 循环次数 48, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 49, 前一次的时间 16，目前总时间 193 单位毫秒
# 循环次数 50, 前一次的时间 17，目前总时间 210 单位毫秒
# 循环次数 51, 前一次的时间 17，目前总时间 227 单位毫秒
# 循环次数 52, 前一次的时间 16，目前总时间 243 单位毫秒
# 循环次数 53, 前一次的时间 17，目前总时间 260 单位毫秒
# 循环次数 54, 前一次的时间 17，目前总时间 277 单位毫秒
# 循环次数 55, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 56, 前一次的时间 17，目前总时间 311 单位毫秒
# 循环次数 57, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 58, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 59, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 60, 前一次的时间 16，目前总时间 67 单位毫秒
# 循环次数 61, 前一次的时间 16，目前总时间 83 单位毫秒
# 循环次数 62, 前一次的时间 16，目前总时间 99 单位毫秒
# 循环次数 63, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 64, 前一次的时间 17，目前总时间 132 单位毫秒
# 循环次数 65, 前一次的时间 17，目前总时间 149 单位毫秒
# 循环次数 66, 前一次的时间 17，目前总时间 166 单位毫秒
# 循环次数 67, 前一次的时间 17，目前总时间 183 单位毫秒
# 循环次数 68, 前一次的时间 17，目前总时间 200 单位毫秒
# 循环次数 69, 前一次的时间 17，目前总时间 217 单位毫秒
# 循环次数 70, 前一次的时间 17，目前总时间 234 单位毫秒
# 循环次数 71, 前一次的时间 17，目前总时间 251 单位毫秒
# 循环次数 72, 前一次的时间 17，目前总时间 268 单位毫秒
# 循环次数 73, 前一次的时间 17，目前总时间 285 单位毫秒
# 循环次数 74, 前一次的时间 17，目前总时间 302 单位毫秒
# 循环次数 75, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 76, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 77, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 78, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 79, 前一次的时间 17，目前总时间 82 单位毫秒
# 循环次数 80, 前一次的时间 16，目前总时间 98 单位毫秒
# 循环次数 81, 前一次的时间 17，目前总时间 115 单位毫秒
# 循环次数 82, 前一次的时间 17，目前总时间 132 单位毫秒
# 循环次数 83, 前一次的时间 17，目前总时间 149 单位毫秒
# 循环次数 84, 前一次的时间 17，目前总时间 166 单位毫秒
# 循环次数 85, 前一次的时间 16，目前总时间 182 单位毫秒
# 循环次数 86, 前一次的时间 16，目前总时间 198 单位毫秒
# 循环次数 87, 前一次的时间 16，目前总时间 214 单位毫秒
# 循环次数 88, 前一次的时间 16，目前总时间 230 单位毫秒
# 循环次数 89, 前一次的时间 16，目前总时间 246 单位毫秒
# 循环次数 90, 前一次的时间 17，目前总时间 263 单位毫秒
# 循环次数 91, 前一次的时间 17，目前总时间 280 单位毫秒
# 循环次数 92, 前一次的时间 16，目前总时间 296 单位毫秒
# 循环次数 93, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 94, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 95, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 96, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 97, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 98, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 99, 前一次的时间 17，目前总时间 102 单位毫秒
# 循环次数 100, 前一次的时间 17，目前总时间 119 单位毫秒
# 循环次数 101, 前一次的时间 17，目前总时间 136 单位毫秒
# 循环次数 102, 前一次的时间 17，目前总时间 153 单位毫秒
# 循环次数 103, 前一次的时间 17，目前总时间 170 单位毫秒
# 循环次数 104, 前一次的时间 16，目前总时间 186 单位毫秒
# 循环次数 105, 前一次的时间 16，目前总时间 202 单位毫秒
# 循环次数 106, 前一次的时间 16，目前总时间 218 单位毫秒
# 循环次数 107, 前一次的时间 16，目前总时间 234 单位毫秒
# 循环次数 108, 前一次的时间 16，目前总时间 250 单位毫秒
# 循环次数 109, 前一次的时间 16，目前总时间 266 单位毫秒
# 循环次数 110, 前一次的时间 16，目前总时间 282 单位毫秒
# 循环次数 111, 前一次的时间 17，目前总时间 299 单位毫秒
# 循环次数 112, 前一次的时间 16，目前总时间 315 单位毫秒
# 循环次数 113, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 114, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 115, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 116, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 117, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 118, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 119, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 120, 前一次的时间 17，目前总时间 135 单位毫秒
# 循环次数 121, 前一次的时间 17，目前总时间 152 单位毫秒
# 循环次数 122, 前一次的时间 17，目前总时间 169 单位毫秒
# 循环次数 123, 前一次的时间 16，目前总时间 185 单位毫秒
# 循环次数 124, 前一次的时间 16，目前总时间 201 单位毫秒
# 循环次数 125, 前一次的时间 16，目前总时间 217 单位毫秒
# 循环次数 126, 前一次的时间 16，目前总时间 233 单位毫秒
# 循环次数 127, 前一次的时间 16，目前总时间 249 单位毫秒
# 循环次数 128, 前一次的时间 16，目前总时间 265 单位毫秒
# 循环次数 129, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 130, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 131, 前一次的时间 16，目前总时间 313 单位毫秒
# 循环次数 132, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 133, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 134, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 135, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 136, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 137, 前一次的时间 17，目前总时间 97 单位毫秒
# 循环次数 138, 前一次的时间 17，目前总时间 114 单位毫秒
# 循环次数 139, 前一次的时间 17，目前总时间 131 单位毫秒
# 循环次数 140, 前一次的时间 17，目前总时间 148 单位毫秒
# 循环次数 141, 前一次的时间 17，目前总时间 165 单位毫秒
# 循环次数 142, 前一次的时间 17，目前总时间 182 单位毫秒
# 循环次数 143, 前一次的时间 17，目前总时间 199 单位毫秒
# 循环次数 144, 前一次的时间 17，目前总时间 216 单位毫秒
# 循环次数 145, 前一次的时间 17，目前总时间 233 单位毫秒
# 循环次数 146, 前一次的时间 17，目前总时间 250 单位毫秒
# 循环次数 147, 前一次的时间 16，目前总时间 266 单位毫秒
# 循环次数 148, 前一次的时间 16，目前总时间 282 单位毫秒
# 循环次数 149, 前一次的时间 16，目前总时间 298 单位毫秒
# 循环次数 150, 前一次的时间 17，目前总时间 315 单位毫秒
# 循环次数 151, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 152, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 153, 前一次的时间 17，目前总时间 49 单位毫秒
# 循环次数 154, 前一次的时间 17，目前总时间 66 单位毫秒
# 循环次数 155, 前一次的时间 17，目前总时间 83 单位毫秒
# 循环次数 156, 前一次的时间 17，目前总时间 100 单位毫秒
# 循环次数 157, 前一次的时间 17，目前总时间 117 单位毫秒
# 循环次数 158, 前一次的时间 16，目前总时间 133 单位毫秒
# 循环次数 159, 前一次的时间 17，目前总时间 150 单位毫秒
# 循环次数 160, 前一次的时间 17，目前总时间 167 单位毫秒
# 循环次数 161, 前一次的时间 17，目前总时间 184 单位毫秒
# 循环次数 162, 前一次的时间 17，目前总时间 201 单位毫秒
# 循环次数 163, 前一次的时间 17，目前总时间 218 单位毫秒
# 循环次数 164, 前一次的时间 16，目前总时间 234 单位毫秒
# 循环次数 165, 前一次的时间 16，目前总时间 250 单位毫秒
# 循环次数 166, 前一次的时间 16，目前总时间 266 单位毫秒
# 循环次数 167, 前一次的时间 16，目前总时间 282 单位毫秒
# 循环次数 168, 前一次的时间 16，目前总时间 298 单位毫秒
# 循环次数 169, 前一次的时间 16，目前总时间 314 单位毫秒
# 循环次数 170, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 171, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 172, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 173, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 174, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 175, 前一次的时间 16，目前总时间 100 单位毫秒
# 循环次数 176, 前一次的时间 16，目前总时间 116 单位毫秒
# 循环次数 177, 前一次的时间 16，目前总时间 132 单位毫秒
# 循环次数 178, 前一次的时间 16，目前总时间 148 单位毫秒
# 循环次数 179, 前一次的时间 17，目前总时间 165 单位毫秒
# 循环次数 180, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 181, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 182, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 183, 前一次的时间 16，目前总时间 229 单位毫秒
# 循环次数 184, 前一次的时间 16，目前总时间 245 单位毫秒
# 循环次数 185, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 186, 前一次的时间 16，目前总时间 278 单位毫秒
# 循环次数 187, 前一次的时间 17，目前总时间 295 单位毫秒
# 循环次数 188, 前一次的时间 16，目前总时间 311 单位毫秒
# 循环次数 189, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 190, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 191, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 192, 前一次的时间 16，目前总时间 66 单位毫秒
# 循环次数 193, 前一次的时间 16，目前总时间 82 单位毫秒
# 循环次数 194, 前一次的时间 17，目前总时间 99 单位毫秒
# 循环次数 195, 前一次的时间 17，目前总时间 116 单位毫秒
# 循环次数 196, 前一次的时间 16，目前总时间 132 单位毫秒
# 循环次数 197, 前一次的时间 17，目前总时间 149 单位毫秒
# 循环次数 198, 前一次的时间 16，目前总时间 165 单位毫秒
# 循环次数 199, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 200, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 201, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 202, 前一次的时间 17，目前总时间 230 单位毫秒
# 循环次数 203, 前一次的时间 17，目前总时间 247 单位毫秒
# 循环次数 204, 前一次的时间 17，目前总时间 264 单位毫秒
# 循环次数 205, 前一次的时间 17，目前总时间 281 单位毫秒
# 循环次数 206, 前一次的时间 17，目前总时间 298 单位毫秒
# 循环次数 207, 前一次的时间 16，目前总时间 314 单位毫秒
# 循环次数 208, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 209, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 210, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 211, 前一次的时间 16，目前总时间 67 单位毫秒
# 循环次数 212, 前一次的时间 16，目前总时间 83 单位毫秒
# 循环次数 213, 前一次的时间 16，目前总时间 99 单位毫秒
# 循环次数 214, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 215, 前一次的时间 16，目前总时间 131 单位毫秒
# 循环次数 216, 前一次的时间 16，目前总时间 147 单位毫秒
# 循环次数 217, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 218, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 219, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 220, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 221, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 222, 前一次的时间 17，目前总时间 244 单位毫秒
# 循环次数 223, 前一次的时间 17，目前总时间 261 单位毫秒
# 循环次数 224, 前一次的时间 16，目前总时间 277 单位毫秒
# 循环次数 225, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 226, 前一次的时间 17，目前总时间 311 单位毫秒
# 循环次数 227, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 228, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 229, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 230, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 231, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 232, 前一次的时间 17，目前总时间 102 单位毫秒
# 循环次数 233, 前一次的时间 16，目前总时间 118 单位毫秒
# 循环次数 234, 前一次的时间 16，目前总时间 134 单位毫秒
# 循环次数 235, 前一次的时间 16，目前总时间 150 单位毫秒
# 循环次数 236, 前一次的时间 16，目前总时间 166 单位毫秒
# 循环次数 237, 前一次的时间 16，目前总时间 182 单位毫秒
# 循环次数 238, 前一次的时间 16，目前总时间 198 单位毫秒
# 循环次数 239, 前一次的时间 16，目前总时间 214 单位毫秒
# 循环次数 240, 前一次的时间 16，目前总时间 230 单位毫秒
# 循环次数 241, 前一次的时间 16，目前总时间 246 单位毫秒
# 循环次数 242, 前一次的时间 16，目前总时间 262 单位毫秒
# 循环次数 243, 前一次的时间 16，目前总时间 278 单位毫秒
# 循环次数 244, 前一次的时间 16，目前总时间 294 单位毫秒
# 循环次数 245, 前一次的时间 16，目前总时间 310 单位毫秒
# 循环次数 246, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 247, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 248, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 249, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 250, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 251, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 252, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 253, 前一次的时间 17，目前总时间 135 单位毫秒
# 循环次数 254, 前一次的时间 17，目前总时间 152 单位毫秒
# 循环次数 255, 前一次的时间 16，目前总时间 168 单位毫秒
# 循环次数 256, 前一次的时间 16，目前总时间 184 单位毫秒
# 循环次数 257, 前一次的时间 16，目前总时间 200 单位毫秒
# 循环次数 258, 前一次的时间 16，目前总时间 216 单位毫秒
# 循环次数 259, 前一次的时间 16，目前总时间 232 单位毫秒
# 循环次数 260, 前一次的时间 16，目前总时间 248 单位毫秒
# 循环次数 261, 前一次的时间 16，目前总时间 264 单位毫秒
# 循环次数 262, 前一次的时间 17，目前总时间 281 单位毫秒
# 循环次数 263, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 264, 前一次的时间 17，目前总时间 314 单位毫秒
# 循环次数 265, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 266, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 267, 前一次的时间 16，目前总时间 50 单位毫秒
# 循环次数 268, 前一次的时间 16，目前总时间 66 单位毫秒
# 循环次数 269, 前一次的时间 17，目前总时间 83 单位毫秒
# 循环次数 270, 前一次的时间 17，目前总时间 100 单位毫秒
# 循环次数 271, 前一次的时间 17，目前总时间 117 单位毫秒
# 循环次数 272, 前一次的时间 17，目前总时间 134 单位毫秒
# 循环次数 273, 前一次的时间 17，目前总时间 151 单位毫秒
# 循环次数 274, 前一次的时间 17，目前总时间 168 单位毫秒
# 循环次数 275, 前一次的时间 17，目前总时间 185 单位毫秒
# 循环次数 276, 前一次的时间 17，目前总时间 202 单位毫秒
# 循环次数 277, 前一次的时间 17，目前总时间 219 单位毫秒
# 循环次数 278, 前一次的时间 17，目前总时间 236 单位毫秒
# 循环次数 279, 前一次的时间 17，目前总时间 253 单位毫秒
# 循环次数 280, 前一次的时间 16，目前总时间 269 单位毫秒
# 循环次数 281, 前一次的时间 16，目前总时间 285 单位毫秒
# 循环次数 282, 前一次的时间 16，目前总时间 301 单位毫秒
# 循环次数 1, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 2, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 3, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 4, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 5, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 6, 前一次的时间 17，目前总时间 97 单位毫秒
# 循环次数 7, 前一次的时间 17，目前总时间 114 单位毫秒
# 循环次数 8, 前一次的时间 16，目前总时间 130 单位毫秒
# 循环次数 9, 前一次的时间 17，目前总时间 147 单位毫秒
# 循环次数 10, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 11, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 12, 前一次的时间 17，目前总时间 196 单位毫秒
# 循环次数 13, 前一次的时间 16，目前总时间 212 单位毫秒
# 循环次数 14, 前一次的时间 17，目前总时间 229 单位毫秒
# 循环次数 15, 前一次的时间 17，目前总时间 246 单位毫秒
# 循环次数 16, 前一次的时间 17，目前总时间 263 单位毫秒
# 循环次数 17, 前一次的时间 17，目前总时间 280 单位毫秒
# 循环次数 18, 前一次的时间 17，目前总时间 297 单位毫秒
# 循环次数 19, 前一次的时间 17，目前总时间 314 单位毫秒
# 循环次数 20, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 21, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 22, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 23, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 24, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 25, 前一次的时间 16，目前总时间 101 单位毫秒
# 循环次数 26, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 27, 前一次的时间 16，目前总时间 134 单位毫秒
# 循环次数 28, 前一次的时间 17，目前总时间 151 单位毫秒
# 循环次数 29, 前一次的时间 17，目前总时间 168 单位毫秒
# 循环次数 30, 前一次的时间 16，目前总时间 184 单位毫秒
# 循环次数 31, 前一次的时间 17，目前总时间 201 单位毫秒
# 循环次数 32, 前一次的时间 17，目前总时间 218 单位毫秒
# 循环次数 33, 前一次的时间 17，目前总时间 235 单位毫秒
# 循环次数 34, 前一次的时间 17，目前总时间 252 单位毫秒
# 循环次数 35, 前一次的时间 17，目前总时间 269 单位毫秒
# 循环次数 36, 前一次的时间 17，目前总时间 286 单位毫秒
# 循环次数 37, 前一次的时间 17，目前总时间 303 单位毫秒
# 循环次数 38, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 39, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 40, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 41, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 42, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 43, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 44, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 45, 前一次的时间 17，目前总时间 130 单位毫秒
# 循环次数 46, 前一次的时间 16，目前总时间 146 单位毫秒
# 循环次数 47, 前一次的时间 17，目前总时间 163 单位毫秒
# 循环次数 48, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 49, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 50, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 51, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 52, 前一次的时间 17，目前总时间 244 单位毫秒
# 循环次数 53, 前一次的时间 17，目前总时间 261 单位毫秒
# 循环次数 54, 前一次的时间 17，目前总时间 278 单位毫秒
# 循环次数 55, 前一次的时间 17，目前总时间 295 单位毫秒
# 循环次数 56, 前一次的时间 17，目前总时间 312 单位毫秒
# 循环次数 57, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 58, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 59, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 60, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 61, 前一次的时间 16，目前总时间 84 单位毫秒
# 循环次数 62, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 63, 前一次的时间 16，目前总时间 117 单位毫秒
# 循环次数 64, 前一次的时间 16，目前总时间 133 单位毫秒
# 循环次数 65, 前一次的时间 16，目前总时间 149 单位毫秒
# 循环次数 66, 前一次的时间 16，目前总时间 165 单位毫秒
# 循环次数 67, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 68, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 69, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 70, 前一次的时间 16，目前总时间 229 单位毫秒
# 循环次数 71, 前一次的时间 16，目前总时间 245 单位毫秒
# 循环次数 72, 前一次的时间 16，目前总时间 261 单位毫秒
# 循环次数 73, 前一次的时间 16，目前总时间 277 单位毫秒
# 循环次数 74, 前一次的时间 16，目前总时间 293 单位毫秒
# 循环次数 75, 前一次的时间 16，目前总时间 309 单位毫秒
# 循环次数 76, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 77, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 78, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 79, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 80, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 81, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 82, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 83, 前一次的时间 17，目前总时间 135 单位毫秒
# 循环次数 84, 前一次的时间 16，目前总时间 151 单位毫秒
# 循环次数 85, 前一次的时间 16，目前总时间 167 单位毫秒
# 循环次数 86, 前一次的时间 16，目前总时间 183 单位毫秒
# 循环次数 87, 前一次的时间 16，目前总时间 199 单位毫秒
# 循环次数 88, 前一次的时间 16，目前总时间 215 单位毫秒
# 循环次数 89, 前一次的时间 16，目前总时间 231 单位毫秒
# 循环次数 90, 前一次的时间 16，目前总时间 247 单位毫秒
# 循环次数 91, 前一次的时间 16，目前总时间 263 单位毫秒
# 循环次数 92, 前一次的时间 16，目前总时间 279 单位毫秒
# 循环次数 93, 前一次的时间 16，目前总时间 295 单位毫秒
# 循环次数 94, 前一次的时间 16，目前总时间 311 单位毫秒
# 循环次数 95, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 96, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 97, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 98, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 99, 前一次的时间 16，目前总时间 83 单位毫秒
# 循环次数 100, 前一次的时间 17，目前总时间 100 单位毫秒
# 循环次数 101, 前一次的时间 17，目前总时间 117 单位毫秒
# 循环次数 102, 前一次的时间 17，目前总时间 134 单位毫秒
# 循环次数 103, 前一次的时间 17，目前总时间 151 单位毫秒
# 循环次数 104, 前一次的时间 17，目前总时间 168 单位毫秒
# 循环次数 105, 前一次的时间 17，目前总时间 185 单位毫秒
# 循环次数 106, 前一次的时间 16，目前总时间 201 单位毫秒
# 循环次数 107, 前一次的时间 16，目前总时间 217 单位毫秒
# 循环次数 108, 前一次的时间 16，目前总时间 233 单位毫秒
# 循环次数 109, 前一次的时间 16，目前总时间 249 单位毫秒
# 循环次数 110, 前一次的时间 16，目前总时间 265 单位毫秒
# 循环次数 111, 前一次的时间 17，目前总时间 282 单位毫秒
# 循环次数 112, 前一次的时间 16，目前总时间 298 单位毫秒
# 循环次数 113, 前一次的时间 17，目前总时间 315 单位毫秒
# 循环次数 114, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 115, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 116, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 117, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 118, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 119, 前一次的时间 16，目前总时间 101 单位毫秒
# 循环次数 120, 前一次的时间 16，目前总时间 117 单位毫秒
# 循环次数 121, 前一次的时间 16，目前总时间 133 单位毫秒
# 循环次数 122, 前一次的时间 17，目前总时间 150 单位毫秒
# 循环次数 123, 前一次的时间 17，目前总时间 167 单位毫秒
# 循环次数 124, 前一次的时间 16，目前总时间 183 单位毫秒
# 循环次数 125, 前一次的时间 16，目前总时间 199 单位毫秒
# 循环次数 126, 前一次的时间 17，目前总时间 216 单位毫秒
# 循环次数 127, 前一次的时间 16，目前总时间 232 单位毫秒
# 循环次数 128, 前一次的时间 16，目前总时间 248 单位毫秒
# 循环次数 129, 前一次的时间 17，目前总时间 265 单位毫秒
# 循环次数 130, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 131, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 132, 前一次的时间 16，目前总时间 313 单位毫秒
# 循环次数 133, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 134, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 135, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 136, 前一次的时间 17，目前总时间 65 单位毫秒
# 循环次数 137, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 138, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 139, 前一次的时间 17，目前总时间 114 单位毫秒
# 循环次数 140, 前一次的时间 17，目前总时间 131 单位毫秒
# 循环次数 141, 前一次的时间 17，目前总时间 148 单位毫秒
# 循环次数 142, 前一次的时间 17，目前总时间 165 单位毫秒
# 循环次数 143, 前一次的时间 17，目前总时间 182 单位毫秒
# 循环次数 144, 前一次的时间 17，目前总时间 199 单位毫秒
# 循环次数 145, 前一次的时间 17，目前总时间 216 单位毫秒
# 循环次数 146, 前一次的时间 17，目前总时间 233 单位毫秒
# 循环次数 147, 前一次的时间 17，目前总时间 250 单位毫秒
# 循环次数 148, 前一次的时间 17，目前总时间 267 单位毫秒
# 循环次数 149, 前一次的时间 16，目前总时间 283 单位毫秒
# 循环次数 150, 前一次的时间 16，目前总时间 299 单位毫秒
# 循环次数 151, 前一次的时间 16，目前总时间 315 单位毫秒
# 循环次数 152, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 153, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 154, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 155, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 156, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 157, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 158, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 159, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 160, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 161, 前一次的时间 16，目前总时间 160 单位毫秒
# 循环次数 162, 前一次的时间 17，目前总时间 177 单位毫秒
# 循环次数 163, 前一次的时间 17，目前总时间 194 单位毫秒
# 循环次数 164, 前一次的时间 17，目前总时间 211 单位毫秒
# 循环次数 165, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 166, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 167, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 168, 前一次的时间 17，目前总时间 279 单位毫秒
# 循环次数 169, 前一次的时间 17，目前总时间 296 单位毫秒
# 循环次数 170, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 171, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 172, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 173, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 174, 前一次的时间 16，目前总时间 66 单位毫秒
# 循环次数 175, 前一次的时间 16，目前总时间 82 单位毫秒
# 循环次数 176, 前一次的时间 16，目前总时间 98 单位毫秒
# 循环次数 177, 前一次的时间 16，目前总时间 114 单位毫秒
# 循环次数 178, 前一次的时间 16，目前总时间 130 单位毫秒
# 循环次数 179, 前一次的时间 16，目前总时间 146 单位毫秒
# 循环次数 180, 前一次的时间 16，目前总时间 162 单位毫秒
# 循环次数 181, 前一次的时间 16，目前总时间 178 单位毫秒
# 循环次数 182, 前一次的时间 17，目前总时间 195 单位毫秒
# 循环次数 183, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 184, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 185, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 186, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 187, 前一次的时间 17，目前总时间 279 单位毫秒
# 循环次数 188, 前一次的时间 17，目前总时间 296 单位毫秒
# 循环次数 189, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 190, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 191, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 192, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 193, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 194, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 195, 前一次的时间 16，目前总时间 101 单位毫秒
# 循环次数 196, 前一次的时间 16，目前总时间 117 单位毫秒
# 循环次数 197, 前一次的时间 17，目前总时间 134 单位毫秒
# 循环次数 198, 前一次的时间 17，目前总时间 151 单位毫秒
# 循环次数 199, 前一次的时间 16，目前总时间 167 单位毫秒
# 循环次数 200, 前一次的时间 16，目前总时间 183 单位毫秒
# 循环次数 201, 前一次的时间 16，目前总时间 199 单位毫秒
# 循环次数 202, 前一次的时间 16，目前总时间 215 单位毫秒
# 循环次数 203, 前一次的时间 16，目前总时间 231 单位毫秒
# 循环次数 204, 前一次的时间 16，目前总时间 247 单位毫秒
# 循环次数 205, 前一次的时间 16，目前总时间 263 单位毫秒
# 循环次数 206, 前一次的时间 16，目前总时间 279 单位毫秒
# 循环次数 207, 前一次的时间 16，目前总时间 295 单位毫秒
# 循环次数 208, 前一次的时间 16，目前总时间 311 单位毫秒
# 循环次数 209, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 210, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 211, 前一次的时间 17，目前总时间 49 单位毫秒
# 循环次数 212, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 213, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 214, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 215, 前一次的时间 17，目前总时间 114 单位毫秒
# 循环次数 216, 前一次的时间 17，目前总时间 131 单位毫秒
# 循环次数 217, 前一次的时间 17，目前总时间 148 单位毫秒
# 循环次数 218, 前一次的时间 16，目前总时间 164 单位毫秒
# 循环次数 219, 前一次的时间 16，目前总时间 180 单位毫秒
# 循环次数 220, 前一次的时间 16，目前总时间 196 单位毫秒
# 循环次数 221, 前一次的时间 16，目前总时间 212 单位毫秒
# 循环次数 222, 前一次的时间 16，目前总时间 228 单位毫秒
# 循环次数 223, 前一次的时间 16，目前总时间 244 单位毫秒
# 循环次数 224, 前一次的时间 16，目前总时间 260 单位毫秒
# 循环次数 225, 前一次的时间 16，目前总时间 276 单位毫秒
# 循环次数 226, 前一次的时间 16，目前总时间 292 单位毫秒
# 循环次数 227, 前一次的时间 16，目前总时间 308 单位毫秒
# 循环次数 228, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 229, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 230, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 231, 前一次的时间 16，目前总时间 67 单位毫秒
# 循环次数 232, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 233, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 234, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 235, 前一次的时间 17，目前总时间 135 单位毫秒
# 循环次数 236, 前一次的时间 16，目前总时间 151 单位毫秒
# 循环次数 237, 前一次的时间 16，目前总时间 167 单位毫秒
# 循环次数 238, 前一次的时间 16，目前总时间 183 单位毫秒
# 循环次数 239, 前一次的时间 16，目前总时间 199 单位毫秒
# 循环次数 240, 前一次的时间 16，目前总时间 215 单位毫秒
# 循环次数 241, 前一次的时间 16，目前总时间 231 单位毫秒
# 循环次数 242, 前一次的时间 18，目前总时间 249 单位毫秒
# 循环次数 243, 前一次的时间 16，目前总时间 265 单位毫秒
# 循环次数 244, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 245, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 246, 前一次的时间 16，目前总时间 313 单位毫秒
# 循环次数 247, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 248, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 249, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 250, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 251, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 252, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 253, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 254, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 255, 前一次的时间 17，目前总时间 145 单位毫秒
# 循环次数 256, 前一次的时间 17，目前总时间 162 单位毫秒
# 循环次数 257, 前一次的时间 17，目前总时间 179 单位毫秒
# 循环次数 258, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 259, 前一次的时间 17，目前总时间 212 单位毫秒
# 循环次数 260, 前一次的时间 17，目前总时间 229 单位毫秒
# 循环次数 261, 前一次的时间 17，目前总时间 246 单位毫秒
# 循环次数 262, 前一次的时间 17，目前总时间 263 单位毫秒
# 循环次数 263, 前一次的时间 17，目前总时间 280 单位毫秒
# 循环次数 264, 前一次的时间 16，目前总时间 296 单位毫秒
# 循环次数 265, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 266, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 267, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 268, 前一次的时间 16，目前总时间 50 单位毫秒
# 循环次数 269, 前一次的时间 16，目前总时间 66 单位毫秒
# 循环次数 270, 前一次的时间 16，目前总时间 82 单位毫秒
# 循环次数 271, 前一次的时间 17，目前总时间 99 单位毫秒
# 循环次数 272, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 273, 前一次的时间 16，目前总时间 131 单位毫秒
# 循环次数 274, 前一次的时间 16，目前总时间 147 单位毫秒
# 循环次数 275, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 276, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 277, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 278, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 279, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 280, 前一次的时间 16，目前总时间 243 单位毫秒
# 循环次数 281, 前一次的时间 16，目前总时间 259 单位毫秒
# 循环次数 282, 前一次的时间 17，目前总时间 276 单位毫秒
# 循环次数 283, 前一次的时间 17，目前总时间 293 单位毫秒
# 循环次数 284, 前一次的时间 17，目前总时间 310 单位毫秒
# 循环次数 1, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 2, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 3, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 4, 前一次的时间 17，目前总时间 66 单位毫秒
# 循环次数 5, 前一次的时间 17，目前总时间 83 单位毫秒
# 循环次数 6, 前一次的时间 17，目前总时间 100 单位毫秒
# 循环次数 7, 前一次的时间 17，目前总时间 117 单位毫秒
# 循环次数 8, 前一次的时间 16，目前总时间 133 单位毫秒
# 循环次数 9, 前一次的时间 16，目前总时间 149 单位毫秒
# 循环次数 10, 前一次的时间 16，目前总时间 165 单位毫秒
# 循环次数 11, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 12, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 13, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 14, 前一次的时间 16，目前总时间 229 单位毫秒
# 循环次数 15, 前一次的时间 17，目前总时间 246 单位毫秒
# 循环次数 16, 前一次的时间 17，目前总时间 263 单位毫秒
# 循环次数 17, 前一次的时间 16，目前总时间 279 单位毫秒
# 循环次数 18, 前一次的时间 17，目前总时间 296 单位毫秒
# 循环次数 19, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 20, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 21, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 22, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 23, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 24, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 25, 前一次的时间 16，目前总时间 101 单位毫秒
# 循环次数 26, 前一次的时间 16，目前总时间 117 单位毫秒
# 循环次数 27, 前一次的时间 16，目前总时间 133 单位毫秒
# 循环次数 28, 前一次的时间 16，目前总时间 149 单位毫秒
# 循环次数 29, 前一次的时间 16，目前总时间 165 单位毫秒
# 循环次数 30, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 31, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 32, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 33, 前一次的时间 16，目前总时间 229 单位毫秒
# 循环次数 34, 前一次的时间 16，目前总时间 245 单位毫秒
# 循环次数 35, 前一次的时间 16，目前总时间 261 单位毫秒
# 循环次数 36, 前一次的时间 16，目前总时间 277 单位毫秒
# 循环次数 37, 前一次的时间 16，目前总时间 293 单位毫秒
# 循环次数 38, 前一次的时间 16，目前总时间 309 单位毫秒
# 循环次数 39, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 40, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 41, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 42, 前一次的时间 17，目前总时间 66 单位毫秒
# 循环次数 43, 前一次的时间 17，目前总时间 83 单位毫秒
# 循环次数 44, 前一次的时间 17，目前总时间 100 单位毫秒
# 循环次数 45, 前一次的时间 17，目前总时间 117 单位毫秒
# 循环次数 46, 前一次的时间 17，目前总时间 134 单位毫秒
# 循环次数 47, 前一次的时间 17，目前总时间 151 单位毫秒
# 循环次数 48, 前一次的时间 16，目前总时间 167 单位毫秒
# 循环次数 49, 前一次的时间 16，目前总时间 183 单位毫秒
# 循环次数 50, 前一次的时间 16，目前总时间 199 单位毫秒
# 循环次数 51, 前一次的时间 16，目前总时间 215 单位毫秒
# 循环次数 52, 前一次的时间 16，目前总时间 231 单位毫秒
# 循环次数 53, 前一次的时间 16，目前总时间 247 单位毫秒
# 循环次数 54, 前一次的时间 16，目前总时间 263 单位毫秒
# 循环次数 55, 前一次的时间 16，目前总时间 279 单位毫秒
# 循环次数 56, 前一次的时间 16，目前总时间 295 单位毫秒
# 循环次数 57, 前一次的时间 16，目前总时间 311 单位毫秒
# 循环次数 58, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 59, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 60, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 61, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 62, 前一次的时间 17，目前总时间 82 单位毫秒
# 循环次数 63, 前一次的时间 17，目前总时间 99 单位毫秒
# 循环次数 64, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 65, 前一次的时间 16，目前总时间 131 单位毫秒
# 循环次数 66, 前一次的时间 17，目前总时间 148 单位毫秒
# 循环次数 67, 前一次的时间 17，目前总时间 165 单位毫秒
# 循环次数 68, 前一次的时间 17，目前总时间 182 单位毫秒
# 循环次数 69, 前一次的时间 16，目前总时间 198 单位毫秒
# 循环次数 70, 前一次的时间 16，目前总时间 214 单位毫秒
# 循环次数 71, 前一次的时间 16，目前总时间 230 单位毫秒
# 循环次数 72, 前一次的时间 16，目前总时间 246 单位毫秒
# 循环次数 73, 前一次的时间 16，目前总时间 262 单位毫秒
# 循环次数 74, 前一次的时间 16，目前总时间 278 单位毫秒
# 循环次数 75, 前一次的时间 18，目前总时间 296 单位毫秒
# 循环次数 76, 前一次的时间 16，目前总时间 312 单位毫秒
# 循环次数 77, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 78, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 79, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 80, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 81, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 82, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 83, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 84, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 85, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 86, 前一次的时间 16，目前总时间 160 单位毫秒
# 循环次数 87, 前一次的时间 16，目前总时间 176 单位毫秒
# 循环次数 88, 前一次的时间 17，目前总时间 193 单位毫秒
# 循环次数 89, 前一次的时间 16，目前总时间 209 单位毫秒
# 循环次数 90, 前一次的时间 17，目前总时间 226 单位毫秒
# 循环次数 91, 前一次的时间 17，目前总时间 243 单位毫秒
# 循环次数 92, 前一次的时间 16，目前总时间 259 单位毫秒
# 循环次数 93, 前一次的时间 17，目前总时间 276 单位毫秒
# 循环次数 94, 前一次的时间 16，目前总时间 292 单位毫秒
# 循环次数 95, 前一次的时间 17，目前总时间 309 单位毫秒
# 循环次数 96, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 97, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 98, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 99, 前一次的时间 17，目前总时间 66 单位毫秒
# 循环次数 100, 前一次的时间 16，目前总时间 82 单位毫秒
# 循环次数 101, 前一次的时间 16，目前总时间 98 单位毫秒
# 循环次数 102, 前一次的时间 16，目前总时间 114 单位毫秒
# 循环次数 103, 前一次的时间 16，目前总时间 130 单位毫秒
# 循环次数 104, 前一次的时间 16，目前总时间 146 单位毫秒
# 循环次数 105, 前一次的时间 16，目前总时间 162 单位毫秒
# 循环次数 106, 前一次的时间 16，目前总时间 178 单位毫秒
# 循环次数 107, 前一次的时间 16，目前总时间 194 单位毫秒
# 循环次数 108, 前一次的时间 17，目前总时间 211 单位毫秒
# 循环次数 109, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 110, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 111, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 112, 前一次的时间 17，目前总时间 279 单位毫秒
# 循环次数 113, 前一次的时间 17，目前总时间 296 单位毫秒
# 循环次数 114, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 115, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 116, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 117, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 118, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 119, 前一次的时间 16，目前总时间 84 单位毫秒
# 循环次数 120, 前一次的时间 16，目前总时间 100 单位毫秒
# 循环次数 121, 前一次的时间 16，目前总时间 116 单位毫秒
# 循环次数 122, 前一次的时间 16，目前总时间 132 单位毫秒
# 循环次数 123, 前一次的时间 16，目前总时间 148 单位毫秒
# 循环次数 124, 前一次的时间 16，目前总时间 164 单位毫秒
# 循环次数 125, 前一次的时间 16，目前总时间 180 单位毫秒
# 循环次数 126, 前一次的时间 16，目前总时间 196 单位毫秒
# 循环次数 127, 前一次的时间 16，目前总时间 212 单位毫秒
# 循环次数 128, 前一次的时间 16，目前总时间 228 单位毫秒
# 循环次数 129, 前一次的时间 16，目前总时间 244 单位毫秒
# 循环次数 130, 前一次的时间 16，目前总时间 260 单位毫秒
# 循环次数 131, 前一次的时间 17，目前总时间 277 单位毫秒
# 循环次数 132, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 133, 前一次的时间 17，目前总时间 311 单位毫秒
# 循环次数 134, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 135, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 136, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 137, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 138, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 139, 前一次的时间 17，目前总时间 102 单位毫秒
# 循环次数 140, 前一次的时间 17，目前总时间 119 单位毫秒
# 循环次数 141, 前一次的时间 16，目前总时间 135 单位毫秒
# 循环次数 142, 前一次的时间 17，目前总时间 152 单位毫秒
# 循环次数 143, 前一次的时间 16，目前总时间 168 单位毫秒
# 循环次数 144, 前一次的时间 16，目前总时间 184 单位毫秒
# 循环次数 145, 前一次的时间 16，目前总时间 200 单位毫秒
# 循环次数 146, 前一次的时间 16，目前总时间 216 单位毫秒
# 循环次数 147, 前一次的时间 16，目前总时间 232 单位毫秒
# 循环次数 148, 前一次的时间 16，目前总时间 248 单位毫秒
# 循环次数 149, 前一次的时间 17，目前总时间 265 单位毫秒
# 循环次数 150, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 151, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 152, 前一次的时间 17，目前总时间 314 单位毫秒
# 循环次数 153, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 154, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 155, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 156, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 157, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 158, 前一次的时间 17，目前总时间 102 单位毫秒
# 循环次数 159, 前一次的时间 17，目前总时间 119 单位毫秒
# 循环次数 160, 前一次的时间 17，目前总时间 136 单位毫秒
# 循环次数 161, 前一次的时间 17，目前总时间 153 单位毫秒
# 循环次数 162, 前一次的时间 17，目前总时间 170 单位毫秒
# 循环次数 163, 前一次的时间 16，目前总时间 186 单位毫秒
# 循环次数 164, 前一次的时间 16，目前总时间 202 单位毫秒
# 循环次数 165, 前一次的时间 16，目前总时间 218 单位毫秒
# 循环次数 166, 前一次的时间 16，目前总时间 234 单位毫秒
# 循环次数 167, 前一次的时间 16，目前总时间 250 单位毫秒
# 循环次数 168, 前一次的时间 16，目前总时间 266 单位毫秒
# 循环次数 169, 前一次的时间 16，目前总时间 282 单位毫秒
# 循环次数 170, 前一次的时间 16，目前总时间 298 单位毫秒
# 循环次数 171, 前一次的时间 16，目前总时间 314 单位毫秒
# 循环次数 172, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 173, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 174, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 175, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 176, 前一次的时间 17，目前总时间 81 单位毫秒
# 循环次数 177, 前一次的时间 17，目前总时间 98 单位毫秒
# 循环次数 178, 前一次的时间 17，目前总时间 115 单位毫秒
# 循环次数 179, 前一次的时间 17，目前总时间 132 单位毫秒
# 循环次数 180, 前一次的时间 17，目前总时间 149 单位毫秒
# 循环次数 181, 前一次的时间 17，目前总时间 166 单位毫秒
# 循环次数 182, 前一次的时间 17，目前总时间 183 单位毫秒
# 循环次数 183, 前一次的时间 17，目前总时间 200 单位毫秒
# 循环次数 184, 前一次的时间 17，目前总时间 217 单位毫秒
# 循环次数 185, 前一次的时间 16，目前总时间 233 单位毫秒
# 循环次数 186, 前一次的时间 16，目前总时间 249 单位毫秒
# 循环次数 187, 前一次的时间 16，目前总时间 265 单位毫秒
# 循环次数 188, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 189, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 190, 前一次的时间 17，目前总时间 314 单位毫秒
# 循环次数 191, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 192, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 193, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 194, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 195, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 196, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 197, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 198, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 199, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 200, 前一次的时间 17，目前总时间 162 单位毫秒
# 循环次数 201, 前一次的时间 16，目前总时间 178 单位毫秒
# 循环次数 202, 前一次的时间 16，目前总时间 194 单位毫秒
# 循环次数 203, 前一次的时间 17，目前总时间 211 单位毫秒
# 循环次数 204, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 205, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 206, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 207, 前一次的时间 17，目前总时间 279 单位毫秒
# 循环次数 208, 前一次的时间 17，目前总时间 296 单位毫秒
# 循环次数 209, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 210, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 211, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 212, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 213, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 214, 前一次的时间 17，目前总时间 81 单位毫秒
# 循环次数 215, 前一次的时间 17，目前总时间 98 单位毫秒
# 循环次数 216, 前一次的时间 16，目前总时间 114 单位毫秒
# 循环次数 217, 前一次的时间 17，目前总时间 131 单位毫秒
# 循环次数 218, 前一次的时间 17，目前总时间 148 单位毫秒
# 循环次数 219, 前一次的时间 17，目前总时间 165 单位毫秒
# 循环次数 220, 前一次的时间 17，目前总时间 182 单位毫秒
# 循环次数 221, 前一次的时间 17，目前总时间 199 单位毫秒
# 循环次数 222, 前一次的时间 17，目前总时间 216 单位毫秒
# 循环次数 223, 前一次的时间 17，目前总时间 233 单位毫秒
# 循环次数 224, 前一次的时间 17，目前总时间 250 单位毫秒
# 循环次数 225, 前一次的时间 16，目前总时间 266 单位毫秒
# 循环次数 226, 前一次的时间 16，目前总时间 282 单位毫秒
# 循环次数 227, 前一次的时间 16，目前总时间 298 单位毫秒
# 循环次数 228, 前一次的时间 16，目前总时间 314 单位毫秒
# 循环次数 229, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 230, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 231, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 232, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 233, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 234, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 235, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 236, 前一次的时间 17，目前总时间 129 单位毫秒
# 循环次数 237, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 238, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 239, 前一次的时间 17，目前总时间 178 单位毫秒
# 循环次数 240, 前一次的时间 17，目前总时间 195 单位毫秒
# 循环次数 241, 前一次的时间 17，目前总时间 212 单位毫秒
# 循环次数 242, 前一次的时间 17，目前总时间 229 单位毫秒
# 循环次数 243, 前一次的时间 17，目前总时间 246 单位毫秒
# 循环次数 244, 前一次的时间 17，目前总时间 263 单位毫秒
# 循环次数 245, 前一次的时间 17，目前总时间 280 单位毫秒
# 循环次数 246, 前一次的时间 16，目前总时间 296 单位毫秒
# 循环次数 247, 前一次的时间 16，目前总时间 312 单位毫秒
# 循环次数 248, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 249, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 250, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 251, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 252, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 253, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 254, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 255, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 256, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 257, 前一次的时间 16，目前总时间 160 单位毫秒
# 循环次数 258, 前一次的时间 16，目前总时间 176 单位毫秒
# 循环次数 259, 前一次的时间 16，目前总时间 192 单位毫秒
# 循环次数 260, 前一次的时间 16，目前总时间 208 单位毫秒
# 循环次数 261, 前一次的时间 17，目前总时间 225 单位毫秒
# 循环次数 262, 前一次的时间 17，目前总时间 242 单位毫秒
# 循环次数 263, 前一次的时间 17，目前总时间 259 单位毫秒
# 循环次数 264, 前一次的时间 17，目前总时间 276 单位毫秒
# 循环次数 265, 前一次的时间 17，目前总时间 293 单位毫秒
# 循环次数 266, 前一次的时间 17，目前总时间 310 单位毫秒
# 循环次数 267, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 268, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 269, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 270, 前一次的时间 16，目前总时间 67 单位毫秒
# 循环次数 271, 前一次的时间 16，目前总时间 83 单位毫秒
# 循环次数 272, 前一次的时间 16，目前总时间 99 单位毫秒
# 循环次数 273, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 274, 前一次的时间 16，目前总时间 131 单位毫秒
# 循环次数 275, 前一次的时间 16，目前总时间 147 单位毫秒
# 循环次数 276, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 277, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 278, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 279, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 280, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 281, 前一次的时间 17，目前总时间 244 单位毫秒
# 循环次数 282, 前一次的时间 16，目前总时间 260 单位毫秒
# 循环次数 283, 前一次的时间 16，目前总时间 276 单位毫秒
# 循环次数 284, 前一次的时间 17，目前总时间 293 单位毫秒
# 循环次数 285, 前一次的时间 17，目前总时间 310 单位毫秒
# 循环次数 1, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 2, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 3, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 4, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 5, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 6, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 7, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 8, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 9, 前一次的时间 17，目前总时间 146 单位毫秒
# 循环次数 10, 前一次的时间 16，目前总时间 162 单位毫秒
# 循环次数 11, 前一次的时间 17，目前总时间 179 单位毫秒
# 循环次数 12, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 13, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 14, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 15, 前一次的时间 16，目前总时间 243 单位毫秒
# 循环次数 16, 前一次的时间 16，目前总时间 259 单位毫秒
# 循环次数 17, 前一次的时间 16，目前总时间 275 单位毫秒
# 循环次数 18, 前一次的时间 16，目前总时间 291 单位毫秒
# 循环次数 19, 前一次的时间 16，目前总时间 307 单位毫秒
# 循环次数 20, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 21, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 22, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 23, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 24, 前一次的时间 17，目前总时间 81 单位毫秒
# 循环次数 25, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 26, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 27, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 28, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 29, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 30, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 31, 前一次的时间 16，目前总时间 193 单位毫秒
# 循环次数 32, 前一次的时间 16，目前总时间 209 单位毫秒
# 循环次数 33, 前一次的时间 16，目前总时间 225 单位毫秒
# 循环次数 34, 前一次的时间 16，目前总时间 241 单位毫秒
# 循环次数 35, 前一次的时间 18，目前总时间 259 单位毫秒
# 循环次数 36, 前一次的时间 16，目前总时间 275 单位毫秒
# 循环次数 37, 前一次的时间 16，目前总时间 291 单位毫秒
# 循环次数 38, 前一次的时间 16，目前总时间 307 单位毫秒
# 循环次数 39, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 40, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 41, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 42, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 43, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 44, 前一次的时间 17，目前总时间 97 单位毫秒
# 循环次数 45, 前一次的时间 17，目前总时间 114 单位毫秒
# 循环次数 46, 前一次的时间 17，目前总时间 131 单位毫秒
# 循环次数 47, 前一次的时间 17，目前总时间 148 单位毫秒
# 循环次数 48, 前一次的时间 17，目前总时间 165 单位毫秒
# 循环次数 49, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 50, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 51, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 52, 前一次的时间 16，目前总时间 229 单位毫秒
# 循环次数 53, 前一次的时间 16，目前总时间 245 单位毫秒
# 循环次数 54, 前一次的时间 16，目前总时间 261 单位毫秒
# 循环次数 55, 前一次的时间 16，目前总时间 277 单位毫秒
# 循环次数 56, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 57, 前一次的时间 16，目前总时间 310 单位毫秒
# 循环次数 58, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 59, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 60, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 61, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 62, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 63, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 64, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 65, 前一次的时间 16，目前总时间 134 单位毫秒
# 循环次数 66, 前一次的时间 17，目前总时间 151 单位毫秒
# 循环次数 67, 前一次的时间 17，目前总时间 168 单位毫秒
# 循环次数 68, 前一次的时间 16，目前总时间 184 单位毫秒
# 循环次数 69, 前一次的时间 16，目前总时间 200 单位毫秒
# 循环次数 70, 前一次的时间 16，目前总时间 216 单位毫秒
# 循环次数 71, 前一次的时间 16，目前总时间 232 单位毫秒
# 循环次数 72, 前一次的时间 16，目前总时间 248 单位毫秒
# 循环次数 73, 前一次的时间 16，目前总时间 264 单位毫秒
# 循环次数 74, 前一次的时间 17，目前总时间 281 单位毫秒
# 循环次数 75, 前一次的时间 17，目前总时间 298 单位毫秒
# 循环次数 76, 前一次的时间 16，目前总时间 314 单位毫秒
# 循环次数 77, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 78, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 79, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 80, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 81, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 82, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 83, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 84, 前一次的时间 17，目前总时间 135 单位毫秒
# 循环次数 85, 前一次的时间 17，目前总时间 152 单位毫秒
# 循环次数 86, 前一次的时间 16，目前总时间 168 单位毫秒
# 循环次数 87, 前一次的时间 16，目前总时间 184 单位毫秒
# 循环次数 88, 前一次的时间 16，目前总时间 200 单位毫秒
# 循环次数 89, 前一次的时间 16，目前总时间 216 单位毫秒
# 循环次数 90, 前一次的时间 16，目前总时间 232 单位毫秒
# 循环次数 91, 前一次的时间 16，目前总时间 248 单位毫秒
# 循环次数 92, 前一次的时间 17，目前总时间 265 单位毫秒
# 循环次数 93, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 94, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 95, 前一次的时间 16，目前总时间 313 单位毫秒
# 循环次数 96, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 97, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 98, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 99, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 100, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 101, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 102, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 103, 前一次的时间 17，目前总时间 129 单位毫秒
# 循环次数 104, 前一次的时间 17，目前总时间 146 单位毫秒
# 循环次数 105, 前一次的时间 17，目前总时间 163 单位毫秒
# 循环次数 106, 前一次的时间 17，目前总时间 180 单位毫秒
# 循环次数 107, 前一次的时间 17，目前总时间 197 单位毫秒
# 循环次数 108, 前一次的时间 17，目前总时间 214 单位毫秒
# 循环次数 109, 前一次的时间 17，目前总时间 231 单位毫秒
# 循环次数 110, 前一次的时间 17，目前总时间 248 单位毫秒
# 循环次数 111, 前一次的时间 17，目前总时间 265 单位毫秒
# 循环次数 112, 前一次的时间 17，目前总时间 282 单位毫秒
# 循环次数 113, 前一次的时间 17，目前总时间 299 单位毫秒
# 循环次数 114, 前一次的时间 16，目前总时间 315 单位毫秒
# 循环次数 115, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 116, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 117, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 118, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 119, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 120, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 121, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 122, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 123, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 124, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 125, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 126, 前一次的时间 17，目前总时间 194 单位毫秒
# 循环次数 127, 前一次的时间 17，目前总时间 211 单位毫秒
# 循环次数 128, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 129, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 130, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 131, 前一次的时间 17，目前总时间 279 单位毫秒
# 循环次数 132, 前一次的时间 16，目前总时间 295 单位毫秒
# 循环次数 133, 前一次的时间 16，目前总时间 311 单位毫秒
# 循环次数 134, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 135, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 136, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 137, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 138, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 139, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 140, 前一次的时间 17，目前总时间 113 单位毫秒
# 循环次数 141, 前一次的时间 17，目前总时间 130 单位毫秒
# 循环次数 142, 前一次的时间 17，目前总时间 147 单位毫秒
# 循环次数 143, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 144, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 145, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 146, 前一次的时间 17，目前总时间 212 单位毫秒
# 循环次数 147, 前一次的时间 17，目前总时间 229 单位毫秒
# 循环次数 148, 前一次的时间 17，目前总时间 246 单位毫秒
# 循环次数 149, 前一次的时间 17，目前总时间 263 单位毫秒
# 循环次数 150, 前一次的时间 16，目前总时间 279 单位毫秒
# 循环次数 151, 前一次的时间 16，目前总时间 295 单位毫秒
# 循环次数 152, 前一次的时间 17，目前总时间 312 单位毫秒
# 循环次数 153, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 154, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 155, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 156, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 157, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 158, 前一次的时间 17，目前总时间 102 单位毫秒
# 循环次数 159, 前一次的时间 17，目前总时间 119 单位毫秒
# 循环次数 160, 前一次的时间 17，目前总时间 136 单位毫秒
# 循环次数 161, 前一次的时间 16，目前总时间 152 单位毫秒
# 循环次数 162, 前一次的时间 17，目前总时间 169 单位毫秒
# 循环次数 163, 前一次的时间 16，目前总时间 185 单位毫秒
# 循环次数 164, 前一次的时间 16，目前总时间 201 单位毫秒
# 循环次数 165, 前一次的时间 16，目前总时间 217 单位毫秒
# 循环次数 166, 前一次的时间 16，目前总时间 233 单位毫秒
# 循环次数 167, 前一次的时间 16，目前总时间 249 单位毫秒
# 循环次数 168, 前一次的时间 16，目前总时间 265 单位毫秒
# 循环次数 169, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 170, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 171, 前一次的时间 16，目前总时间 313 单位毫秒
# 循环次数 172, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 173, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 174, 前一次的时间 17，目前总时间 49 单位毫秒
# 循环次数 175, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 176, 前一次的时间 17，目前总时间 82 单位毫秒
# 循环次数 177, 前一次的时间 17，目前总时间 99 单位毫秒
# 循环次数 178, 前一次的时间 17，目前总时间 116 单位毫秒
# 循环次数 179, 前一次的时间 17，目前总时间 133 单位毫秒
# 循环次数 180, 前一次的时间 17，目前总时间 150 单位毫秒
# 循环次数 181, 前一次的时间 17，目前总时间 167 单位毫秒
# 循环次数 182, 前一次的时间 17，目前总时间 184 单位毫秒
# 循环次数 183, 前一次的时间 17，目前总时间 201 单位毫秒
# 循环次数 184, 前一次的时间 16，目前总时间 217 单位毫秒
# 循环次数 185, 前一次的时间 16，目前总时间 233 单位毫秒
# 循环次数 186, 前一次的时间 16，目前总时间 249 单位毫秒
# 循环次数 187, 前一次的时间 17，目前总时间 266 单位毫秒
# 循环次数 188, 前一次的时间 16，目前总时间 282 单位毫秒
# 循环次数 189, 前一次的时间 16，目前总时间 298 单位毫秒
# 循环次数 190, 前一次的时间 16，目前总时间 314 单位毫秒
# 循环次数 191, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 192, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 193, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 194, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 195, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 196, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 197, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 198, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 199, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 200, 前一次的时间 16，目前总时间 160 单位毫秒
# 循环次数 201, 前一次的时间 17，目前总时间 177 单位毫秒
# 循环次数 202, 前一次的时间 17，目前总时间 194 单位毫秒
# 循环次数 203, 前一次的时间 17，目前总时间 211 单位毫秒
# 循环次数 204, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 205, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 206, 前一次的时间 16，目前总时间 261 单位毫秒
# 循环次数 207, 前一次的时间 16，目前总时间 277 单位毫秒
# 循环次数 208, 前一次的时间 16，目前总时间 293 单位毫秒
# 循环次数 209, 前一次的时间 16，目前总时间 309 单位毫秒
# 循环次数 210, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 211, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 212, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 213, 前一次的时间 17，目前总时间 65 单位毫秒
# 循环次数 214, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 215, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 216, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 217, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 218, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 219, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 220, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 221, 前一次的时间 16，目前总时间 193 单位毫秒
# 循环次数 222, 前一次的时间 17，目前总时间 210 单位毫秒
# 循环次数 223, 前一次的时间 16，目前总时间 226 单位毫秒
# 循环次数 224, 前一次的时间 17，目前总时间 243 单位毫秒
# 循环次数 225, 前一次的时间 17，目前总时间 260 单位毫秒
# 循环次数 226, 前一次的时间 17，目前总时间 277 单位毫秒
# 循环次数 227, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 228, 前一次的时间 16，目前总时间 310 单位毫秒
# 循环次数 229, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 230, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 231, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 232, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 233, 前一次的时间 16，目前总时间 83 单位毫秒
# 循环次数 234, 前一次的时间 17，目前总时间 100 单位毫秒
# 循环次数 235, 前一次的时间 17，目前总时间 117 单位毫秒
# 循环次数 236, 前一次的时间 17，目前总时间 134 单位毫秒
# 循环次数 237, 前一次的时间 17，目前总时间 151 单位毫秒
# 循环次数 238, 前一次的时间 16，目前总时间 167 单位毫秒
# 循环次数 239, 前一次的时间 16，目前总时间 183 单位毫秒
# 循环次数 240, 前一次的时间 17，目前总时间 200 单位毫秒
# 循环次数 241, 前一次的时间 17，目前总时间 217 单位毫秒
# 循环次数 242, 前一次的时间 17，目前总时间 234 单位毫秒
# 循环次数 243, 前一次的时间 16，目前总时间 250 单位毫秒
# 循环次数 244, 前一次的时间 17，目前总时间 267 单位毫秒
# 循环次数 245, 前一次的时间 17，目前总时间 284 单位毫秒
# 循环次数 246, 前一次的时间 17，目前总时间 301 单位毫秒
# 循环次数 247, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 248, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 249, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 250, 前一次的时间 16，目前总时间 67 单位毫秒
# 循环次数 251, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 252, 前一次的时间 16，目前总时间 100 单位毫秒
# 循环次数 253, 前一次的时间 16，目前总时间 116 单位毫秒
# 循环次数 254, 前一次的时间 16，目前总时间 132 单位毫秒
# 循环次数 255, 前一次的时间 16，目前总时间 148 单位毫秒
# 循环次数 256, 前一次的时间 16，目前总时间 164 单位毫秒
# 循环次数 257, 前一次的时间 16，目前总时间 180 单位毫秒
# 循环次数 258, 前一次的时间 16，目前总时间 196 单位毫秒
# 循环次数 259, 前一次的时间 16，目前总时间 212 单位毫秒
# 循环次数 260, 前一次的时间 16，目前总时间 228 单位毫秒
# 循环次数 261, 前一次的时间 16，目前总时间 244 单位毫秒
# 循环次数 262, 前一次的时间 16，目前总时间 260 单位毫秒
# 循环次数 263, 前一次的时间 16，目前总时间 276 单位毫秒
# 循环次数 264, 前一次的时间 17，目前总时间 293 单位毫秒
# 循环次数 265, 前一次的时间 17，目前总时间 310 单位毫秒
# 循环次数 266, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 267, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 268, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 269, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 270, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 271, 前一次的时间 16，目前总时间 101 单位毫秒
# 循环次数 272, 前一次的时间 16，目前总时间 117 单位毫秒
# 循环次数 273, 前一次的时间 16，目前总时间 133 单位毫秒
# 循环次数 274, 前一次的时间 16，目前总时间 149 单位毫秒
# 循环次数 275, 前一次的时间 16，目前总时间 165 单位毫秒
# 循环次数 276, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 277, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 278, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 279, 前一次的时间 17，目前总时间 230 单位毫秒
# 循环次数 280, 前一次的时间 16，目前总时间 246 单位毫秒
# 循环次数 281, 前一次的时间 17，目前总时间 263 单位毫秒
# 循环次数 282, 前一次的时间 17，目前总时间 280 单位毫秒
# 循环次数 283, 前一次的时间 16，目前总时间 296 单位毫秒
# 循环次数 284, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 1, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 2, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 3, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 4, 前一次的时间 17，目前总时间 65 单位毫秒
# 循环次数 5, 前一次的时间 17，目前总时间 82 单位毫秒
# 循环次数 6, 前一次的时间 17，目前总时间 99 单位毫秒
# 循环次数 7, 前一次的时间 17，目前总时间 116 单位毫秒
# 循环次数 8, 前一次的时间 17，目前总时间 133 单位毫秒
# 循环次数 9, 前一次的时间 17，目前总时间 150 单位毫秒
# 循环次数 10, 前一次的时间 17，目前总时间 167 单位毫秒
# 循环次数 11, 前一次的时间 17，目前总时间 184 单位毫秒
# 循环次数 12, 前一次的时间 17，目前总时间 201 单位毫秒
# 循环次数 13, 前一次的时间 17，目前总时间 218 单位毫秒
# 循环次数 14, 前一次的时间 17，目前总时间 235 单位毫秒
# 循环次数 15, 前一次的时间 17，目前总时间 252 单位毫秒
# 循环次数 16, 前一次的时间 16，目前总时间 268 单位毫秒
# 循环次数 17, 前一次的时间 16，目前总时间 284 单位毫秒
# 循环次数 18, 前一次的时间 16，目前总时间 300 单位毫秒
# 循环次数 19, 前一次的时间 16，目前总时间 316 单位毫秒
# 循环次数 20, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 21, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 22, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 23, 前一次的时间 17，目前总时间 65 单位毫秒
# 循环次数 24, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 25, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 26, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 27, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 28, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 29, 前一次的时间 17，目前总时间 162 单位毫秒
# 循环次数 30, 前一次的时间 17，目前总时间 179 单位毫秒
# 循环次数 31, 前一次的时间 17，目前总时间 196 单位毫秒
# 循环次数 32, 前一次的时间 17，目前总时间 213 单位毫秒
# 循环次数 33, 前一次的时间 17，目前总时间 230 单位毫秒
# 循环次数 34, 前一次的时间 17，目前总时间 247 单位毫秒
# 循环次数 35, 前一次的时间 17，目前总时间 264 单位毫秒
# 循环次数 36, 前一次的时间 17，目前总时间 281 单位毫秒
# 循环次数 37, 前一次的时间 17，目前总时间 298 单位毫秒
# 循环次数 38, 前一次的时间 17，目前总时间 315 单位毫秒
# 循环次数 39, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 40, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 41, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 42, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 43, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 44, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 45, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 46, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 47, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 48, 前一次的时间 16，目前总时间 160 单位毫秒
# 循环次数 49, 前一次的时间 16，目前总时间 176 单位毫秒
# 循环次数 50, 前一次的时间 16，目前总时间 192 单位毫秒
# 循环次数 51, 前一次的时间 16，目前总时间 208 单位毫秒
# 循环次数 52, 前一次的时间 16，目前总时间 224 单位毫秒
# 循环次数 53, 前一次的时间 17，目前总时间 241 单位毫秒
# 循环次数 54, 前一次的时间 17，目前总时间 258 单位毫秒
# 循环次数 55, 前一次的时间 17，目前总时间 275 单位毫秒
# 循环次数 56, 前一次的时间 17，目前总时间 292 单位毫秒
# 循环次数 57, 前一次的时间 17，目前总时间 309 单位毫秒
# 循环次数 58, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 59, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 60, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 61, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 62, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 63, 前一次的时间 17，目前总时间 97 单位毫秒
# 循环次数 64, 前一次的时间 17，目前总时间 114 单位毫秒
# 循环次数 65, 前一次的时间 16，目前总时间 130 单位毫秒
# 循环次数 66, 前一次的时间 17，目前总时间 147 单位毫秒
# 循环次数 67, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 68, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 69, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 70, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 71, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 72, 前一次的时间 16，目前总时间 243 单位毫秒
# 循环次数 73, 前一次的时间 16，目前总时间 259 单位毫秒
# 循环次数 74, 前一次的时间 16，目前总时间 275 单位毫秒
# 循环次数 75, 前一次的时间 16，目前总时间 291 单位毫秒
# 循环次数 76, 前一次的时间 16，目前总时间 307 单位毫秒
# 循环次数 77, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 78, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 79, 前一次的时间 17，目前总时间 49 单位毫秒
# 循环次数 80, 前一次的时间 17，目前总时间 66 单位毫秒
# 循环次数 81, 前一次的时间 17，目前总时间 83 单位毫秒
# 循环次数 82, 前一次的时间 16，目前总时间 99 单位毫秒
# 循环次数 83, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 84, 前一次的时间 16，目前总时间 131 单位毫秒
# 循环次数 85, 前一次的时间 16，目前总时间 147 单位毫秒
# 循环次数 86, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 87, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 88, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 89, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 90, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 91, 前一次的时间 16，目前总时间 243 单位毫秒
# 循环次数 92, 前一次的时间 16，目前总时间 259 单位毫秒
# 循环次数 93, 前一次的时间 16，目前总时间 275 单位毫秒
# 循环次数 94, 前一次的时间 16，目前总时间 291 单位毫秒
# 循环次数 95, 前一次的时间 16，目前总时间 307 单位毫秒
# 循环次数 96, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 97, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 98, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 99, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 100, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 101, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 102, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 103, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 104, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 105, 前一次的时间 16，目前总时间 160 单位毫秒
# 循环次数 106, 前一次的时间 16，目前总时间 176 单位毫秒
# 循环次数 107, 前一次的时间 17，目前总时间 193 单位毫秒
# 循环次数 108, 前一次的时间 16，目前总时间 209 单位毫秒
# 循环次数 109, 前一次的时间 17，目前总时间 226 单位毫秒
# 循环次数 110, 前一次的时间 17，目前总时间 243 单位毫秒
# 循环次数 111, 前一次的时间 17，目前总时间 260 单位毫秒
# 循环次数 112, 前一次的时间 17，目前总时间 277 单位毫秒
# 循环次数 113, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 114, 前一次的时间 16，目前总时间 310 单位毫秒
# 循环次数 115, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 116, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 117, 前一次的时间 17，目前总时间 49 单位毫秒
# 循环次数 118, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 119, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 120, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 121, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 122, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 123, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 124, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 125, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 126, 前一次的时间 16，目前总时间 193 单位毫秒
# 循环次数 127, 前一次的时间 17，目前总时间 210 单位毫秒
# 循环次数 128, 前一次的时间 17，目前总时间 227 单位毫秒
# 循环次数 129, 前一次的时间 16，目前总时间 243 单位毫秒
# 循环次数 130, 前一次的时间 17，目前总时间 260 单位毫秒
# 循环次数 131, 前一次的时间 16，目前总时间 276 单位毫秒
# 循环次数 132, 前一次的时间 17，目前总时间 293 单位毫秒
# 循环次数 133, 前一次的时间 17，目前总时间 310 单位毫秒
# 循环次数 134, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 135, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 136, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 137, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 138, 前一次的时间 16，目前总时间 84 单位毫秒
# 循环次数 139, 前一次的时间 16，目前总时间 100 单位毫秒
# 循环次数 140, 前一次的时间 16，目前总时间 116 单位毫秒
# 循环次数 141, 前一次的时间 16，目前总时间 132 单位毫秒
# 循环次数 142, 前一次的时间 16，目前总时间 148 单位毫秒
# 循环次数 143, 前一次的时间 16，目前总时间 164 单位毫秒
# 循环次数 144, 前一次的时间 16，目前总时间 180 单位毫秒
# 循环次数 145, 前一次的时间 16，目前总时间 196 单位毫秒
# 循环次数 146, 前一次的时间 16，目前总时间 212 单位毫秒
# 循环次数 147, 前一次的时间 16，目前总时间 228 单位毫秒
# 循环次数 148, 前一次的时间 16，目前总时间 244 单位毫秒
# 循环次数 149, 前一次的时间 16，目前总时间 260 单位毫秒
# 循环次数 150, 前一次的时间 17，目前总时间 277 单位毫秒
# 循环次数 151, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 152, 前一次的时间 17，目前总时间 311 单位毫秒
# 循环次数 153, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 154, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 155, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 156, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 157, 前一次的时间 16，目前总时间 84 单位毫秒
# 循环次数 158, 前一次的时间 16，目前总时间 100 单位毫秒
# 循环次数 159, 前一次的时间 16，目前总时间 116 单位毫秒
# 循环次数 160, 前一次的时间 16，目前总时间 132 单位毫秒
# 循环次数 161, 前一次的时间 16，目前总时间 148 单位毫秒
# 循环次数 162, 前一次的时间 16，目前总时间 164 单位毫秒
# 循环次数 163, 前一次的时间 17，目前总时间 181 单位毫秒
# 循环次数 164, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 165, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 166, 前一次的时间 17，目前总时间 230 单位毫秒
# 循环次数 167, 前一次的时间 17，目前总时间 247 单位毫秒
# 循环次数 168, 前一次的时间 17，目前总时间 264 单位毫秒
# 循环次数 169, 前一次的时间 17，目前总时间 281 单位毫秒
# 循环次数 170, 前一次的时间 17，目前总时间 298 单位毫秒
# 循环次数 171, 前一次的时间 17，目前总时间 315 单位毫秒
# 循环次数 172, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 173, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 174, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 175, 前一次的时间 16，目前总时间 67 单位毫秒
# 循环次数 176, 前一次的时间 16，目前总时间 83 单位毫秒
# 循环次数 177, 前一次的时间 16，目前总时间 99 单位毫秒
# 循环次数 178, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 179, 前一次的时间 16，目前总时间 131 单位毫秒
# 循环次数 180, 前一次的时间 17，目前总时间 148 单位毫秒
# 循环次数 181, 前一次的时间 17，目前总时间 165 单位毫秒
# 循环次数 182, 前一次的时间 17，目前总时间 182 单位毫秒
# 循环次数 183, 前一次的时间 16，目前总时间 198 单位毫秒
# 循环次数 184, 前一次的时间 17，目前总时间 215 单位毫秒
# 循环次数 185, 前一次的时间 17，目前总时间 232 单位毫秒
# 循环次数 186, 前一次的时间 17，目前总时间 249 单位毫秒
# 循环次数 187, 前一次的时间 17，目前总时间 266 单位毫秒
# 循环次数 188, 前一次的时间 17，目前总时间 283 单位毫秒
# 循环次数 189, 前一次的时间 17，目前总时间 300 单位毫秒
# 循环次数 190, 前一次的时间 16，目前总时间 316 单位毫秒
# 循环次数 191, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 192, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 193, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 194, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 195, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 196, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 197, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 198, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 199, 前一次的时间 17，目前总时间 145 单位毫秒
# 循环次数 200, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 201, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 202, 前一次的时间 17，目前总时间 194 单位毫秒
# 循环次数 203, 前一次的时间 17，目前总时间 211 单位毫秒
# 循环次数 204, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 205, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 206, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 207, 前一次的时间 17，目前总时间 279 单位毫秒
# 循环次数 208, 前一次的时间 17，目前总时间 296 单位毫秒
# 循环次数 209, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 210, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 211, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 212, 前一次的时间 16，目前总时间 50 单位毫秒
# 循环次数 213, 前一次的时间 16，目前总时间 66 单位毫秒
# 循环次数 214, 前一次的时间 17，目前总时间 83 单位毫秒
# 循环次数 215, 前一次的时间 16，目前总时间 99 单位毫秒
# 循环次数 216, 前一次的时间 16，目前总时间 115 单位毫秒
# 循环次数 217, 前一次的时间 16，目前总时间 131 单位毫秒
# 循环次数 218, 前一次的时间 16，目前总时间 147 单位毫秒
# 循环次数 219, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 220, 前一次的时间 16，目前总时间 179 单位毫秒
# 循环次数 221, 前一次的时间 16，目前总时间 195 单位毫秒
# 循环次数 222, 前一次的时间 16，目前总时间 211 单位毫秒
# 循环次数 223, 前一次的时间 16，目前总时间 227 单位毫秒
# 循环次数 224, 前一次的时间 17，目前总时间 244 单位毫秒
# 循环次数 225, 前一次的时间 17，目前总时间 261 单位毫秒
# 循环次数 226, 前一次的时间 17，目前总时间 278 单位毫秒
# 循环次数 227, 前一次的时间 17，目前总时间 295 单位毫秒
# 循环次数 228, 前一次的时间 17，目前总时间 312 单位毫秒
# 循环次数 229, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 230, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 231, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 232, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 233, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 234, 前一次的时间 17，目前总时间 102 单位毫秒
# 循环次数 235, 前一次的时间 16，目前总时间 118 单位毫秒
# 循环次数 236, 前一次的时间 16，目前总时间 134 单位毫秒
# 循环次数 237, 前一次的时间 16，目前总时间 150 单位毫秒
# 循环次数 238, 前一次的时间 16，目前总时间 166 单位毫秒
# 循环次数 239, 前一次的时间 16，目前总时间 182 单位毫秒
# 循环次数 240, 前一次的时间 16，目前总时间 198 单位毫秒
# 循环次数 241, 前一次的时间 16，目前总时间 214 单位毫秒
# 循环次数 242, 前一次的时间 16，目前总时间 230 单位毫秒
# 循环次数 243, 前一次的时间 16，目前总时间 246 单位毫秒
# 循环次数 244, 前一次的时间 16，目前总时间 262 单位毫秒
# 循环次数 245, 前一次的时间 16，目前总时间 278 单位毫秒
# 循环次数 246, 前一次的时间 16，目前总时间 294 单位毫秒
# 循环次数 247, 前一次的时间 16，目前总时间 310 单位毫秒
# 循环次数 248, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 249, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 250, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 251, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 252, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 253, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 254, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 255, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 256, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 257, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 258, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 259, 前一次的时间 16，目前总时间 193 单位毫秒
# 循环次数 260, 前一次的时间 17，目前总时间 210 单位毫秒
# 循环次数 261, 前一次的时间 17，目前总时间 227 单位毫秒
# 循环次数 262, 前一次的时间 17，目前总时间 244 单位毫秒
# 循环次数 263, 前一次的时间 17，目前总时间 261 单位毫秒
# 循环次数 264, 前一次的时间 17，目前总时间 278 单位毫秒
# 循环次数 265, 前一次的时间 17，目前总时间 295 单位毫秒
# 循环次数 266, 前一次的时间 17，目前总时间 312 单位毫秒
# 循环次数 267, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 268, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 269, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 270, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 271, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 272, 前一次的时间 17，目前总时间 97 单位毫秒
# 循环次数 273, 前一次的时间 17，目前总时间 114 单位毫秒
# 循环次数 274, 前一次的时间 17，目前总时间 131 单位毫秒
# 循环次数 275, 前一次的时间 16，目前总时间 147 单位毫秒
# 循环次数 276, 前一次的时间 17，目前总时间 164 单位毫秒
# 循环次数 277, 前一次的时间 17，目前总时间 181 单位毫秒
# 循环次数 278, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 279, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 280, 前一次的时间 17，目前总时间 230 单位毫秒
# 循环次数 281, 前一次的时间 17，目前总时间 247 单位毫秒
# 循环次数 282, 前一次的时间 17，目前总时间 264 单位毫秒
# 循环次数 283, 前一次的时间 17，目前总时间 281 单位毫秒
# 循环次数 284, 前一次的时间 17，目前总时间 298 单位毫秒
# 循环次数 285, 前一次的时间 17，目前总时间 315 单位毫秒
# 循环次数 1, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 2, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 3, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 4, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 5, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 6, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 7, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 8, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 9, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 10, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 11, 前一次的时间 16，目前总时间 177 单位毫秒
# 循环次数 12, 前一次的时间 17，目前总时间 194 单位毫秒
# 循环次数 13, 前一次的时间 16，目前总时间 210 单位毫秒
# 循环次数 14, 前一次的时间 17，目前总时间 227 单位毫秒
# 循环次数 15, 前一次的时间 17，目前总时间 244 单位毫秒
# 循环次数 16, 前一次的时间 17，目前总时间 261 单位毫秒
# 循环次数 17, 前一次的时间 17，目前总时间 278 单位毫秒
# 循环次数 18, 前一次的时间 16，目前总时间 294 单位毫秒
# 循环次数 19, 前一次的时间 16，目前总时间 310 单位毫秒
# 循环次数 20, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 21, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 22, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 23, 前一次的时间 17，目前总时间 65 单位毫秒
# 循环次数 24, 前一次的时间 17，目前总时间 82 单位毫秒
# 循环次数 25, 前一次的时间 17，目前总时间 99 单位毫秒
# 循环次数 26, 前一次的时间 17，目前总时间 116 单位毫秒
# 循环次数 27, 前一次的时间 17，目前总时间 133 单位毫秒
# 循环次数 28, 前一次的时间 16，目前总时间 149 单位毫秒
# 循环次数 29, 前一次的时间 16，目前总时间 165 单位毫秒
# 循环次数 30, 前一次的时间 16，目前总时间 181 单位毫秒
# 循环次数 31, 前一次的时间 16，目前总时间 197 单位毫秒
# 循环次数 32, 前一次的时间 16，目前总时间 213 单位毫秒
# 循环次数 33, 前一次的时间 16，目前总时间 229 单位毫秒
# 循环次数 34, 前一次的时间 16，目前总时间 245 单位毫秒
# 循环次数 35, 前一次的时间 16，目前总时间 261 单位毫秒
# 循环次数 36, 前一次的时间 16，目前总时间 277 单位毫秒
# 循环次数 37, 前一次的时间 16，目前总时间 293 单位毫秒
# 循环次数 38, 前一次的时间 16，目前总时间 309 单位毫秒
# 循环次数 39, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 40, 前一次的时间 17，目前总时间 33 单位毫秒
# 循环次数 41, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 42, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 43, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 44, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 45, 前一次的时间 17，目前总时间 118 单位毫秒
# 循环次数 46, 前一次的时间 17，目前总时间 135 单位毫秒
# 循环次数 47, 前一次的时间 17，目前总时间 152 单位毫秒
# 循环次数 48, 前一次的时间 17，目前总时间 169 单位毫秒
# 循环次数 49, 前一次的时间 17，目前总时间 186 单位毫秒
# 循环次数 50, 前一次的时间 17，目前总时间 203 单位毫秒
# 循环次数 51, 前一次的时间 17，目前总时间 220 单位毫秒
# 循环次数 52, 前一次的时间 16，目前总时间 236 单位毫秒
# 循环次数 53, 前一次的时间 16，目前总时间 252 单位毫秒
# 循环次数 54, 前一次的时间 16，目前总时间 268 单位毫秒
# 循环次数 55, 前一次的时间 16，目前总时间 284 单位毫秒
# 循环次数 56, 前一次的时间 16，目前总时间 300 单位毫秒
# 循环次数 57, 前一次的时间 16，目前总时间 316 单位毫秒
# 循环次数 58, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 59, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 60, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 61, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 62, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 63, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 64, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 65, 前一次的时间 17，目前总时间 129 单位毫秒
# 循环次数 66, 前一次的时间 16，目前总时间 145 单位毫秒
# 循环次数 67, 前一次的时间 17，目前总时间 162 单位毫秒
# 循环次数 68, 前一次的时间 17，目前总时间 179 单位毫秒
# 循环次数 69, 前一次的时间 17，目前总时间 196 单位毫秒
# 循环次数 70, 前一次的时间 17，目前总时间 213 单位毫秒
# 循环次数 71, 前一次的时间 17，目前总时间 230 单位毫秒
# 循环次数 72, 前一次的时间 17，目前总时间 247 单位毫秒
# 循环次数 73, 前一次的时间 17，目前总时间 264 单位毫秒
# 循环次数 74, 前一次的时间 16，目前总时间 280 单位毫秒
# 循环次数 75, 前一次的时间 16，目前总时间 296 单位毫秒
# 循环次数 76, 前一次的时间 16，目前总时间 312 单位毫秒
# 循环次数 77, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 78, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 79, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 80, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 81, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 82, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 83, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 84, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 85, 前一次的时间 16，目前总时间 144 单位毫秒
# 循环次数 86, 前一次的时间 16，目前总时间 160 单位毫秒
# 循环次数 87, 前一次的时间 16，目前总时间 176 单位毫秒
# 循环次数 88, 前一次的时间 16，目前总时间 192 单位毫秒
# 循环次数 89, 前一次的时间 16，目前总时间 208 单位毫秒
# 循环次数 90, 前一次的时间 16，目前总时间 224 单位毫秒
# 循环次数 91, 前一次的时间 16，目前总时间 240 单位毫秒
# 循环次数 92, 前一次的时间 16，目前总时间 256 单位毫秒
# 循环次数 93, 前一次的时间 16，目前总时间 272 单位毫秒
# 循环次数 94, 前一次的时间 16，目前总时间 288 单位毫秒
# 循环次数 95, 前一次的时间 17，目前总时间 305 单位毫秒
# 循环次数 96, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 97, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 98, 前一次的时间 17，目前总时间 50 单位毫秒
# 循环次数 99, 前一次的时间 17，目前总时间 67 单位毫秒
# 循环次数 100, 前一次的时间 17，目前总时间 84 单位毫秒
# 循环次数 101, 前一次的时间 17，目前总时间 101 单位毫秒
# 循环次数 102, 前一次的时间 16，目前总时间 117 单位毫秒
# 循环次数 103, 前一次的时间 17，目前总时间 134 单位毫秒
# 循环次数 104, 前一次的时间 16，目前总时间 150 单位毫秒
# 循环次数 105, 前一次的时间 17，目前总时间 167 单位毫秒
# 循环次数 106, 前一次的时间 17，目前总时间 184 单位毫秒
# 循环次数 107, 前一次的时间 17，目前总时间 201 单位毫秒
# 循环次数 108, 前一次的时间 17，目前总时间 218 单位毫秒
# 循环次数 109, 前一次的时间 17，目前总时间 235 单位毫秒
# 循环次数 110, 前一次的时间 17，目前总时间 252 单位毫秒
# 循环次数 111, 前一次的时间 17，目前总时间 269 单位毫秒
# 循环次数 112, 前一次的时间 17，目前总时间 286 单位毫秒
# 循环次数 113, 前一次的时间 17，目前总时间 303 单位毫秒
# 循环次数 114, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 115, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 116, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 117, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 118, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 119, 前一次的时间 17，目前总时间 97 单位毫秒
# 循环次数 120, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 121, 前一次的时间 17，目前总时间 130 单位毫秒
# 循环次数 122, 前一次的时间 17，目前总时间 147 单位毫秒
# 循环次数 123, 前一次的时间 16，目前总时间 163 单位毫秒
# 循环次数 124, 前一次的时间 17，目前总时间 180 单位毫秒
# 循环次数 125, 前一次的时间 17，目前总时间 197 单位毫秒
# 循环次数 126, 前一次的时间 17，目前总时间 214 单位毫秒
# 循环次数 127, 前一次的时间 17，目前总时间 231 单位毫秒
# 循环次数 128, 前一次的时间 17，目前总时间 248 单位毫秒
# 循环次数 129, 前一次的时间 17，目前总时间 265 单位毫秒
# 循环次数 130, 前一次的时间 16，目前总时间 281 单位毫秒
# 循环次数 131, 前一次的时间 16，目前总时间 297 单位毫秒
# 循环次数 132, 前一次的时间 16，目前总时间 313 单位毫秒
# 循环次数 133, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 134, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 135, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 136, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 137, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 138, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 139, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 140, 前一次的时间 16，目前总时间 128 单位毫秒
# 循环次数 141, 前一次的时间 17，目前总时间 145 单位毫秒
# 循环次数 142, 前一次的时间 16，目前总时间 161 单位毫秒
# 循环次数 143, 前一次的时间 17，目前总时间 178 单位毫秒
# 循环次数 144, 前一次的时间 17，目前总时间 195 单位毫秒
# 循环次数 145, 前一次的时间 17，目前总时间 212 单位毫秒
# 循环次数 146, 前一次的时间 16，目前总时间 228 单位毫秒
# 循环次数 147, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 148, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 149, 前一次的时间 16，目前总时间 278 单位毫秒
# 循环次数 150, 前一次的时间 17，目前总时间 295 单位毫秒
# 循环次数 151, 前一次的时间 17，目前总时间 312 单位毫秒
# 循环次数 152, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 153, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 154, 前一次的时间 16，目前总时间 50 单位毫秒
# 循环次数 155, 前一次的时间 16，目前总时间 66 单位毫秒
# 循环次数 156, 前一次的时间 16，目前总时间 82 单位毫秒
# 循环次数 157, 前一次的时间 16，目前总时间 98 单位毫秒
# 循环次数 158, 前一次的时间 16，目前总时间 114 单位毫秒
# 循环次数 159, 前一次的时间 16，目前总时间 130 单位毫秒
# 循环次数 160, 前一次的时间 16，目前总时间 146 单位毫秒
# 循环次数 161, 前一次的时间 16，目前总时间 162 单位毫秒
# 循环次数 162, 前一次的时间 16，目前总时间 178 单位毫秒
# 循环次数 163, 前一次的时间 16，目前总时间 194 单位毫秒
# 循环次数 164, 前一次的时间 16，目前总时间 210 单位毫秒
# 循环次数 165, 前一次的时间 16，目前总时间 226 单位毫秒
# 循环次数 166, 前一次的时间 17，目前总时间 243 单位毫秒
# 循环次数 167, 前一次的时间 17，目前总时间 260 单位毫秒
# 循环次数 168, 前一次的时间 17，目前总时间 277 单位毫秒
# 循环次数 169, 前一次的时间 17，目前总时间 294 单位毫秒
# 循环次数 170, 前一次的时间 17，目前总时间 311 单位毫秒
# 循环次数 171, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 172, 前一次的时间 17，目前总时间 34 单位毫秒
# 循环次数 173, 前一次的时间 17，目前总时间 51 单位毫秒
# 循环次数 174, 前一次的时间 17，目前总时间 68 单位毫秒
# 循环次数 175, 前一次的时间 17，目前总时间 85 单位毫秒
# 循环次数 176, 前一次的时间 17，目前总时间 102 单位毫秒
# 循环次数 177, 前一次的时间 16，目前总时间 118 单位毫秒
# 循环次数 178, 前一次的时间 16，目前总时间 134 单位毫秒
# 循环次数 179, 前一次的时间 16，目前总时间 150 单位毫秒
# 循环次数 180, 前一次的时间 16，目前总时间 166 单位毫秒
# 循环次数 181, 前一次的时间 16，目前总时间 182 单位毫秒
# 循环次数 182, 前一次的时间 16，目前总时间 198 单位毫秒
# 循环次数 183, 前一次的时间 16，目前总时间 214 单位毫秒
# 循环次数 184, 前一次的时间 16，目前总时间 230 单位毫秒
# 循环次数 185, 前一次的时间 16，目前总时间 246 单位毫秒
# 循环次数 186, 前一次的时间 16，目前总时间 262 单位毫秒
# 循环次数 187, 前一次的时间 17，目前总时间 279 单位毫秒
# 循环次数 188, 前一次的时间 17，目前总时间 296 单位毫秒
# 循环次数 189, 前一次的时间 17，目前总时间 313 单位毫秒
# 循环次数 190, 前一次的时间 17，目前总时间 17 单位毫秒
# 循环次数 191, 前一次的时间 16，目前总时间 33 单位毫秒
# 循环次数 192, 前一次的时间 16，目前总时间 49 单位毫秒
# 循环次数 193, 前一次的时间 16，目前总时间 65 单位毫秒
# 循环次数 194, 前一次的时间 16，目前总时间 81 单位毫秒
# 循环次数 195, 前一次的时间 16，目前总时间 97 单位毫秒
# 循环次数 196, 前一次的时间 16，目前总时间 113 单位毫秒
# 循环次数 197, 前一次的时间 16，目前总时间 129 单位毫秒
# 循环次数 198, 前一次的时间 17，目前总时间 146 单位毫秒
# 循环次数 199, 前一次的时间 16，目前总时间 162 单位毫秒
# 循环次数 200, 前一次的时间 16，目前总时间 178 单位毫秒
# 循环次数 201, 前一次的时间 16，目前总时间 194 单位毫秒
# 循环次数 202, 前一次的时间 17，目前总时间 211 单位毫秒
# 循环次数 203, 前一次的时间 17，目前总时间 228 单位毫秒
# 循环次数 204, 前一次的时间 17，目前总时间 245 单位毫秒
# 循环次数 205, 前一次的时间 17，目前总时间 262 单位毫秒
# 循环次数 206, 前一次的时间 16，目前总时间 278 单位毫秒
# 循环次数 207, 前一次的时间 16，目前总时间 294 单位毫秒
# 循环次数 208, 前一次的时间 16，目前总时间 310 单位毫秒
# 循环次数 209, 前一次的时间 16，目前总时间 16 单位毫秒
# 循环次数 210, 前一次的时间 16，目前总时间 32 单位毫秒
# 循环次数 211, 前一次的时间 16，目前总时间 48 单位毫秒
# 循环次数 212, 前一次的时间 16，目前总时间 64 单位毫秒
# 循环次数 213, 前一次的时间 16，目前总时间 80 单位毫秒
# 循环次数 214, 前一次的时间 16，目前总时间 96 单位毫秒
# 循环次数 215, 前一次的时间 16，目前总时间 112 单位毫秒
# 循环次数 216, 前一次的时间 17，目前总时间 129 单位毫秒
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-764cecf7c791> in <module>
#     191     best = 0 # 本次游戏的最佳分数
#     192     while True:
# --> 193         best = main(best)
#     194         time.sleep(1)
#
# <ipython-input-1-764cecf7c791> in main(best)
#     138     clock = pygame.time.Clock() # 创建帮助记录时间的对象
#     139     while going:
# --> 140         lastt = clock.tick(60) # 帧率 60
#     141         dt += lastt # 累计时间
#     142         c += 1
#
# KeyboardInterrupt:
