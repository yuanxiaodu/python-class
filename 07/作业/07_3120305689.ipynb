# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
plt.show()
# plt.savefig('test.pdf', format='pdf')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.

# %%
# OO-style
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
# pyplot-style

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt


def loadDataSet():
    X = [];
    Y = []
    file = open('ex2data2.txt')
    for line in file.readlines():
        line = line.strip().split(',')
        X.append([float(line[0]), float(line[1])])
        Y.append(int(line[2]))
    file.close()
    return X, Y


def sigmoid(inX):
    return 1 / (1 + np.exp(-inX))

X, Y = loadDataSet()
X = np.array(X)
Y = np.array(Y)
n = np.shape(X)[0]
X_pos = [];
X_neg = []
for i in range(n):
    if int(Y[i]) == 1:
        X_pos.append([X[i, 0], X[i, 1]])
    else:
        X_neg.append([X[i, 0], X[i, 1]])

X_pos = np.array(X_pos)
X_neg = np.array(X_neg)
Y = Y[:, np.newaxis]

numIterations = 1000
theta = np.random.rand(5, 1)
alpha = 10e-4
m = np.shape(X)[0]
xtrain = np.array([np.array([1., x[0], x[1], x[0] ** 2, x[1] ** 2]) for x in X]).T
for i in range(0, numIterations):
    y_pred = sigmoid(np.dot(xtrain.T,theta))
    loss = y_pred - Y
    theta = theta - alpha * np.dot(xtrain, loss)

x_ax = np.arange(-1, 1, 0.1)
y_ax = np.arange(-1, 1, 0.1)
x_ax, y_ax = np.meshgrid(x_ax, y_ax)
para = theta.reshape(5).tolist()
fig = plt.figure()
ax = fig.add_subplot(111)
ax.contour(x_ax, y_ax, para[0] + para[1] * x_ax + para[2] * y_ax + para[3] * (x_ax ** 2) + para[4] * (y_ax ** 2), [0])
ax.scatter(X_pos[:, 0], X_pos[:, 1], s=20, marker='o', alpha=.5)
ax.scatter(X_neg[:, 0], X_neg[:, 1], s=20, marker='^',alpha=.5)
plt.xlabel('x');
plt.ylabel('y')
plt.show()

# %%
var1 = 'Hello World!'
var2 = "Runoob"
print(type(var1))
print(len(var1))
print ("var1[0]: ", var1[0])
print ("var2[1:5]: ", var2[1:5])
# Out:
# <class 'str'>
# 12
# var1[0]:  H
# var2[1:5]:  unoo

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
# Operating System Interface
import os
os.getcwd()      # Return the current working directory
# Out:
# 'D:\\ProgramData\\jupyter_notebook（py3.8）'

# %%
# File Wildcards
import glob
glob.glob('*.py')
# Out:
# ['Logistic_duan.py']

# %%
# Command Line Arguments
import sys
print(sys.argv)
# Out:
# ['D:\\ProgramData\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\86156\\AppData\\Roaming\\jupyter\\runtime\\kernel-d91c2f6c-862a-42eb-8171-8e8aa1a388b4.json']

# %%
# Mathematics
import math
print(math.cos(math.pi / 4))
print(math.log(1024, 2))
# Out:
# 0.7071067811865476
# 10.0

# %%
import random
print(random.choice(['apple', 'pear', 'banana']))
print(random.sample(range(100), 10))
print(random.random())
print(random.randrange(6))
# Out:
# pear
# [35, 18, 37, 44, 89, 19, 43, 79, 25, 59]
# 0.9465078930349835
# 2

# %%
import statistics
data = [2.75, 1.75, 1.25, 0.25, 0.5, 1.25, 3.5]
statistics.mean(data)
statistics.median(data)
statistics.variance(data)
# Out:
# 1.3720238095238095

# %%
# Internet Access
from urllib.request import urlopen
with urlopen('http://news.xjtu.edu.cn/zyxw.htm') as response:
    for line in response:
        line = line.decode('utf-8')  # Decoding the binary data to text.
        if '西迁精神' in line or '十九大' in line:  # look for Eastern Time
            print(line)

# %%
# Dates and Times
# dates are easily constructed and formatted
from datetime import date
now = date.today()
print(now)
print(now.strftime("%m-%d-%y. %d %b %Y is a %A on the %d day of %B."))
# dates support calendar arithmetic
birthday = date(1964, 7, 31)
age = now - birthday
print(age)
print(age.days)
# Out:
# 2020-12-30
# 12-30-20. 30 Dec 2020 is a Wednesday on the 30 day of December.
# 20606 days, 0:00:00
# 20606

# %%
# Output Formatting
import reprlib
reprlib.repr(set('supercalifragilisticexpialidocious'))
# Out:
# "{'a', 'c', 'd', 'e', 'f', 'g', ...}"

# %%
import pprint
t = [[[['black', 'cyan'], 'white', ['green', 'red']], [['magenta',
    'yellow'], 'blue']]]

pprint.pprint(t, width=30)
# Out:
# [[[['black', 'cyan'],
#    'white',
#    ['green', 'red']],
#   [['magenta', 'yellow'],
#    'blue']]]

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()
# Out:
# <ipython-input-24-9398a8f76be2>:30: MatplotlibDeprecationWarning: SymmetricalLogScale got an unexpected keyword argument 'linthresh'. In the future this will raise TypeError
#   plt.yscale('symlog', linthresh=0.01)
