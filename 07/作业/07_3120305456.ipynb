# %%
import requests
from lxml import etree

if __name__ == "__main__":
    url = "https://s.weibo.com/top/summary"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:84.0) Gecko/20100101 Firefox/84.0"
    }
    page = requests.get(url, headers).text
    print(page)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <meta name="renderer" content="webkit"/>
#     <meta name="viewport" content="initial-scale=1,minimum-scale=1"/>
#     <title>微博搜索-热搜榜</title>
#     <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/video.css?version=202012251903" rel="stylesheet"/>
#     <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/global.css?version=202012251903" rel="stylesheet"/>
#     <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/module.css?version=202012251903" rel="stylesheet"/>
#     <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/page.css?version=202012251903" rel="stylesheet"/>
#     <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/card.css?version=202012251903" rel="stylesheet"/>
#     <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/css_v6/layer/layer_show_pic.css?version=202012251903"
#           rel="stylesheet"/>
#
#     <script type="text/javascript">
#         var $PHOTO_TAGS=[]
#         var $CONFIG = {};
#         $CONFIG['islogin'] = '0';
#         $CONFIG['uid'] = '0';
#         $CONFIG['entry'] = 'weisousuo';
#         $CONFIG['setCover'] = 1; //ie6hack
#         $CONFIG['version'] = '202012251903';
#         $CONFIG['bigpipe'] = 'false';
#         $CONFIG['timeDiff'] = (new Date() - 1609894972000);
#         $CONFIG['product'] = 'search';
#         $CONFIG['pageid'] = 'top';
#         $CONFIG['skin'] = '';
#         $CONFIG['lang'] = 'zh-cn';
#         $CONFIG['jsPath'] = '//jstest.t.sinajs.cn/t4/';
#         $CONFIG['cssPath'] = '//img.t.sinajs.cn/t4/';
#         $CONFIG['imgPath'] = '//img.t.sinajs.cn/t4/';
#         $CONFIG['servertime'] = 1609894972;
#         $CONFIG['ad_url_jump'] = '';
#         $CONFIG['$webim'] = 0; //1;
#         $CONFIG['mJsPath'] = ['https://js{n}.t.sinajs.cn/t4/', 1, 2];
#         $CONFIG['mCssPath'] = ['https://img{n}.t.sinajs.cn/t4/', 1, 2];
#         $CONFIG['s_domain'] = '//s.weibo.com';
#         $CONFIG['isAuto'] = 0;//0自动播放
#     </script>
#
#
#     <script src="//js.t.sinajs.cn/t5/pack/js/bootstrap.js"></script>
# </head>
# <body class="wbs-hotrank">
# <div class="m-main">
#     <!--搜索-->
# <div class="m-search" id="pl_feedtop_top">
#     <div class="logo"><a href="/" class="logo_img"></a></div>
#     <div class="searchbox" node-type="searchBar">
#     <div class="search-input">
#         <input type="text" node-type="text" maxlength="40" autocomplete="off" value=""/>
#         <div class="m-sug-list" node-type="suggestbox">
#         </div>
#     </div>
#     <button class="s-btn-b" node-type="submit" >搜索</button>
# </div>
#     </div>
# <!--/搜索-->
#     <!--内容 aa-->
#     <div class="m-wrap" id="plc_main">
#         <div class="menu">
#             <a href="summary?cate=realtimehot" title="热搜榜" class="cur">热搜榜</a>
#             <a href="summary?cate=socialevent" title="要闻榜">要闻榜</a>
#             <a href="summary?cate=total&key=friends" title="好友搜">好友搜</a>
#         </div>
#         <div class="data" id="pl_top_realtimehot">
#             <table>
#                 <thead>
#                 <tr class="thead_tr">
#                     <th class="th-01">序号</th>
#                     <th class="th-02">关键词</th>
#                     <th class="th-03"></th>
#                 </tr>
#                 </thead>
#                 <tbody>
#                                                         <tr class="">
set="UTF-8" src="//js.t.sinajs.cn/t4/apps/searchpc/js/pc/js/conf/summary.js?version=202012251903"></script>
# </div>
# <!--脚部-->
# <div class="m-footer">
#     <div class="bottom">
#         <div class="m-outlink">
#             <div class="link">
#                 <a href="http://ir.weibo.com/phoenix.zhtml?c=253076&p=irol-irhome" class="icon-wb" target="_blank" title="关于微博">关于微博</a>
#                 <a href="https://kefu.weibo.com/" target="_blank" title="微博帮助">微博帮助</a>
#                 <a href="https://s.weibo.com/weibo?q=%23%E5%BE%AE%E5%BB%BA%E8%AE%AE%23&bottomnav=1&wvr=6" target="_blank" title="意见反馈">意见反馈</a>
#                 <a href="http://open.weibo.com/?bottomnav=1&wvr=5" target="_blank" title="开放平台">开放平台</a>
#                 <a href="http://hr.weibo.com/?bottomnav=1&wvr=5" target="_blank" title="微博招聘">微博招聘</a>
#                 <a href="http://news.sina.com.cn/guide/?bottomnav=1&wvr=5" target="_blank" title="新浪网导航">新浪网导航</a>
#                 <a href="http://service.account.weibo.com/?bottomnav=1&wvr=5&is_redirected=1" target="_blank" title="社区管理中心">社区管理中心</a>
#                 <a href="http://service.account.weibo.com/roles/gongyue?bottomnav=1&wvr=5&is_redirected=1" target="_blank" title="微博社区公约">微博社区公约</a>
#             </div>
#             <p class="copyright">
#                 Copyright © 2009-2021 WEIBO 北京微梦创科网络技术有限公司
#                 <a href="https://weibo.com/aj/static/jww.html" target="_blank">京网文[2011]0398-130号</a>
#                 <a href="http://www.miibeian.gov.cn" target="_blank" target="_blank">京ICP备12002058号</a>
#                 <!-- <select id="pl_language_language">
#                     <option value="zh-cn" selected="selected">中文(简体)</option>
#                     <option value="zh-tw">中文(繁体)</option>
#                 </select> -->
#                 </span>
#             </p>
#         </div>
#     </div>
#     <!-- <script src="https://js.t.sinajs.cn/t5/pack/static/musicplayer/musicplayer_stk_v6.1.5.js"></script> -->
#     <script>
#     // //设置用户uid 用于同步赞状态
#     // WEIBO_MUSIC_PLAYER.load({page_id:''});
#     // //监听赞事件
#     // //监听分享事件
#     // WEIBO_MUSIC_PLAYER.on('share', function (evt, song) {
#     //     alert(song.copy);
#     //     song //歌曲的所有信息
#     // });
#     </script>
#
#
# </div>
# <!--脚部-->
# <!--回到顶部-->
# <div id="pl_common_scrollToTop">
#     <div class="m-gotop" node-type="scrollToTop" style="display: none;">
#         <a href="javascript:void(0);" class="wbicon" >Ú</a>
#     </div>
# </div>
# <!--/回到顶部-->
#
# <script src="//js.t.sinajs.cn/t6/home/js/pl/top/topInit.js"></script>
# <script type="text/javascript">
#     (function() {
#         WBtopGlobal && WBtopGlobal.init({
#             'islogin':0,
#             "backurl":"//s.weibo.com"
#         });
#     })();
# </script>
# <script type="text/javascript" charset="utf-8" async="" src="//js.t.sinajs.cn/open/analytics/js/suda.js?version=2018080418263900"></script>
# <!-- SUDA_CODE_START -->
# <noscript><img width="0" height="0" src="//beacon.sina.com.cn/a.gif?noScript" border="0" alt="" /></noscript>
# <!-- SUDA_CODE_END -->
# </body>
# <!-- video -->
# <!-- <script src="//js.t.sinajs.cn/t6/page/js/pl/third/search/index.js?version=2018073117" type="text/javascript"></script> -->
#
# </html>

# %%
import requests
from lxml import etree

if __name__ == "__main__":
    url = "https://s.weibo.com/top/summary"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:84.0) Gecko/20100101 Firefox/84.0"
    }
    page = requests.get(url, headers).text
    tree = etree.HTML(page)
    hotSearch_list = tree.xpath('//tbody/tr')
    del hotSearch_list[0]
    hotSearch_all_data = []
    for hotSearch in hotSearch_list:
        rank = hotSearch.xpath('./td[@class="td-01 ranktop"]/text()')[0]
        title = hotSearch.xpath('./td[@class="td-02"]/a/text()')[0]
        hot_degree = hotSearch.xpath('./td[@class="td-02"]/span/text()')[0]
        hotSearch_data = {
            "rank":rank;
            "title":title;
            "hot_degree":hot_degree
        }
        hotSearch_all_data.append(hotSearch_data)
    print(hotSearch_all_data)
# Out:
#   File "<ipython-input-2-cbd6e9507b5c>", line 19
#     "rank":rank;
#                ^
# SyntaxError: invalid syntax

# %%
import requests
from lxml import etree

if __name__ == "__main__":
    url = "https://s.weibo.com/top/summary"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:84.0) Gecko/20100101 Firefox/84.0"
    }
    page = requests.get(url, headers).text
    tree = etree.HTML(page)
    hotSearch_list = tree.xpath('//tbody/tr')
    del hotSearch_list[0]
    hotSearch_all_data = []
    for hotSearch in hotSearch_list:
        rank = hotSearch.xpath('./td[@class="td-01 ranktop"]/text()')[0]
        title = hotSearch.xpath('./td[@class="td-02"]/a/text()')[0]
        hot_degree = hotSearch.xpath('./td[@class="td-02"]/span/text()')[0]
        hotSearch_data = [rank, title, hot_degree]
        hotSearch_all_data.append(hotSearch_data)
    print(hotSearch_all_data)
# Out:
# [['1', '侃爷卡戴珊离婚', '5016562'], ['2', '石家庄此次疫情呈现家庭聚集性特点', '1971607'], ['3', '全国冻哭预警', '1884397'], ['4', '上海白领体检异常率99%', '1758227'], ['5', '小红书崩了', '1167511'], ['6', '铁锅爱炖糖葫芦开锅', '1156589'], ['7', '河北新增20例本土确诊', '1150174'], ['8', '特朗普签令禁止与8款中国应用交易', '981433'], ['9', '大连88岁新冠肺炎确诊患者出院', '897990'], ['10', '石家庄全寄宿学校实行全封闭管理', '842334'], ['11', '宋运辉梁思申关系被误会', '759189'], ['12', '木子洋回应被认成辣目洋子', '709554'], ['13', '浙江新增1例西班牙输入无症状', '644419'], ['14', '岳云鹏 我还能改成岳云啥', '594793'], ['15', '港警今早至少拘捕50人', '522547'], ['16', '尼格买提拦撒贝宁干饭太难了', '518498'], ['17', '杨幂演技', '513719'], ['18', '拼多多员工去世后股价再次暴涨', '508821'], ['19', '满25岁就不用定闹钟了', '497733'], ['20', '付豪', '492425'], ['21', '老师晚自习带学生看工地加班', '485212'], ['22', '喜欢的人拿着花向你奔来', '478007'], ['23', '晴雅集', '469805'], ['24', '8个省会房价跌回一年前', '468129'], ['25', '石家庄客运总站暂时停运', '447043'], ['26', '急寻辽A5V97P网约车乘客', '420195'], ['27', '重庆现蘑菇林地铁站', '411500'], ['28', '西班牙发现至少50例变异新冠病毒感染者', '380682'], ['29', '中日韩男团的区别', '356031'], ['30', '河北20例确诊病例行动轨迹', '355875'], ['31', '满足万千少女梦想的婚纱', '350894'], ['32', '彭斯告诉特朗普自己无权改变大选结果', '345794'], ['33', '雪梨直播', '329325'], ['34', '南京一隧道失火致2辆轿车烧毁', '320968'], ['35', 'GOT7金有谦解约', '301849'], ['36', '河北境内多条高速禁止上道', '290415'], ['37', '蝴蝶结还能这么玩', '286896'], ['38', '王者荣耀', '279012'], ['39', '全国中高风险地区图', '275617'], ['40', '钟南山来石家庄系谣言', '218311'], ['41', '猫 老虎 被雨淋湿的狗狗', '199762'], ['42', '福建鼓励弹性休假倡议就地过节', '194577'], ['43', '股市', '193787'], ['44', '北京大风', '193376'], ['45', '白酒股', '192340'], ['46', '金融诈骗案女性举报者占比近7成', '191989'], ['47', '顶楼大结局', '191951'], ['48', '无证驾驶儿子新车连撞10车', '181736'], ['49', '北京气温', '179662'], ['50', '美国已有5个州发现变异病毒', '178836']]

# %%
import requests
from lxml import etree
import pickle
if __name__ == "__main__":
    url = "https://s.weibo.com/top/summary"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:84.0) Gecko/20100101 Firefox/84.0"
    }
    page = requests.get(url, headers).text
    tree = etree.HTML(page)
    hotSearch_list = tree.xpath('//tbody/tr')
    del hotSearch_list[0]
    hotSearch_all_data = []
    for hotSearch in hotSearch_list:
        rank = hotSearch.xpath('./td[@class="td-01 ranktop"]/text()')[0]
        title = hotSearch.xpath('./td[@class="td-02"]/a/text()')[0]
        hot_degree = hotSearch.xpath('./td[@class="td-02"]/span/text()')[0]
        hotSearch_data = [rank, title, hot_degree]
        hotSearch_all_data.append(hotSearch_data)
    with open('./微博热搜.pkl', 'wb') as f:
        pickle.dump(hotSearch_all_data, f)

# %%
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
print(data)
# Out:
# [['1', '侃爷卡戴珊离婚', '4668020'], ['2', '石家庄此次疫情呈现家庭聚集性特点', '2070281'], ['3', '全国冻哭预警', '1870435'], ['4', '上海白领体检异常率99%', '1828825'], ['5', '小红书崩了', '1166393'], ['6', '范丞丞程潇新剧定档', '1149965'], ['7', '河北新增20例本土确诊', '1144192'], ['8', '特朗普签令禁止与8款中国应用交易', '995363'], ['9', '大连88岁新冠肺炎确诊患者出院', '905885'], ['10', '石家庄全寄宿学校实行全封闭管理', '852429'], ['11', '宋运辉梁思申关系被误会', '761661'], ['12', '木子洋回应被认成辣目洋子', '708295'], ['13', '浙江新增1例西班牙输入无症状', '624599'], ['14', '岳云鹏 我还能改成岳云啥', '545406'], ['15', '港警今早至少拘捕50人', '526810'], ['16', '尼格买提拦撒贝宁干饭太难了', '517156'], ['17', '杨幂演技', '511140'], ['18', '拼多多员工去世后股价再次暴涨', '506456'], ['19', '满25岁就不用定闹钟了', '502240'], ['20', '付豪', '498658'], ['21', '老师晚自习带学生看工地加班', '492827'], ['22', '喜欢的人拿着花向你奔来', '482912'], ['23', '晴雅集', '480752'], ['24', '8个省会房价跌回一年前', '474970'], ['25', '石家庄客运总站暂时停运', '452693'], ['26', '河北20例确诊病例行动轨迹', '444605'], ['27', '急寻辽A5V97P网约车乘客', '429347'], ['28', '重庆现蘑菇林地铁站', '416007'], ['29', '西班牙发现至少50例变异新冠病毒感染者', '373034'], ['30', '满足万千少女梦想的婚纱', '354738'], ['31', '雪梨直播', '332440'], ['32', '彭斯告诉特朗普自己无权改变大选结果', '332291'], ['33', '南京一隧道失火致2辆轿车烧毁', '330025'], ['34', '中日韩男团的区别', '326755'], ['35', '河北境内多条高速禁止上道', '297493'], ['36', '蝴蝶结还能这么玩', '288336'], ['37', '王者荣耀', '280874'], ['38', 'GOT7金有谦解约', '271788'], ['39', '全国中高风险地区图', '260068'], ['40', '钟南山来石家庄系谣言', '221613'], ['41', '猫 老虎 被雨淋湿的狗狗', '207206'], ['42', '北京大风', '195703'], ['43', '福建鼓励弹性休假倡议就地过节', '191828'], ['44', '股市', '190652'], ['45', '白酒股', '190574'], ['46', '顶楼大结局', '190504'], ['47', '金融诈骗案女性举报者占比近7成', '187425'], ['48', '无证驾驶儿子新车连撞10车', '184564'], ['49', '北京气温', '181899'], ['50', '美国已有5个州发现变异病毒', '181217']]

# %%
import pickle
import pandas as pd
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
frame = pd.dataframe(data)
frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-fb862337a83e> in <module>
#       3 f = open('./微博热搜.pkl', 'rb')
#       4 data = pickle.load(f)
# ----> 5 frame = pd.dataframe(data)
#       6 frame
#
# D:\ANACONDA\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
import pickle
import pandas as pd
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
frame = pd.DataFrame(data)
frame
# Out:
#      0                    1        2
# 0    1              侃爷卡戴珊离婚  4668020
# 1    2     石家庄此次疫情呈现家庭聚集性特点  2070281
# 2    3               全国冻哭预警  1870435
# 3    4         上海白领体检异常率99%  1828825
# 4    5                小红书崩了  1166393
# 5    6            范丞丞程潇新剧定档  1149965
# 6    7          河北新增20例本土确诊  1144192
# 7    8     特朗普签令禁止与8款中国应用交易   995363
# 8    9      大连88岁新冠肺炎确诊患者出院   905885
# 9   10      石家庄全寄宿学校实行全封闭管理   852429
# 10  11          宋运辉梁思申关系被误会   761661
# 11  12         木子洋回应被认成辣目洋子   708295
# 12  13       浙江新增1例西班牙输入无症状   624599
# 13  14         岳云鹏 我还能改成岳云啥   545406
# 14  15          港警今早至少拘捕50人   526810
# 15  16        尼格买提拦撒贝宁干饭太难了   517156
# 16  17                 杨幂演技   511140
# 17  18       拼多多员工去世后股价再次暴涨   506456
# 18  19          满25岁就不用定闹钟了   502240
# 19  20                   付豪   498658
# 20  21        老师晚自习带学生看工地加班   492827
# 21  22          喜欢的人拿着花向你奔来   482912
# 22  23                  晴雅集   480752
# 23  24          8个省会房价跌回一年前   474970
# 24  25          石家庄客运总站暂时停运   452693
# 25  26        河北20例确诊病例行动轨迹   444605
# 26  27       急寻辽A5V97P网约车乘客   429347
# 27  28            重庆现蘑菇林地铁站   416007
# 28  29  西班牙发现至少50例变异新冠病毒感染者   373034
# 29  30          满足万千少女梦想的婚纱   354738
# 30  31                 雪梨直播   332440
# 31  32    彭斯告诉特朗普自己无权改变大选结果   332291
# 32  33       南京一隧道失火致2辆轿车烧毁   330025
# 33  34             中日韩男团的区别   326755
# 34  35         河北境内多条高速禁止上道   297493
# 35  36             蝴蝶结还能这么玩   288336
# 36  37                 王者荣耀   280874
# 37  38            GOT7金有谦解约   271788
# 38  39            全国中高风险地区图   260068
# 39  40           钟南山来石家庄系谣言   221613
# 40  41         猫 老虎 被雨淋湿的狗狗   207206
# 41  42                 北京大风   195703
# 42  43       福建鼓励弹性休假倡议就地过节   191828
# 43  44                   股市   190652
# 44  45                  白酒股   190574
# 45  46                顶楼大结局   190504
# 46  47      金融诈骗案女性举报者占比近7成   187425
# 47  48        无证驾驶儿子新车连撞10车   184564
# 48  49                 北京气温   181899
# 49  50        美国已有5个州发现变异病毒   181217

# %%
import pickle
import pandas as pd
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
frame = pd.DataFrame(data, columns=["排名", "关键词", "热度"])
frame
# Out:
#     排名                  关键词       热度
# 0    1              侃爷卡戴珊离婚  4668020
# 1    2     石家庄此次疫情呈现家庭聚集性特点  2070281
# 2    3               全国冻哭预警  1870435
# 3    4         上海白领体检异常率99%  1828825
# 4    5                小红书崩了  1166393
# 5    6            范丞丞程潇新剧定档  1149965
# 6    7          河北新增20例本土确诊  1144192
# 7    8     特朗普签令禁止与8款中国应用交易   995363
# 8    9      大连88岁新冠肺炎确诊患者出院   905885
# 9   10      石家庄全寄宿学校实行全封闭管理   852429
# 10  11          宋运辉梁思申关系被误会   761661
# 11  12         木子洋回应被认成辣目洋子   708295
# 12  13       浙江新增1例西班牙输入无症状   624599
# 13  14         岳云鹏 我还能改成岳云啥   545406
# 14  15          港警今早至少拘捕50人   526810
# 15  16        尼格买提拦撒贝宁干饭太难了   517156
# 16  17                 杨幂演技   511140
# 17  18       拼多多员工去世后股价再次暴涨   506456
# 18  19          满25岁就不用定闹钟了   502240
# 19  20                   付豪   498658
# 20  21        老师晚自习带学生看工地加班   492827
# 21  22          喜欢的人拿着花向你奔来   482912
# 22  23                  晴雅集   480752
# 23  24          8个省会房价跌回一年前   474970
# 24  25          石家庄客运总站暂时停运   452693
# 25  26        河北20例确诊病例行动轨迹   444605
# 26  27       急寻辽A5V97P网约车乘客   429347
# 27  28            重庆现蘑菇林地铁站   416007
# 28  29  西班牙发现至少50例变异新冠病毒感染者   373034
# 29  30          满足万千少女梦想的婚纱   354738
# 30  31                 雪梨直播   332440
# 31  32    彭斯告诉特朗普自己无权改变大选结果   332291
# 32  33       南京一隧道失火致2辆轿车烧毁   330025
# 33  34             中日韩男团的区别   326755
# 34  35         河北境内多条高速禁止上道   297493
# 35  36             蝴蝶结还能这么玩   288336
# 36  37                 王者荣耀   280874
# 37  38            GOT7金有谦解约   271788
# 38  39            全国中高风险地区图   260068
# 39  40           钟南山来石家庄系谣言   221613
# 40  41         猫 老虎 被雨淋湿的狗狗   207206
# 41  42                 北京大风   195703
# 42  43       福建鼓励弹性休假倡议就地过节   191828
# 43  44                   股市   190652
# 44  45                  白酒股   190574
# 45  46                顶楼大结局   190504
# 46  47      金融诈骗案女性举报者占比近7成   187425
# 47  48        无证驾驶儿子新车连撞10车   184564
# 48  49                 北京气温   181899
# 49  50        美国已有5个州发现变异病毒   181217

# %%
import pickle
import pandas as pd
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
frame = pd.DataFrame(data, columns=["排名", "关键词", "热度"], index=False)
frame
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-3e9b713a68d3> in <module>
#       3 f = open('./微博热搜.pkl', 'rb')
#       4 data = pickle.load(f)
# ----> 5 frame = pd.DataFrame(data, columns=["排名", "关键词", "热度"], index=False)
#       6 frame
#
# D:\ANACONDA\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     484                             index = ibase.default_index(len(data))
#     485
# --> 486                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     487                 else:
#     488                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# D:\ANACONDA\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      64         index = extract_index(arrays)
#      65     else:
# ---> 66         index = ensure_index(index)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
#
# D:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    5356             index_like = copy(index_like)
#    5357
# -> 5358     return Index(index_like)
#    5359
#    5360
#
# D:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     420             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#     421         elif data is None or is_scalar(data):
# --> 422             raise cls._scalar_data_error(data)
#     423         else:
#     424             if tupleize_cols and is_list_like(data):
#
# TypeError: Index(...) must be called with a collection of some kind, False was passed

# %%
import pickle
import pandas as pd
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
frame = pd.DataFrame(data, columns=["排名", "关键词", "热度"], index=[])
frame
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\ANACONDA\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1670         blocks = form_blocks(arrays, names, axes)
# -> 1671         mgr = BlockManager(blocks, axes)
#    1672         mgr._consolidate_inplace()
#
# D:\ANACONDA\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     138         if do_integrity_check:
# --> 139             self._verify_integrity()
#     140
#
# D:\ANACONDA\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     333             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 334                 construction_error(tot_items, block.shape[1:], self.axes)
#     335         if len(self.items) != tot_items:
#
# D:\ANACONDA\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#
# ValueError: Shape of passed values is (50, 3), indices imply (0, 3)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b1aef5dade26> in <module>
#       3 f = open('./微博热搜.pkl', 'rb')
#       4 data = pickle.load(f)
# ----> 5 frame = pd.DataFrame(data, columns=["排名", "关键词", "热度"], index=[])
#       6 frame
#
# D:\ANACONDA\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     484                             index = ibase.default_index(len(data))
#     485
# --> 486                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     487                 else:
#     488                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# D:\ANACONDA\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      72     axes = [ensure_index(columns), index]
#      73
# ---> 74     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      75
#      76
#
# D:\ANACONDA\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1673         return mgr
#    1674     except ValueError as e:
# -> 1675         construction_error(len(arrays), arrays[0].shape, axes, e)
#    1676
#    1677
#
# D:\ANACONDA\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (50, 3), indices imply (0, 3)

# %%
import pickle
import pandas as pd
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
frame = pd.DataFrame(data, columns=["排名", "关键词", "热度"])
pd.DataFrame.reset_index(drop=True)
frame
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-85ed2d01d4be> in <module>
#       4 data = pickle.load(f)
#       5 frame = pd.DataFrame(data, columns=["排名", "关键词", "热度"])
# ----> 6 pd.DataFrame.reset_index(drop=True)
#       7 frame
#
# TypeError: reset_index() missing 1 required positional argument: 'self'

# %%
import pickle
import pandas as pd
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
nu = []
for i in range(50):
    nu.append('')
frame = pd.DataFrame(data, index=nu, columns=["排名", "关键词", "热度"])
frame
# Out:
#   排名                  关键词       热度
#    1              侃爷卡戴珊离婚  4668020
#    2     石家庄此次疫情呈现家庭聚集性特点  2070281
#    3               全国冻哭预警  1870435
#    4         上海白领体检异常率99%  1828825
#    5                小红书崩了  1166393
#    6            范丞丞程潇新剧定档  1149965
#    7          河北新增20例本土确诊  1144192
#    8     特朗普签令禁止与8款中国应用交易   995363
#    9      大连88岁新冠肺炎确诊患者出院   905885
#   10      石家庄全寄宿学校实行全封闭管理   852429
#   11          宋运辉梁思申关系被误会   761661
#   12         木子洋回应被认成辣目洋子   708295
#   13       浙江新增1例西班牙输入无症状   624599
#   14         岳云鹏 我还能改成岳云啥   545406
#   15          港警今早至少拘捕50人   526810
#   16        尼格买提拦撒贝宁干饭太难了   517156
#   17                 杨幂演技   511140
#   18       拼多多员工去世后股价再次暴涨   506456
#   19          满25岁就不用定闹钟了   502240
#   20                   付豪   498658
#   21        老师晚自习带学生看工地加班   492827
#   22          喜欢的人拿着花向你奔来   482912
#   23                  晴雅集   480752
#   24          8个省会房价跌回一年前   474970
#   25          石家庄客运总站暂时停运   452693
#   26        河北20例确诊病例行动轨迹   444605
#   27       急寻辽A5V97P网约车乘客   429347
#   28            重庆现蘑菇林地铁站   416007
#   29  西班牙发现至少50例变异新冠病毒感染者   373034
#   30          满足万千少女梦想的婚纱   354738
#   31                 雪梨直播   332440
#   32    彭斯告诉特朗普自己无权改变大选结果   332291
#   33       南京一隧道失火致2辆轿车烧毁   330025
#   34             中日韩男团的区别   326755
#   35         河北境内多条高速禁止上道   297493
#   36             蝴蝶结还能这么玩   288336
#   37                 王者荣耀   280874
#   38            GOT7金有谦解约   271788
#   39            全国中高风险地区图   260068
#   40           钟南山来石家庄系谣言   221613
#   41         猫 老虎 被雨淋湿的狗狗   207206
#   42                 北京大风   195703
#   43       福建鼓励弹性休假倡议就地过节   191828
#   44                   股市   190652
#   45                  白酒股   190574
#   46                顶楼大结局   190504
#   47      金融诈骗案女性举报者占比近7成   187425
#   48        无证驾驶儿子新车连撞10车   184564
#   49                 北京气温   181899
#   50        美国已有5个州发现变异病毒   181217

# %%
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
all_title = []
for i in data:
    all_title.append(i[1])
print(all_title)
# Out:
# ['侃爷卡戴珊离婚', '石家庄此次疫情呈现家庭聚集性特点', '全国冻哭预警', '上海白领体检异常率99%', '小红书崩了', '范丞丞程潇新剧定档', '河北新增20例本土确诊', '特朗普签令禁止与8款中国应用交易', '大连88岁新冠肺炎确诊患者出院', '石家庄全寄宿学校实行全封闭管理', '宋运辉梁思申关系被误会', '木子洋回应被认成辣目洋子', '浙江新增1例西班牙输入无症状', '岳云鹏 我还能改成岳云啥', '港警今早至少拘捕50人', '尼格买提拦撒贝宁干饭太难了', '杨幂演技', '拼多多员工去世后股价再次暴涨', '满25岁就不用定闹钟了', '付豪', '老师晚自习带学生看工地加班', '喜欢的人拿着花向你奔来', '晴雅集', '8个省会房价跌回一年前', '石家庄客运总站暂时停运', '河北20例确诊病例行动轨迹', '急寻辽A5V97P网约车乘客', '重庆现蘑菇林地铁站', '西班牙发现至少50例变异新冠病毒感染者', '满足万千少女梦想的婚纱', '雪梨直播', '彭斯告诉特朗普自己无权改变大选结果', '南京一隧道失火致2辆轿车烧毁', '中日韩男团的区别', '河北境内多条高速禁止上道', '蝴蝶结还能这么玩', '王者荣耀', 'GOT7金有谦解约', '全国中高风险地区图', '钟南山来石家庄系谣言', '猫 老虎 被雨淋湿的狗狗', '北京大风', '福建鼓励弹性休假倡议就地过节', '股市', '白酒股', '顶楼大结局', '金融诈骗案女性举报者占比近7成', '无证驾驶儿子新车连撞10车', '北京气温', '美国已有5个州发现变异病毒']

# %%
import jieba
jieba.enable_paddle()
cut_word = []
for t in all_title:
    seg_list = jieba.cut_for_search(t)
    cut_word.append(list(seg_list))
print(cut_word)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-20b45aa91c82> in <module>
# ----> 1 import jieba
#       2 jieba.enable_paddle()
#       3 cut_word = []
#       4 for t in all_title:
#       5     seg_list = jieba.cut_for_search(t)
#
# ModuleNotFoundError: No module named 'jieba'

# %%
from ltp import LTP
ltp = LTP()
cut_word = []
cut_word_type=[]
for t in title:
    seg, hidden = ltp.seg([t])
    ner = ltp.ner(hidden)
    if len(ner[0])==0:
        continue
    for ner_t in ner[0]:
        tag, start, end = ner_t
        cut_word.append("".join(seg[0][start:end + 1]))
        cut_word_type.append(tag)
print("cut_word:" + cut_word)
print("cut_word_type:" + cut_word_type)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=164437832.0, style=ProgressStyle(descri…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e2afdba397d5> in <module>
#       1 from ltp import LTP
# ----> 2 ltp = LTP()
#       3 cut_word = []
#       4 cut_word_type=[]
#       5 for t in title:
#
# D:\ANACONDA\lib\site-packages\ltp\frontend.py in __init__(self, path, device, **kwargs)
#     114             resume_download = kwargs.pop("resume_download", False)
#     115             local_files_only = kwargs.pop("local_files_only", False)
# --> 116             path = cached_path(
#     117                 model_map.get(path, path),
#     118                 cache_dir=cache_dir,
#
# D:\ANACONDA\lib\site-packages\transformers\file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1075     if is_remote_url(url_or_filename):
#    1076         # URL, so get it from the cache (downloading if necessary)
# -> 1077         output_path = get_from_cache(
#    1078             url_or_filename,
#    1079             cache_dir=cache_dir,
#
# D:\ANACONDA\lib\site-packages\transformers\file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1301             logger.info("%s not found in cache or force_download set to True, downloading to %s", url, temp_file.name)
#    1302
# -> 1303             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1304
#    1305         logger.info("storing %s in cache at %s", url, cache_path)
#
# D:\ANACONDA\lib\site-packages\transformers\file_utils.py in http_get(url, temp_file, proxies, resume_size, headers)
#    1164         disable=bool(logging.get_verbosity() == logging.NOTSET),
#    1165     )
# -> 1166     for chunk in r.iter_content(chunk_size=1024):
#    1167         if chunk:  # filter out keep-alive new chunks
#    1168             progress.update(len(chunk))
#
# D:\ANACONDA\lib\site-packages\requests\models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# D:\ANACONDA\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# D:\ANACONDA\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# D:\ANACONDA\lib\http\client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# D:\ANACONDA\lib\http\client.py in readinto(self, b)
#     496         # connection, and the user is reading more bytes than will be provided
#     497         # (for example, reading in 1k chunks)
# --> 498         n = self.fp.readinto(b)
#     499         if not n and b:
#     500             # Ideally, we would raise IncompleteRead if the content-length
#
# D:\ANACONDA\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud

text_string=''
for i in all_title:
    text_string = text_string+ i +' '
font = " /System/Library/Fonts/PingFang.ttc"
wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2020年度词云',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-c4b8698c9f2d> in <module>
#       7     text_string = text_string+ i +' '
#       8 font = " /System/Library/Fonts/PingFang.ttc"
# ----> 9 wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
#      10 # wordcloud.to_file('./images/2020.png')
#      11 plt.figure(figsize=(15, 15))
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     612         """
#     613         words = self.process_text(text)
# --> 614         self.generate_from_frequencies(words)
#     615         return self
#     616
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     444                 font_size = self.height
#     445             else:
# --> 446                 self.generate_from_frequencies(dict(frequencies[:2]),
#     447                                                max_font_size=self.height)
#     448                 # find font sizes
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     494             while True:
#     495                 # try to find a position
# --> 496                 font = ImageFont.truetype(self.font_path, font_size)
#     497                 # transpose font optionally
#     498                 transposed_font = ImageFont.TransposedFont(
#
# D:\ANACONDA\lib\site-packages\PIL\ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     653
#     654     try:
# --> 655         return freetype(font)
#     656     except OSError:
#     657         if not isPath(font):
#
# D:\ANACONDA\lib\site-packages\PIL\ImageFont.py in freetype(font)
#     650
#     651     def freetype(font):
# --> 652         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     653
#     654     try:
#
# D:\ANACONDA\lib\site-packages\PIL\ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     191                         load_from_bytes(f)
#     192                     return
# --> 193             self.font = core.getfont(
#     194                 font, size, index, encoding, layout_engine=layout_engine
#     195             )
#
# OSError: cannot open resource

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud

text_string=''
for i in all_title:
    text_string = text_string+ i +' '
# font = " /System/Library/Fonts/PingFang.ttc"
wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2020年度词云',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f211a2408cc2> in <module>
#       4
#       5 text_string=''
# ----> 6 for i in all_title:
#       7     text_string = text_string+ i +' '
#       8 # font = " /System/Library/Fonts/PingFang.ttc"
#
# NameError: name 'all_title' is not defined

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
all_title = []
for i in data:
    all_title.append(i[1])

text_string=''
for i in all_title:
    text_string = text_string+ i +' '
font = " /System/Library/Fonts/PingFang.ttc"
wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2020年度词云',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-9e3ff46a80ca> in <module>
#      13     text_string = text_string+ i +' '
#      14 font = " /System/Library/Fonts/PingFang.ttc"
# ---> 15 wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
#      16 # wordcloud.to_file('./images/2020.png')
#      17 plt.figure(figsize=(15, 15))
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     612         """
#     613         words = self.process_text(text)
# --> 614         self.generate_from_frequencies(words)
#     615         return self
#     616
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     444                 font_size = self.height
#     445             else:
# --> 446                 self.generate_from_frequencies(dict(frequencies[:2]),
#     447                                                max_font_size=self.height)
#     448                 # find font sizes
#
# D:\ANACONDA\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     494             while True:
#     495                 # try to find a position
# --> 496                 font = ImageFont.truetype(self.font_path, font_size)
#     497                 # transpose font optionally
#     498                 transposed_font = ImageFont.TransposedFont(
#
# D:\ANACONDA\lib\site-packages\PIL\ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     653
#     654     try:
# --> 655         return freetype(font)
#     656     except OSError:
#     657         if not isPath(font):
#
# D:\ANACONDA\lib\site-packages\PIL\ImageFont.py in freetype(font)
#     650
#     651     def freetype(font):
# --> 652         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     653
#     654     try:
#
# D:\ANACONDA\lib\site-packages\PIL\ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     191                         load_from_bytes(f)
#     192                     return
# --> 193             self.font = core.getfont(
#     194                 font, size, index, encoding, layout_engine=layout_engine
#     195             )
#
# OSError: cannot open resource

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
all_title = []
for i in data:
    all_title.append(i[1])

text_string=''
for i in all_title:
    text_string = text_string+ i +' '
font = "./PingFang.ttc"
wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2020年度词云',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
all_title = []
for i in data:
    all_title.append(i[1])

text_string=''
for i in all_title:
    text_string = text_string+ i +' '
font = "./PingFang.ttc"
wordcloud = WordCloud(width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2021年1月6日热搜',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
all_title = []
for i in data:
    all_title.append(i[1])

text_string=''
for i in all_title:
    text_string = text_string+ i +' '
font = "./PingFang.ttc"
wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2021年1月6日热搜',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
from ltp import LTP
ltp = LTP()
cut_word = []
cut_word_type=[]
for t in title:
    seg, hidden = ltp.seg([t])
    ner = ltp.ner(hidden)
    if len(ner[0])==0:
        continue
    for ner_t in ner[0]:
        tag, start, end = ner_t
        cut_word.append("".join(seg[0][start:end + 1]))
        cut_word_type.append(tag)
print("cut_word:" + cut_word)
print("cut_word_type:" + cut_word_type)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=164437832.0, style=ProgressStyle(descri…
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e2afdba397d5> in <module>
#       3 cut_word = []
#       4 cut_word_type=[]
# ----> 5 for t in title:
#       6     seg, hidden = ltp.seg([t])
#       7     ner = ltp.ner(hidden)
#
# NameError: name 'title' is not defined

# %%
from ltp import LTP
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
all_title = []
for i in data:
    all_title.append(i[1])
ltp = LTP()
cut_word = []
cut_word_type=[]
for t in all_title:
    seg, hidden = ltp.seg([t])
    ner = ltp.ner(hidden)
    if len(ner[0])==0:
        continue
    for ner_t in ner[0]:
        tag, start, end = ner_t
        cut_word.append("".join(seg[0][start:end + 1]))
        cut_word_type.append(tag)
print("cut_word:")
print(cut_word)
print("cut_word_type:")
print(cut_word_type)
# Out:
# cut_word:
# ['金莎', '黑龙江', '陈凯歌', '安吉', '廊坊师范学院', '特朗普', '中国', '石家庄', '林更新', '韩红', '孟美岐', '中国', '卡戴珊', '美国', '郑渊洁', '李荣浩', '岳云鹏', '岳云', '河北', '金庸', '陈坤', '北京', '王笑悦', '孙侨潞', '牛津', '南非', '彭斯', '特朗普', '胡先煦', '杨幂', '倪妮', '河北', '英雄联盟', '沈阳', '李沁新', '石家庄', '库克', '蔡徐坤', '上海']
# cut_word_type:
# ['Nh', 'Ns', 'Nh', 'Nh', 'Ni', 'Nh', 'Ns', 'Ns', 'Nh', 'Nh', 'Nh', 'Ns', 'Nh', 'Ns', 'Nh', 'Nh', 'Nh', 'Nh', 'Ns', 'Nh', 'Nh', 'Ns', 'Nh', 'Nh', 'Ns', 'Ns', 'Nh', 'Nh', 'Nh', 'Nh', 'Nh', 'Ns', 'Ni', 'Ns', 'Nh', 'Ns', 'Nh', 'Nh', 'Ns']

# %%
from ltp import LTP
import pickle
f = open('./微博热搜.pkl', 'rb')
data = pickle.load(f)
all_title = []
for i in data:
    all_title.append(i[1])
ltp = LTP()
cut_word = []
cut_word_type=[]
for t in all_title:
    seg, hidden = ltp.seg([t])
    ner = ltp.ner(hidden)
    if len(ner[0])==0:
        continue
    for ner_t in ner[0]:
        tag, start, end = ner_t
        cut_word.append("".join(seg[0][start:end + 1]))
        cut_word_type.append(tag)
    with open('./分词结果.pkl', 'wb') as f:
        pickle.dump(cut_word, f)

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud
import pickle
f = open('./分词结果.pkl', 'rb')
data = pickle.load(f)
text_string=''
for i in data:
    text_string = text_string+ i +' '
font = "./PingFang.ttc"
wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2021年1月6日热搜',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
import requests
from lxml import etree
import pickle
if __name__ == "__main__":
    url = "https://www.cnblogs.com/sonder/p/13496173.html"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:84.0) Gecko/20100101 Firefox/84.0"
    }
    page = requests.get(url, headers).text
    tree = etree.HTML(page)
    hotSearch_all_data = tree.xpath('//div[@id="cnblogs_post_body"]/p[5]//text()')
    with open('./2020微博热搜汇总.pkl', 'wb') as f:
        pickle.dump(hotSearch_all_data, f)
    print("数据保存成功！")
# Out:
# 数据保存成功！

# %%
from ltp import LTP
import pickle
f = open('./2020微博热搜汇总.pkl', 'rb')
data = pickle.load(f)
print(type(data))
ltp = LTP()
cut_word = []
cut_word_type=[]
for t in data:
    seg, hidden = ltp.seg([t])
    ner = ltp.ner(hidden)
    if len(ner[0])==0:
        continue
    for ner_t in ner[0]:
        tag, start, end = ner_t
        cut_word.append("".join(seg[0][start:end + 1]))
        cut_word_type.append(tag)
    with open('./分词结果1.pkl', 'wb') as f:
        pickle.dump(cut_word, f)
# Out:
# <class 'list'>

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud
import pickle
f = open('./分词结果1.pkl', 'rb')
data = pickle.load(f)
text_string=''
for i in data:
    text_string = text_string+ i +' '
font = "./PingFang.ttc"
wordcloud = WordCloud(font_path=font,width=600,height=600,background_color='white',).generate(text_string)
# wordcloud.to_file('./images/2020.png')
plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
myfontdict = {'fontsize':80}
plt.title('2020年热搜集合',fontdict = myfontdict)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
